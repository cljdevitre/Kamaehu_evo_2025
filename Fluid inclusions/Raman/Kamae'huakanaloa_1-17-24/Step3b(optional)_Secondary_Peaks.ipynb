# %% [markdown]
# # 3b. Fitting carbonate and SO$_2$ peaks
# - This notebook shows how to fit secondary peaks, such as carbonate and S-rich phases in vapour bubbles and fluid inclusions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
from tqdm import tqdm
pf.__version__
# Out:
# '0.0.88'

# %%
# Here, we are loading in the settings files from Step1. If all you want to do is find secondary phases, paste that code here
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()

# %%
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'CRR', 'secphase']
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
File_df=pd.DataFrame(data={'filename': Diad_Files})
# Out:
# ['05 187-1-111-reg4-A--Spectrum--012--Spec.Data 1.txt', '06 187-1-111-reg4-A--Spectrum--013--Spec.Data 1.txt', '07 187-1-111-reg4-A--Spectrum--014--Spec.Data 1.txt', '08 187-1-111-reg4-B--Spectrum--016--Spec.Data 1.txt', '09 187-1-111-reg4-B--Spectrum--017--Spec.Data 1.txt', '10 187-1-111-reg4-B--Spectrum--018--Spec.Data 1.txt', '12 187-1-111-reg4-C--Spectrum--021--Spec.Data 1.txt', '13 187-1-111-reg4-C--Spectrum--022--Spec.Data 1.txt', '14 187-1-111-reg4-C--Spectrum--023--Spec.Data 1.txt', '16 187-1-111-reg5-A--Spectrum--032--Spec.Data 1.txt', '17 187-1-111-reg5-A--Spectrum--033--Spec.Data 1.txt', '18 187-1-111-reg5-A--Spectrum--034--Spec.Data 1.txt', '19 187-1-111-reg5-B--Spectrum--036--Spec.Data 1.txt', '21 187-1-111-reg5-C--Spectrum--038--Spec.Data 1.txt', '22 187-1-111-reg5-D--Spectrum--041--Spec.Data 1.txt', '23 187-1-111-reg6-A--Spectrum--047--Spec.Data 1.txt', '24 187-1-111-reg6-B--Spectrum--048--Spec.Data 1.txt', '25 187-1-111-reg7-A--Spectrum--055--Spec.Data 1.txt', '26 187-1-111-reg7-B--Spectrum--057--Spec.Data 1.txt', '28 187-1-111-reg8-A--Spectrum--061--Spec.Data 1.txt', '29 187-1-111-reg8-B--Spectrum--063--Spec.Data 1.txt', '30 187-1-111-reg8-C--Spectrum--065--Spec.Data 1.txt', '32 187-1-112-reg1-A--Spectrum--079--Spec.Data 1.txt', '33 187-1-112-reg2-A--Spectrum--082--Spec.Data 1.txt', '34 187-1-112-reg2-B--Spectrum--085--Spec.Data 1.txt', '35 187-1-112-reg2-C--Spectrum--088--Spec.Data 1.txt', '37 187-1-112-reg3-A--Spectrum--094--Spec.Data 1.txt', '38 187-1-112-reg3-B--Spectrum--096--Spec.Data 1.txt', '39 187-1-112-reg3-C--Spectrum--097--Spec.Data 1.txt', '41 187-1-112-reg4-A--Spectrum--105--Spec.Data 1.txt', '42 187-1-112-reg4-B--Spectrum--107--Spec.Data 1.txt', '43 187-1-112-reg4-C--Spectrum--109--Spec.Data 1.txt', '44 187-1-112-reg5-A--Spectrum--114--Spec.Data 1.txt', '45 187-1-112-reg5-B--Spectrum--116--Spec.Data 1.txt', '46 187-1-112-reg5-C--Spectrum--118--Spec.Data 1.txt', '48 187-1-112-reg6-A--Spectrum--123--Spec.Data 1.txt', '49 187-1-112-reg6-B--Spectrum--125--Spec.Data 1.txt', '50 187-1-112-reg6-C--Spectrum--127--Spec.Data 1.txt', '51 187-1-112-reg7-A--Spectrum--131--Spec.Data 1.txt', '52 187-1-112-reg7-B--Spectrum--133--Spec.Data 1.txt', '53 187-1-112-reg7-C--Spectrum--135--Spec.Data 1.txt', '58 FO1--Spectrum--141--Spec.Data 1.txt']

# %% [markdown]
# ## Plot spectra in a given region of space to examine secondary peaks or not

# %% [markdown]
# ### You'll need to tweak the peak parameters to find them
# - height = minimum height a peak should have to be identified
# - threshold = required vertical distance between a peak and its neighbours
# - distance = required horizontal distance bewteen neighbouring peaks.
# - prominence = required prominence of peaks
# - width = width of peaks

# %% [markdown]
# ## Example 1 - Using Scipy find peaks to look for SO2

# %%
prominence_SO2=20
height_SO2=20
width_SO2=1
threshold_SO2=1

SO2_peaks_scipy, x_data_scipy, y_data_scipy, fig_scipy=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
filetype=spectra_filetype, find_peaks_filter=True,  
xlim_peaks=[1145, 1155], xlim_plot=[1130, 1180], yscale=0.3,
prominence=prominence_SO2, height=height_SO2, width=width_SO2, threshold=threshold_SO2)

SO2_peaks=SO2_peaks_scipy

# %%
SO2_peaks
# Out:
#     pos  height  prom                                         file_names
# 0   NaN     NaN   NaN  05 187-1-111-reg4-A--Spectrum--012--Spec.Data ...
# 1   NaN     NaN   NaN  06 187-1-111-reg4-A--Spectrum--013--Spec.Data ...
# 2   NaN     NaN   NaN  07 187-1-111-reg4-A--Spectrum--014--Spec.Data ...
# 3   NaN     NaN   NaN  08 187-1-111-reg4-B--Spectrum--016--Spec.Data ...
# 4   NaN     NaN   NaN  09 187-1-111-reg4-B--Spectrum--017--Spec.Data ...
# 5   NaN     NaN   NaN  10 187-1-111-reg4-B--Spectrum--018--Spec.Data ...
# 6   NaN     NaN   NaN  12 187-1-111-reg4-C--Spectrum--021--Spec.Data ...
# 7   NaN     NaN   NaN  13 187-1-111-reg4-C--Spectrum--022--Spec.Data ...
# 8   NaN     NaN   NaN  14 187-1-111-reg4-C--Spectrum--023--Spec.Data ...
# 9   NaN     NaN   NaN  16 187-1-111-reg5-A--Spectrum--032--Spec.Data ...
# 10  NaN     NaN   NaN  17 187-1-111-reg5-A--Spectrum--033--Spec.Data ...
# 11  NaN     NaN   NaN  18 187-1-111-reg5-A--Spectrum--034--Spec.Data ...
# 12  NaN     NaN   NaN  19 187-1-111-reg5-B--Spectrum--036--Spec.Data ...
# 13  NaN     NaN   NaN  21 187-1-111-reg5-C--Spectrum--038--Spec.Data ...
# 14  NaN     NaN   NaN  22 187-1-111-reg5-D--Spectrum--041--Spec.Data ...
# 15  NaN     NaN   NaN  23 187-1-111-reg6-A--Spectrum--047--Spec.Data ...
# 16  NaN     NaN   NaN  24 187-1-111-reg6-B--Spectrum--048--Spec.Data ...
# 17  NaN     NaN   NaN  25 187-1-111-reg7-A--Spectrum--055--Spec.Data ...
# 18  NaN     NaN   NaN  26 187-1-111-reg7-B--Spectrum--057--Spec.Data ...
# 19  NaN     NaN   NaN  28 187-1-111-reg8-A--Spectrum--061--Spec.Data ...
# 20  NaN     NaN   NaN  29 187-1-111-reg8-B--Spectrum--063--Spec.Data ...
# 21  NaN     NaN   NaN  30 187-1-111-reg8-C--Spectrum--065--Spec.Data ...
# 22  NaN     NaN   NaN  32 187-1-112-reg1-A--Spectrum--079--Spec.Data ...
# 23  NaN     NaN   NaN  33 187-1-112-reg2-A--Spectrum--082--Spec.Data ...
# 24  NaN     NaN   NaN  34 187-1-112-reg2-B--Spectrum--085--Spec.Data ...
# 25  NaN     NaN   NaN  35 187-1-112-reg2-C--Spectrum--088--Spec.Data ...
# 26  NaN     NaN   NaN  37 187-1-112-reg3-A--Spectrum--094--Spec.Data ...
# 27  NaN     NaN   NaN  38 187-1-112-reg3-B--Spectrum--096--Spec.Data ...
# 28  NaN     NaN   NaN  39 187-1-112-reg3-C--Spectrum--097--Spec.Data ...
# 29  NaN     NaN   NaN  41 187-1-112-reg4-A--Spectrum--105--Spec.Data ...
# 30  NaN     NaN   NaN  42 187-1-112-reg4-B--Spectrum--107--Spec.Data ...
# 31  NaN     NaN   NaN  43 187-1-112-reg4-C--Spectrum--109--Spec.Data ...
# 32  NaN     NaN   NaN  44 187-1-112-reg5-A--Spectrum--114--Spec.Data ...
# 33  NaN     NaN   NaN  45 187-1-112-reg5-B--Spectrum--116--Spec.Data ...
# 34  NaN     NaN   NaN  46 187-1-112-reg5-C--Spectrum--118--Spec.Data ...
# 35  NaN     NaN   NaN  48 187-1-112-reg6-A--Spectrum--123--Spec.Data ...
# 36  NaN     NaN   NaN  49 187-1-112-reg6-B--Spectrum--125--Spec.Data ...
# 37  NaN     NaN   NaN  50 187-1-112-reg6-C--Spectrum--127--Spec.Data ...
# 38  NaN     NaN   NaN  51 187-1-112-reg7-A--Spectrum--131--Spec.Data ...
# 39  NaN     NaN   NaN  52 187-1-112-reg7-B--Spectrum--133--Spec.Data ...
# 40  NaN     NaN   NaN  53 187-1-112-reg7-C--Spectrum--135--Spec.Data ...
# 41  NaN     NaN   NaN             58 FO1--Spectrum--141--Spec.Data 1.txt

# %% [markdown]
# ### Now filter out ones with no peaks, or low prominence before we loop through them

# %%
# Remove the ones where it didnt find SO2
SO2_notNa=np.isnan(SO2_peaks['pos'])
# Remove ones with a prominence less than this. 
prom_filt=10
SO2_filter=((SO2_peaks['prom']>10))&(~SO2_notNa)
print('Number kept with this filter:')
print(sum(SO2_filter))
print('Number discarded:')
print(sum(~SO2_filter&(~SO2_notNa)))
filenames_SO2=list(File_df['filename'].loc[SO2_filter])
print('filenames with SO2:')
print(filenames_SO2)
# Out:
# Number kept with this filter:
# 0
# Number discarded:
# 0
# filenames with SO2:
# []

# %% [markdown]
# ### Choose a filename to test peak fits

# %%
if sum(SO2_filter)>0:
    filename=filenames_SO2[0]

# %% [markdown]
# ### Set up configuration file for S peak fitting
# - Here, we are using a spline to quantify the area down to the 92% of the peak height (int_cut_of=0.08), there are differen options you can use for this

# %%
if sum(SO2_filter)>0:
    SO2_peak_config=pf.generic_peak_config(name='SO2', lower_bck=[1110, 1130],
    upper_bck=[1190, 1200], cent=1150, x_range_bck=20, N_peaks=1,   model_name='PseudoVoigtModel', int_cut_off=0.05)
    print(SO2_peak_config)

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
    path=spectra_path, filename=filename, filetype=spectra_filetype, 
     plot_figure=True)

# %% [markdown]
# ## Now lets loop through files

# %%
files_to_fit=filenames_SO2
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_SO2 = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_SO2 = pd.concat([df_Merge_SO2, SO2_peak_fit], axis=0)
# Out:
# 0it [00:00, ?it/s]

# %%
df_Merge_SO2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Plot peak areas and peak heights

# %%
if sum(SO2_filter)>0:
    plt.plot(df_Merge_SO2['Peak_Area_SO2'], 
            df_Merge_SO2['Peak_Height_SO2'], 'ok')
    plt.xlabel('Peak Area SO2')
    plt.ylabel('Peak Height SO2')
    # plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ### Save this to excel

# %%
if sum(SO2_filter)>0:
    df_Merge_SO2.to_excel('SO2_Peak_fits.xlsx', index=False)

# %% [markdown]
# ## Now do the same to ID any carbonate peaks

# %% [markdown]
# ### Using scipy find peaks methods
# - This method doesnt always work perfectly for broader carbonate peaks

# %%
prominence_carb=15
height_carb=10
width_carb=2
threshold_carb=1

Carb_peaks_scipy, x_data_scipy, y_data_scipy, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, find_peaks_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1075, 1120], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_scipy

# %%
# prominence_carb=30
# height_carb=10
# width_carb=1
# threshold_carb=1

# Carb_peaks_prom, x_data_prom, y_data_prom, fig=pf.plot_secondary_peaks(
# Diad_Files=Diad_Files, path=spectra_path, 
#  filetype=spectra_filetype, prominence_filter=True,  
# xlim_plot=[1050, 1150], xlim_peaks=[1070, 1100], yscale=0.3,
# prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)

# %% [markdown]
# ## Find ones with certain peak parameters to include

# %%
Carb_noNa=np.isnan(Carb_peaks['pos'])
prom_filter=10
Carb_filter=((Carb_peaks['prom']>prom_filter))&(~Carb_noNa)
print('Number kept with this filter:')
print(sum(Carb_filter))
print('Number discarded:')
print(sum(~Carb_filter&(~Carb_noNa)))
filenames_Carb=list(File_df['filename'].loc[Carb_filter])
print('filenames with carb:')
print(filenames_Carb)
# Out:
# Number kept with this filter:
# 2
# Number discarded:
# 0
# filenames with carb:
# ['48 187-1-112-reg6-A--Spectrum--123--Spec.Data 1.txt', '49 187-1-112-reg6-B--Spectrum--125--Spec.Data 1.txt']

# %% [markdown]
# ### Fit one to tweak parameters

# %%
if sum(Carb_filter)>0:
    filename_carb=filenames_Carb[0]

    Carb_peak_config=pf.generic_peak_config(name='Carb', lower_bck=[1050, 1070],
    upper_bck=[1120, 1150], cent=1090, x_range_bck=50, N_poly_carb_bck=2, model_name='Spline')
    print(Carb_peak_config)

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
    path=spectra_path, filename=filename_carb, filetype=spectra_filetype,
     plot_figure=True)
# Out:
# generic_peak_config(name='Carb', lower_bck=[1050, 1070], upper_bck=[1120, 1150], model_name='Spline', x_range_bck=50, N_poly_carb_bck=2, amplitude=1000, cent=1090, outlier_sigma=12, distance=10, prominence=5, width=6, threshold=0.1, height=100, exclude_range=None, return_other_params=False, N_peaks=1, int_cut_off=0.05)

# %% [markdown]
# ### Loop over all carbonate files

# %%
files_to_fit=filenames_Carb
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_Carb = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_Carb = pd.concat([df_Merge_Carb, Carb_peak_fit], axis=0)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  4.97it/s]

# %%
if sum(Carb_filter)>0:
    plt.plot(df_Merge_Carb['Peak_Area_Carb'], 
        df_Merge_Carb['Peak_Height_Carb'], 'ok')
    plt.xlabel('Peak Area Carb')
    plt.ylabel('Peak Height Carb')
# plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ## Save to excel

# %%
if sum(Carb_filter)>0:
    df_Merge_Carb=df_Merge_Carb[df_Merge_Carb['Peak_Cent_Carb']<1100]
    df_Merge_Carb['filename'] = df_Merge_Carb['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_Carb.to_excel('Carb_Peak_fits.xlsx', index=False )

# %%
df_Merge_Carb
# Out:
#                                  filename  Peak_Cent_Carb  Peak_Area_Carb  \
# 0  48 187-1-112-reg6-A--Spectrum--123.txt     1097.127641      436.489417
#
#    Peak_Height_Carb Model_name
# 0         35.069844     Spline
