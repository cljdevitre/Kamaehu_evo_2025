# %% [markdown]
# # 2. Filtering diad files into categories
# - This workbook shows how to filter diad files into 3 categories, to allow easier fitting
# - This data is from Devitre et al. (in review)

# %%
# Import useful python packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
pf.__version__
# Out:
# '0.0.88'

# %% [markdown]
# ## Get the folder to your files
# - This loads in the information from Step1 of where you have stored things and file types

# %%
## This reads in the previous settings you set in Step1
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()
# dont fit files with these strings in them
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'CRR', 'no_diad','093']

# %% [markdown]
# ## This function finds all files in your path with the specified file format
# - Specify information about your file formats here, as well as any text in filenames that you dont want to fit.

# %%
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
# Out:
# ['04 187-1-127-reg5-B--Spectrum--012--Spec.Data 1.txt', '05 187-1-127-reg5-C--Spectrum--015--Spec.Data 1.txt', '06 187-1-127-reg5-D--Spectrum--018--Spec.Data 1.txt', '08 187-1-127-reg6-A--Spectrum--024--Spec.Data 1.txt', '09 187-1-127-reg6-B--Spectrum--027--Spec.Data 1.txt', '10 187-1-127-reg6-C--Spectrum--030--Spec.Data 1.txt', '11 187-1-127-reg6-D--Spectrum--033--Spec.Data 1.txt', '13 187-1-127-reg7-A--Spectrum--037--Spec.Data 1.txt', '14 187-1-127-reg7-B--Spectrum--040--Spec.Data 1.txt', '15 187-1-127-reg7-C--Spectrum--043--Spec.Data 1.txt', '16 187-1-127-reg8-A--Spectrum--046--Spec.Data 1.txt', '17 187-1-127-reg8-B--Spectrum--048--Spec.Data 1.txt', '20 187-1-128-A_withmelt--Spectrum--060--Spec.Data 1.txt', '21 187-1-128-B--Spectrum--063--Spec.Data 1.txt', '22 187-1-128-A--Spectrum--064--Spec.Data 1.txt', '23 187-1-128-C--Spectrum--067--Spec.Data 1.txt', '24 187-1-128-D--Spectrum--070--Spec.Data 1.txt', '26 187-1-129-A--Spectrum--076--Spec.Data 1.txt', '28 187-1-130-A--Spectrum--087--Spec.Data 1.txt', '30 187-1-130-B--Spectrum--094--Spec.Data 1.txt', '31 187-1-130-C--Spectrum--100--Spec.Data 1.txt', '32 187-1-130-D_hasmelt--Spectrum--105--Spec.Data 1.txt']

# %% [markdown]
# ## Find approximate peak positions
# - Tweak Scipy parameters to find the diad peaks
# - Tweak these parameters to make sure Scipy 'find_peaks' gets your diad peaks for your instrument.
# - Prominence: most useful parameter, required prominence of peaks
# - height: Minimum height of peaks, not that useful with various background positions
# - distance: Used to help with peaks that are very close to one another, smaller distance, remove peaks until keep set distance apart
# - width: Minimum width of peaks

# %%
# Tweak parameters away from the default here
diad_id_config=pf.diad_id_config(prominence=30, width=1)
diad_id_config
# Out:
# diad_id_config(height=1, width=1, prominence=30, plot_figure=True, exclude_range1=None, exclude_range2=None, approx_diad2_pos=(1379, 1395), approx_diad1_pos=(1275, 1290), Diad2_window=(1349, 1425), Diad1_window=(1245, 1290), approx_diad2_pos_3peaks=(1379, 1395, 1362))

# %%
# Check it has found the peaks of interest. Here we are looking at the 1st file

df_peaks, Diad, fig=pf.identify_diad_peaks(
config=diad_id_config, 
path=spectra_path, filename=Diad_Files[0],
filetype=spectra_filetype, plot_figure=True)
df_peaks
# Out:
#                                             filename  approx_split  \
# 1  04 187-1-127-reg5-B--Spectrum--012--Spec.Data ...    103.805261
#
#      Diad1_pos    Diad2_pos  HB1_pos  HB2_pos  C13_pos  Diad1_abs_prom  \
# 1  1284.209913  1388.015173      NaN      NaN      NaN      249.248563
#
#    Diad2_abs_prom  HB1_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 1      526.097713           NaN  ...         NaN         NaN    914.548551
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 1         NaN        665.299988        664.899994                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 1                    NaN                        NaN                        NaN
#
# [1 rows x 39 columns]

# %% [markdown]
# ### Now you have looked at a few files and are happy with these parameters, loop over all files to get approximate fit parameters for all your diad acquisitions

# %%
fit_params, data_y_all=pf.loop_approx_diad_fits(spectra_path=spectra_path, config=diad_id_config, 
                       Diad_Files=Diad_Files, filetype=spectra_filetype, plot_figure=False)
fit_params.head()
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 100%|██████████| 22/22 [00:00<00:00, 38.85it/s]
#                                             filename  approx_split  \
# 0  04 187-1-127-reg5-B--Spectrum--012--Spec.Data ...    103.805261
# 1  05 187-1-127-reg5-C--Spectrum--015--Spec.Data ...    103.953750
# 2  06 187-1-127-reg5-D--Spectrum--018--Spec.Data ...    103.673270
# 3  08 187-1-127-reg6-A--Spectrum--024--Spec.Data ...    103.849258
# 4  09 187-1-127-reg6-B--Spectrum--027--Spec.Data ...    103.645772
#
#      Diad1_pos    Diad2_pos  HB1_pos      HB2_pos  C13_pos  Diad1_abs_prom  \
# 0  1284.209913  1388.015173      NaN          NaN      NaN      249.248563
# 1  1283.995428  1387.949178      NaN          NaN      NaN      189.503919
# 2  1284.517891  1388.191161      NaN          NaN      NaN      163.698117
# 3  1284.143917  1387.993175      NaN  1409.458178      NaN      414.190591
# 4  1284.743376  1388.389147      NaN          NaN      NaN      215.082591
#
#    Diad2_abs_prom  HB1_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      526.097713           NaN  ...         NaN         NaN    914.548551
# 1      384.475653           NaN  ...         NaN         NaN    853.603925
# 2      329.624764           NaN  ...         NaN         NaN    825.498105
# 3      877.488809           NaN  ...  718.768661         NaN   1080.390603
# 4      414.599524           NaN  ...         NaN         NaN    878.582591
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        665.299988        664.899994                     NaN
# 1         NaN        664.100006        663.750000                     NaN
# 2         NaN        661.799988        661.500000                     NaN
# 3         NaN        666.200012        666.100006                     NaN
# 4         NaN        663.500000        663.100006                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3               1.005846                        NaN                  28.495212
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Check for duplicates now!

# %%
file_s=pf.extracting_filenames_generic(
    names=fit_params['filename'].reset_index(drop=True),
prefix=prefix, str_prefix=str_prefix,
   file_ext=spectra_file_ext)
# Out:
# good job, no duplicate file names

# %% [markdown]
# ## Filter out spectra with Cosmic rays

# %% [markdown]
# ### Pick a spectra to tweak first

# %%
Diad_files=fit_params['filename']
i=0
filename_select=Diad_files.iloc[i] 
print(Diad_Files[i])
plot1=pf.plot_diad(path=spectra_path, filename=filename_select, filetype=spectra_filetype)
# Out:
# 04 187-1-127-reg5-B--Spectrum--012--Spec.Data 1.txt

# %% [markdown]
# ### Pick your other parameters
#
# NOTE that you can also change the number of neighbors considered in the intensity factor (n),but n=1 is often the best. dynfact is the intensity factor cutoff above which pixels are considered outliers in the first pass (y axis on the first plot on the leftmost). dynfact_2 is the same, but for the second pass. The filter automatically disregards pixels that are known to be of interest (here diads, hbs and c13).

# %%
# This extract the peaks for the diads, HBs and C13 from fit_params_crr, essential to the CRR process.
diad_peaks=fit_params[['Diad1_pos','Diad2_pos','HB1_pos','HB2_pos','C13_pos']]

#Pick your settings
plot_rays='rays_only'#whether to plot the results or not
export_cleanspec=True #whether to export the spectra with the cosmic ray pixels removed
save_fig='all' #whether to save the figures, options are 'all' or the default 'rays_only'
dynfact=0.001 #dynamic intensity factor for the first pass (y axis on the leftmost plots)
dynfact_2=0.001#dynamic intensity factor for the second pass
n=1 # number of neighboring pixels being compared, typically 1 is ideal.

exclude_ranges=[(1100,1200)] # List of tuples containing ranges to exclude from filtering (i.e., for secondary peaks

# %% [markdown]
# ### Run the filter on the selected spectra
# - rays_found is a dataframe containing the filename and whether cosmic rays were found. spectrum is the filtered spectrum in the form of a dataframe.
# - It contains nan values where the cosmic rays are. It is NOT for fitting.

# %%
rays_found,spectrum=pf.cosmicray_filter.filter_singleray(path=spectra_path,
                                        exclude_ranges=exclude_ranges,filetype=spectra_filetype,
                                        Diad_files=Diad_files,i=i,diad_peaks=diad_peaks,plot_rays=plot_rays,
                                      export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n)

# %% [markdown]
# ###  Loop over all other spectra
# the output of this is the data_y_all file, which contains plottable spectra and the new fit_params file with filtered spectra

# %%
data_y_all_crr,fit_params_crr=pf.cosmicray_filter.filter_raysinloop(Diad_files=Diad_files, spectra_path=spectra_path, 
                exclude_ranges=exclude_ranges,filetype=spectra_filetype,
                    fit_params=fit_params, diad_peaks=diad_peaks,plot_rays=plot_rays,
                    export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n )
# Out:
# 100%|██████████| 22/22 [00:00<00:00, 43.03it/s]
#                                             filename  rays_present  \
# 0  04 187-1-127-reg5-B--Spectrum--012--Spec.Data ...           0.0
# 1  05 187-1-127-reg5-C--Spectrum--015--Spec.Data ...           0.0
# 2  06 187-1-127-reg5-D--Spectrum--018--Spec.Data ...           0.0
# 3  08 187-1-127-reg6-A--Spectrum--024--Spec.Data ...           1.0
# 4  09 187-1-127-reg6-B--Spectrum--027--Spec.Data ...           0.0
#
#    approx_split    Diad1_pos    Diad2_pos  HB1_pos      HB2_pos  C13_pos  \
# 0    103.805261  1284.209913  1388.015173      NaN          NaN      NaN
# 1    103.953750  1283.995428  1387.949178      NaN          NaN      NaN
# 2    103.673270  1284.517891  1388.191161      NaN          NaN      NaN
# 3    103.849258  1284.143917  1387.993175      NaN  1409.458178      NaN
# 4    103.645772  1284.743376  1388.389147      NaN          NaN      NaN
#
#    Diad1_abs_prom  Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      249.248563      526.097713  ...         NaN         NaN    914.548551
# 1      189.503919      384.475653  ...         NaN         NaN    853.603925
# 2      163.698117      329.624764  ...         NaN         NaN    825.498105
# 3      414.190591      877.488809  ...  718.768661         NaN   1080.390603
# 4      215.082591      414.599524  ...         NaN         NaN    878.582591
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        665.299988        664.899994                     NaN
# 1         NaN        664.100006        663.750000                     NaN
# 2         NaN        661.799988        661.500000                     NaN
# 3         NaN        666.200012        666.100006                     NaN
# 4         NaN        663.500000        663.100006                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3               1.005846                        NaN                  28.495212
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Plot peak parameters
# - This will help you inspect clear cut offs you can use to split your diads into groups for fitting
# - You can enter different x and y coordinates from the dataframe headings above
# - In this example, there are no clear groups, because all the spectra are weak (see paper for definition). This means we place them all in the weak category.

# %%
fig=pf.plot_peak_params(fit_params=fit_params_crr, 
                     x_param='Diad1_pos',  y1_param='approx_split',
                    y2_param='Diad1_abs_prom', y3_param='C13_abs_prom',
                    y4_param='Diad1_prom/std_betweendiads', fill_na=0)

# %%
fit_params_crr.head()
# Out:
#                                             filename  rays_present  \
# 0  04 187-1-127-reg5-B--Spectrum--012--Spec.Data ...           0.0
# 1  05 187-1-127-reg5-C--Spectrum--015--Spec.Data ...           0.0
# 2  06 187-1-127-reg5-D--Spectrum--018--Spec.Data ...           0.0
# 3  08 187-1-127-reg6-A--Spectrum--024--Spec.Data ...           1.0
# 4  09 187-1-127-reg6-B--Spectrum--027--Spec.Data ...           0.0
#
#    approx_split    Diad1_pos    Diad2_pos  HB1_pos      HB2_pos  C13_pos  \
# 0    103.805261  1284.209913  1388.015173      NaN          NaN      NaN
# 1    103.953750  1283.995428  1387.949178      NaN          NaN      NaN
# 2    103.673270  1284.517891  1388.191161      NaN          NaN      NaN
# 3    103.849258  1284.143917  1387.993175      NaN  1409.458178      NaN
# 4    103.645772  1284.743376  1388.389147      NaN          NaN      NaN
#
#    Diad1_abs_prom  Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      249.248563      526.097713  ...         NaN         NaN    914.548551
# 1      189.503919      384.475653  ...         NaN         NaN    853.603925
# 2      163.698117      329.624764  ...         NaN         NaN    825.498105
# 3      414.190591      877.488809  ...  718.768661         NaN   1080.390603
# 4      215.082591      414.599524  ...         NaN         NaN    878.582591
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        665.299988        664.899994                     NaN
# 1         NaN        664.100006        663.750000                     NaN
# 2         NaN        661.799988        661.500000                     NaN
# 3         NaN        666.200012        666.100006                     NaN
# 4         NaN        663.500000        663.100006                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3               1.005846                        NaN                  28.495212
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Filter out ones with really bad splitting or really low diad prominence
# - Here, we only take files with splitting between 101-108 (you will need to tweak this for each instrument)
# - We also only take files with a prominence of diad 1 >10
# - You can also choose to discard based on a specific string in the file name - excxlude exclude_str='noisy'
# - None here got filtered out, but these can be helpful filters on other datasets

# %%
fit_params_filt, data_y_filt, fit_params_disc, data_y_disc=pf.filter_splitting_prominence(
fit_params=fit_params_crr, data_y_all=data_y_all, x_cord=Diad[:, 0],
splitting_limits=[101, 108], lower_diad1_prom=10, exclude_str=None)
# Out:
# Keeping N=22
# Discarding N=0

# %% [markdown]
# ### Now apply filters to find the weakest diads (e.g. ones you wouldnt want to fit a hotband too)
# - In this case, we find the best filters are the position of Diad1 (shifts way more than Diad2),
# and where HB2 had a prominence (e.g., not nan because it wasnt found)
# - We find it also helpful to apply a filter, e.g. weak is Diad1pos<1287 or HB2 prominence nan, and  the prominence of Diad1 is <300X the standard deviation of the diad region

# %%
var='Diad1_pos'
plt.hist(fit_params_filt[var])
# Out:
# (array([1., 1., 0., 2., 4., 5., 2., 3., 3., 1.]),
#  array([1283.02749526, 1283.29862635, 1283.56975744, 1283.84088853,
#         1284.11201962, 1284.38315071, 1284.65428181, 1284.9254129 ,
#         1285.19654399, 1285.46767508, 1285.73880617]),
#  <BarContainer object of 10 artists>)

# %%
# Here we put spectra in the weak group if diad1 position is >1285.5 or if the av prominence of the diad relative to the standard deviation is <150

Filter2=(fit_params_filt['Av_Diad_prom/std_betweendiads']<150)
Filter3=fit_params_filt['Diad2_prom/std_betweendiads']<1100
Filter4=fit_params_filt['Diad1_pos']>1283
filter_bool=Filter4 
fit_params_Weak, fit_params_NotWeak, data_y_Weak, data_y_NotWeak=pf.identify_diad_group(
    fit_params=fit_params_filt, 
     data_y=data_y_filt, 
    x_cord=Diad[:, 0], 
    y_fig_scale=0.3,
    filter_bool=filter_bool, grp_filter='Weak')

# %% [markdown]
# ## Seperate Medium and strong diads
# - Now we need to find something that separates out strong diads from medium strength diads
# - The aim here is to get diads that are sufficiently strong that you have to fit a gaussian background in addition to diads, hbs and C13 peaks. Not having to fit a gaussian background to medium density diads will save you a lot of computational time (and decrease the number of bad fits)
# - In many datasets, you wont need a strong diad category. In which case, everything will stay in the 'Medium' Category
# - Here, the best filter appears to be the prominence of the C13 peak, and the general elevation of the valley between diad and HB above the background outside the diad positions (Mean_Diad_HB variable).

# %%
var1='C13_abs_prom'
var2='Mean_Diad_HB_Valley_prom'
filter_bool_Strong=((fit_params_NotWeak[var1]>100)
                    &(fit_params_NotWeak[var2]>100))
# Here we make a plot of these parameters to better help select the right values
if sum(filter_bool_Strong)>0:
    fig, (ax1) = plt.subplots(1, 1, figsize=(7,4))
    ax1.plot(fit_params_NotWeak[var1].loc[filter_bool_Strong],
            fit_params_NotWeak[var2].loc[filter_bool_Strong], 'xr', label='Strong')
    ax1.plot(fit_params_NotWeak[var1].loc[~filter_bool_Strong],
            fit_params_NotWeak[var2].loc[~filter_bool_Strong], 'xk', label='Medium')

    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_xlabel(var1)
    ax1.set_ylabel(var2)
    ax1.legend()
#This makes a plot
fit_params_Strong, fit_params_Medium, data_y_Strong, data_y_Medium=pf.identify_diad_group(
    fit_params=fit_params_NotWeak.reset_index(drop=True), 
    data_y=data_y_NotWeak,x_cord=Diad[:, 0], 
    filter_bool=filter_bool_Strong, y_fig_scale=0.2, grp_filter='Medium-Strong')

# %% [markdown]
# ## Plot them all

# %%
fig=pf.plot_diad_groups(x_cord=Diad[:, 0], Weak_np=data_y_Weak,
                 Medium_np=data_y_Medium, Strong_np=data_y_Strong,
                   y_fig_scale=0.5)

# %% [markdown]
# ## Now lets save these lists, and we load them in another notebook

# %%
import joblib
joblib.dump(Diad[:, 0], 'np_x.sav')
joblib.dump(Diad[:, 1], 'np_y.sav')
joblib.dump(fit_params_Weak.reset_index(drop=True), 'Weak_df.sav')
joblib.dump(fit_params_Medium.reset_index(drop=True), 'Medium_df.sav')
joblib.dump(fit_params_Strong.reset_index(drop=True), 'Strong_df.sav')
fit_params_disc.to_excel('Discarded_df.xlsx')

# %%
fit_params_Weak
# Out:
#                                              filename  rays_present  \
# 0   04 187-1-127-reg5-B--Spectrum--012--Spec.Data ...           0.0
# 1   05 187-1-127-reg5-C--Spectrum--015--Spec.Data ...           0.0
# 2   06 187-1-127-reg5-D--Spectrum--018--Spec.Data ...           0.0
# 3   08 187-1-127-reg6-A--Spectrum--024--Spec.Data ...           1.0
# 4   09 187-1-127-reg6-B--Spectrum--027--Spec.Data ...           0.0
# 5   10 187-1-127-reg6-C--Spectrum--030--Spec.Data ...           0.0
# 6   11 187-1-127-reg6-D--Spectrum--033--Spec.Data ...           0.0
# 7   13 187-1-127-reg7-A--Spectrum--037--Spec.Data ...           0.0
# 8   14 187-1-127-reg7-B--Spectrum--040--Spec.Data ...           0.0
# 9   15 187-1-127-reg7-C--Spectrum--043--Spec.Data ...           0.0
# 10  16 187-1-127-reg8-A--Spectrum--046--Spec.Data ...           0.0
# 11  17 187-1-127-reg8-B--Spectrum--048--Spec.Data ...           0.0
# 12  20 187-1-128-A_withmelt--Spectrum--060--Spec.D...           0.0
# 13  21 187-1-128-B--Spectrum--063--Spec.Data 1_CRR...           1.0
# 14     22 187-1-128-A--Spectrum--064--Spec.Data 1.txt           0.0
# 15     23 187-1-128-C--Spectrum--067--Spec.Data 1.txt           0.0
# 16  24 187-1-128-D--Spectrum--070--Spec.Data 1_CRR...           1.0
# 17     26 187-1-129-A--Spectrum--076--Spec.Data 1.txt           0.0
# 18  28 187-1-130-A--Spectrum--087--Spec.Data 1_CRR...           1.0
# 19     30 187-1-130-B--Spectrum--094--Spec.Data 1.txt           0.0
# 20  31 187-1-130-C--Spectrum--100--Spec.Data 1_CRR...           1.0
# 21  32 187-1-130-D_hasmelt--Spectrum--105--Spec.Da...           0.0
#
#     approx_split    Diad1_pos    Diad2_pos      HB1_pos      HB2_pos  \
# 0     103.805261  1284.209913  1388.015173          NaN          NaN
# 1     103.953750  1283.995428  1387.949178          NaN          NaN
# 2     103.673270  1284.517891  1388.191161          NaN          NaN
# 3     103.849258  1284.143917  1387.993175          NaN  1409.458178
# 4     103.645772  1284.743376  1388.389147          NaN          NaN
# 5     103.689769  1284.726877  1388.416645          NaN          NaN
# 6     103.739265  1284.336404  1388.075669          NaN          NaN
# 7     103.689769  1284.396900  1388.086668          NaN          NaN
# 8     103.623773  1284.567388  1388.191161          NaN          NaN
# 9     103.684269  1284.429897  1388.114167          NaN          NaN
# 10    103.915253  1284.110920  1388.026173          NaN          NaN
# 11    103.865756  1284.149417  1388.015173          NaN          NaN
# 12    103.260799  1285.452826  1388.713625  1265.170241  1410.140130
# 13    103.337793  1285.309836  1388.647629          NaN          NaN
# 14    103.420287  1285.205343  1388.625631          NaN          NaN
# 15    103.425787  1285.183345  1388.609132          NaN          NaN
# 16    103.508281  1285.012857  1388.521138          NaN          NaN
# 17    104.173735  1283.549959  1387.723694  1263.454360  1409.188697
# 18    103.469784  1285.073353  1388.543137          NaN          NaN
# 19    104.448716  1283.027495  1387.476211          NaN          NaN
# 20    103.282797  1285.738806  1389.021603          NaN          NaN
# 21    103.656771  1284.600386  1388.257157          NaN  1409.678163
#
#         C13_pos  Diad1_abs_prom  Diad2_abs_prom  ...  HB2_height  C13_height  \
# 0           NaN      249.248563      526.097713  ...         NaN         NaN
# 1           NaN      189.503919      384.475653  ...         NaN         NaN
# 2           NaN      163.698117      329.624764  ...         NaN         NaN
# 3           NaN      414.190591      877.488809  ...  718.768661         NaN
# 4           NaN      215.082591      414.599524  ...         NaN         NaN
# 5           NaN      106.665328      206.134641  ...         NaN         NaN
# 6           NaN      244.723467      523.136707  ...         NaN         NaN
# 7           NaN      235.002165      490.074967  ...         NaN         NaN
# 8           NaN      230.591663      449.190443  ...         NaN         NaN
# 9           NaN      200.849584      398.410207  ...         NaN         NaN
# 10          NaN      191.006502      417.225015  ...         NaN         NaN
# 11          NaN       55.595894      124.046143  ...         NaN         NaN
# 12  1370.432900      898.602935     1539.089729  ...  856.417561  730.671676
# 13          NaN      168.508167      308.022551  ...         NaN         NaN
# 14          NaN       32.274357       52.229636  ...         NaN         NaN
# 15          NaN      211.401384      384.292122  ...         NaN         NaN
# 16          NaN       46.532348       90.877856  ...         NaN         NaN
# 17  1369.943434      760.139648     1661.991235  ...  759.290350  714.005896
# 18          NaN       65.709162      118.951313  ...         NaN         NaN
# 19          NaN      320.204143      654.300852  ...         NaN         NaN
# 20          NaN       29.360485       55.014157  ...         NaN         NaN
# 21          NaN      427.475568      830.778125  ...  725.880637         NaN
#
#     Diad1_height  HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  \
# 0     914.548551         NaN        665.299988        664.899994
# 1     853.603925         NaN        664.100006        663.750000
# 2     825.498105         NaN        661.799988        661.500000
# 3    1080.390603         NaN        666.200012        666.100006
# 4     878.582591         NaN        663.500000        663.100006
# 5     768.565322         NaN        661.899994        661.600006
# 6     907.223467         NaN        662.500000        662.299988
# 7     899.402159         NaN        664.399994        663.949997
# 8     895.991657         NaN        665.399994        665.000000
# 9     868.149602         NaN        667.300018        665.750015
# 10    858.806520         NaN        667.800018        667.399994
# 11    728.195900         NaN        672.600006        671.000000
# 12   1603.302916  798.864959        704.699982        701.949997
# 13    834.808185         NaN        666.300018        665.750015
# 14    690.574345         NaN        658.299988        657.899994
# 15    876.201403         NaN        664.800018        664.150009
# 16    710.132354         NaN        663.600006        663.300018
# 17   1433.239654  718.867832        673.100006        673.150009
# 18    781.609186         NaN        715.900024        706.900009
# 19    999.704143         NaN        679.500000        679.150009
# 20    697.960491         NaN        668.600006        667.600006
# 21   1100.175581         NaN        672.700012        673.600006
#
#     C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  \
# 0                      NaN                    NaN                        NaN
# 1                      NaN                    NaN                        NaN
# 2                      NaN                    NaN                        NaN
# 3                      NaN               1.005846                        NaN
# 4                      NaN                    NaN                        NaN
# 5                      NaN                    NaN                        NaN
# 6                      NaN                    NaN                        NaN
# 7                      NaN                    NaN                        NaN
# 8                      NaN                    NaN                        NaN
# 9                      NaN                    NaN                        NaN
# 10                     NaN                    NaN                        NaN
# 11                     NaN                    NaN                        NaN
# 12                5.957330               0.997867                   43.46971
# 13                     NaN                    NaN                        NaN
# 14                     NaN                    NaN                        NaN
# 15                     NaN                    NaN                        NaN
# 16                     NaN                    NaN                        NaN
# 17                2.624252               1.013107                   29.63408
# 18                     NaN                    NaN                        NaN
# 19                     NaN                    NaN                        NaN
# 20                     NaN                    NaN                        NaN
# 21                     NaN               1.000000                        NaN
#
#     HB2_prom/std_betweendiads
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                   28.495212
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                  73.176290
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                  54.596994
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                  37.796560
#
# [22 rows x 40 columns]
