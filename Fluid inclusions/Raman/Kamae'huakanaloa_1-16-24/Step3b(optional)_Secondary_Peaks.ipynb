# %% [markdown]
# # 3b. Fitting carbonate and SO$_2$ peaks
# - This notebook shows how to fit secondary peaks, such as carbonate and S-rich phases in vapour bubbles and fluid inclusions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
from tqdm import tqdm
pf.__version__
# Out:
# '0.0.90'

# %%
# Here, we are loading in the settings files from Step1. If all you want to do is find secondary phases, paste that code here
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()

# %%
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'CRR', 'secphase']
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
File_df=pd.DataFrame(data={'filename': Diad_Files})
# Out:
# ['04 187-1-110-A--Spectrum--009--Spec.Data 1.txt', '05 187-1-110-A--Spectrum--010--Spec.Data 1.txt', '06 187-1-110-A--Spectrum--011--Spec.Data 1.txt', '08 187-1-110-B--Spectrum--014--Spec.Data 1.txt', '09 187-1-110-B--Spectrum--015--Spec.Data 1.txt', '10 187-1-110-B--Spectrum--016--Spec.Data 1.txt', '12 187-1-110-C--Spectrum--020--Spec.Data 1.txt', '13 187-1-110-C--Spectrum--021--Spec.Data 1.txt', '14 187-1-110-C--Spectrum--022--Spec.Data 1.txt', '17 187-1-111-reg1-A--Spectrum--031--Spec.Data 1.txt', '18 187-1-111-reg1-A--Spectrum--032--Spec.Data 1.txt', '20 187-1-111-reg1-A--Spectrum--034--Spec.Data 1.txt', '22 187-1-111-reg1-A--Spectrum--036--Spec.Data 1.txt', '23 187-1-111-reg1-B--Spectrum--038--Spec.Data 1.txt', '24 187-1-111-reg1-B--Spectrum--039--Spec.Data 1.txt', '25 187-1-111-reg1-B--Spectrum--040--Spec.Data 1.txt', '26 187-1-111-reg1-C--Spectrum--043--Spec.Data 1.txt', '27 187-1-111-reg1-C--Spectrum--044--Spec.Data 1.txt', '28 187-1-111-reg1-C--Spectrum--045--Spec.Data 1.txt', '29 187-1-111-reg2-A--Spectrum--047--Spec.Data 1.txt', '30 187-1-111-reg2-A--Spectrum--048--Spec.Data 1.txt', '31 187-1-111-reg2-A--Spectrum--049--Spec.Data 1.txt', '33 187-1-111-reg2-B--Spectrum--052--Spec.Data 1.txt', '34 187-1-111-reg2-B--Spectrum--053--Spec.Data 1.txt', '35 187-1-111-reg2-B--Spectrum--054--Spec.Data 1.txt', '38 187-1-111-reg3-A--Spectrum--060--Spec.Data 1.txt', '39 187-1-111-reg3-A--Spectrum--061--Spec.Data 1.txt', '41 187-1-111-reg3-B--Spectrum--064--Spec.Data 1.txt', '42 187-1-111-reg3-B--Spectrum--065--Spec.Data 1.txt', '43 187-1-111-reg3-B--Spectrum--066--Spec.Data 1.txt', '45 187-1-111-reg3-C--Spectrum--070--Spec.Data 1.txt', '46 187-1-111-reg3-C--Spectrum--071--Spec.Data 1.txt', '47 187-1-111-reg3-C--Spectrum--072--Spec.Data 1.txt', '49 187-1-111-reg4-A--Spectrum--078--Spec.Data 1.txt', '50 187-1-111-reg4-A--Spectrum--079--Spec.Data 1.txt']

# %% [markdown]
# ## Plot spectra in a given region of space to examine secondary peaks or not

# %% [markdown]
# ### You'll need to tweak the peak parameters to find them
# - height = minimum height a peak should have to be identified
# - threshold = required vertical distance between a peak and its neighbours
# - distance = required horizontal distance bewteen neighbouring peaks.
# - prominence = required prominence of peaks
# - width = width of peaks

# %% [markdown]
# ## Example 1 - Using Scipy find peaks to look for SO2

# %%
prominence_SO2=20
height_SO2=20
width_SO2=1
threshold_SO2=1

SO2_peaks_scipy, x_data_scipy, y_data_scipy, fig_scipy=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
filetype=spectra_filetype, find_peaks_filter=True,  
xlim_peaks=[1145, 1155], xlim_plot=[1130, 1180], yscale=0.3,
prominence=prominence_SO2, height=height_SO2, width=width_SO2, threshold=threshold_SO2)

SO2_peaks=SO2_peaks_scipy

# %%
SO2_peaks
# Out:
#     pos  height  prom                                         file_names
# 0   NaN     NaN   NaN     04 187-1-110-A--Spectrum--009--Spec.Data 1.txt
# 1   NaN     NaN   NaN     05 187-1-110-A--Spectrum--010--Spec.Data 1.txt
# 2   NaN     NaN   NaN     06 187-1-110-A--Spectrum--011--Spec.Data 1.txt
# 3   NaN     NaN   NaN     08 187-1-110-B--Spectrum--014--Spec.Data 1.txt
# 4   NaN     NaN   NaN     09 187-1-110-B--Spectrum--015--Spec.Data 1.txt
# 5   NaN     NaN   NaN     10 187-1-110-B--Spectrum--016--Spec.Data 1.txt
# 6   NaN     NaN   NaN     12 187-1-110-C--Spectrum--020--Spec.Data 1.txt
# 7   NaN     NaN   NaN     13 187-1-110-C--Spectrum--021--Spec.Data 1.txt
# 8   NaN     NaN   NaN     14 187-1-110-C--Spectrum--022--Spec.Data 1.txt
# 9   NaN     NaN   NaN  17 187-1-111-reg1-A--Spectrum--031--Spec.Data ...
# 10  NaN     NaN   NaN  18 187-1-111-reg1-A--Spectrum--032--Spec.Data ...
# 11  NaN     NaN   NaN  20 187-1-111-reg1-A--Spectrum--034--Spec.Data ...
# 12  NaN     NaN   NaN  22 187-1-111-reg1-A--Spectrum--036--Spec.Data ...
# 13  NaN     NaN   NaN  23 187-1-111-reg1-B--Spectrum--038--Spec.Data ...
# 14  NaN     NaN   NaN  24 187-1-111-reg1-B--Spectrum--039--Spec.Data ...
# 15  NaN     NaN   NaN  25 187-1-111-reg1-B--Spectrum--040--Spec.Data ...
# 16  NaN     NaN   NaN  26 187-1-111-reg1-C--Spectrum--043--Spec.Data ...
# 17  NaN     NaN   NaN  27 187-1-111-reg1-C--Spectrum--044--Spec.Data ...
# 18  NaN     NaN   NaN  28 187-1-111-reg1-C--Spectrum--045--Spec.Data ...
# 19  NaN     NaN   NaN  29 187-1-111-reg2-A--Spectrum--047--Spec.Data ...
# 20  NaN     NaN   NaN  30 187-1-111-reg2-A--Spectrum--048--Spec.Data ...
# 21  NaN     NaN   NaN  31 187-1-111-reg2-A--Spectrum--049--Spec.Data ...
# 22  NaN     NaN   NaN  33 187-1-111-reg2-B--Spectrum--052--Spec.Data ...
# 23  NaN     NaN   NaN  34 187-1-111-reg2-B--Spectrum--053--Spec.Data ...
# 24  NaN     NaN   NaN  35 187-1-111-reg2-B--Spectrum--054--Spec.Data ...
# 25  NaN     NaN   NaN  38 187-1-111-reg3-A--Spectrum--060--Spec.Data ...
# 26  NaN     NaN   NaN  39 187-1-111-reg3-A--Spectrum--061--Spec.Data ...
# 27  NaN     NaN   NaN  41 187-1-111-reg3-B--Spectrum--064--Spec.Data ...
# 28  NaN     NaN   NaN  42 187-1-111-reg3-B--Spectrum--065--Spec.Data ...
# 29  NaN     NaN   NaN  43 187-1-111-reg3-B--Spectrum--066--Spec.Data ...
# 30  NaN     NaN   NaN  45 187-1-111-reg3-C--Spectrum--070--Spec.Data ...
# 31  NaN     NaN   NaN  46 187-1-111-reg3-C--Spectrum--071--Spec.Data ...
# 32  NaN     NaN   NaN  47 187-1-111-reg3-C--Spectrum--072--Spec.Data ...
# 33  NaN     NaN   NaN  49 187-1-111-reg4-A--Spectrum--078--Spec.Data ...
# 34  NaN     NaN   NaN  50 187-1-111-reg4-A--Spectrum--079--Spec.Data ...

# %% [markdown]
# ### Now filter out ones with no peaks, or low prominence before we loop through them

# %%
# Remove the ones where it didnt find SO2
SO2_notNa=np.isnan(SO2_peaks['pos'])
# Remove ones with a prominence less than this. 
prom_filt=10
SO2_filter=((SO2_peaks['prom']>10))&(~SO2_notNa)
print('Number kept with this filter:')
print(sum(SO2_filter))
print('Number discarded:')
print(sum(~SO2_filter&(~SO2_notNa)))
filenames_SO2=list(File_df['filename'].loc[SO2_filter])
print('filenames with SO2:')
print(filenames_SO2)
# Out:
# Number kept with this filter:
# 0
# Number discarded:
# 0
# filenames with SO2:
# []

# %% [markdown]
# ### Choose a filename to test peak fits

# %%
if sum(SO2_filter)>0:
    filename=filenames_SO2[0]

# %% [markdown]
# ### Set up configuration file for S peak fitting
# - Here, we are using a spline to quantify the area down to the 92% of the peak height (int_cut_of=0.08), there are differen options you can use for this

# %%
if sum(SO2_filter)>0:
    SO2_peak_config=pf.generic_peak_config(name='SO2', lower_bck=[1110, 1130],
    upper_bck=[1190, 1200], cent=1150, x_range_bck=20, N_peaks=1,   model_name='PseudoVoigtModel', int_cut_off=0.05)
    print(SO2_peak_config)

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
    path=spectra_path, filename=filename, filetype=spectra_filetype, 
     plot_figure=True)

# %% [markdown]
# ## Now lets loop through files

# %%
files_to_fit=filenames_SO2
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_SO2 = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_SO2 = pd.concat([df_Merge_SO2, SO2_peak_fit], axis=0)
# Out:
# 0it [00:00, ?it/s]

# %%
df_Merge_SO2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Plot peak areas and peak heights

# %%
if sum(SO2_filter)>0:
    plt.plot(df_Merge_SO2['Peak_Area_SO2'], 
            df_Merge_SO2['Peak_Height_SO2'], 'ok')
    plt.xlabel('Peak Area SO2')
    plt.ylabel('Peak Height SO2')
    # plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ### Save this to excel

# %%
if sum(SO2_filter)>0:
    df_Merge_SO2.to_excel('SO2_Peak_fits.xlsx', index=False)

# %% [markdown]
# ## Now do the same to ID any carbonate peaks

# %% [markdown]
# ### Using scipy find peaks methods
# - This method doesnt always work perfectly for broader carbonate peaks

# %%
prominence_carb=10
height_carb=10
width_carb=1
threshold_carb=1

Carb_peaks_scipy, x_data_scipy, y_data_scipy, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, find_peaks_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1075, 1120], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_scipy

# %%
# prominence_carb=30
# height_carb=10
# width_carb=1
# threshold_carb=1

# Carb_peaks_prom, x_data_prom, y_data_prom, fig=pf.plot_secondary_peaks(
# Diad_Files=Diad_Files, path=spectra_path, 
#  filetype=spectra_filetype, prominence_filter=True,  
# xlim_plot=[1050, 1150], xlim_peaks=[1070, 1100], yscale=0.3,
# prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)

# %% [markdown]
# ## Find ones with certain peak parameters to include

# %%
Carb_noNa=np.isnan(Carb_peaks['pos'])
prom_filter=10
Carb_filter=((Carb_peaks['prom']>prom_filter))&(~Carb_noNa)
print('Number kept with this filter:')
print(sum(Carb_filter))
print('Number discarded:')
print(sum(~Carb_filter&(~Carb_noNa)))
filenames_Carb=list(File_df['filename'].loc[Carb_filter])
print('filenames with carb:')
print(filenames_Carb)
# Out:
# Number kept with this filter:
# 11
# Number discarded:
# 16
# filenames with carb:
# ['08 187-1-110-B--Spectrum--014--Spec.Data 1.txt', '09 187-1-110-B--Spectrum--015--Spec.Data 1.txt', '10 187-1-110-B--Spectrum--016--Spec.Data 1.txt', '12 187-1-110-C--Spectrum--020--Spec.Data 1.txt', '13 187-1-110-C--Spectrum--021--Spec.Data 1.txt', '14 187-1-110-C--Spectrum--022--Spec.Data 1.txt', '23 187-1-111-reg1-B--Spectrum--038--Spec.Data 1.txt', '41 187-1-111-reg3-B--Spectrum--064--Spec.Data 1.txt', '42 187-1-111-reg3-B--Spectrum--065--Spec.Data 1.txt', '43 187-1-111-reg3-B--Spectrum--066--Spec.Data 1.txt', '46 187-1-111-reg3-C--Spectrum--071--Spec.Data 1.txt']

# %% [markdown]
# ### Fit one to tweak parameters

# %%
if sum(Carb_filter)>0:
    filename_carb=filenames_Carb[0]

    Carb_peak_config=pf.generic_peak_config(name='Carb', lower_bck=[1050, 1070],
    upper_bck=[1120, 1150], cent=1090, x_range_bck=50, N_poly_carb_bck=2, model_name='Spline')
    print(Carb_peak_config)

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
    path=spectra_path, filename=filename_carb, filetype=spectra_filetype,
     plot_figure=True)
# Out:
# generic_peak_config(name='Carb', lower_bck=[1050, 1070], upper_bck=[1120, 1150], model_name='Spline', x_range_bck=50, N_poly_carb_bck=2, amplitude=1000, cent=1090, outlier_sigma=12, distance=10, prominence=5, width=6, threshold=0.1, height=100, exclude_range=None, return_other_params=False, N_peaks=1, int_cut_off=0.05)

# %% [markdown]
# ### Loop over all carbonate files

# %%
files_to_fit=filenames_Carb
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_Carb = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_Carb = pd.concat([df_Merge_Carb, Carb_peak_fit], axis=0)
# Out:
# 100%|██████████| 11/11 [00:02<00:00,  4.83it/s]

# %%
if sum(Carb_filter)>0:
    plt.plot(df_Merge_Carb['Peak_Area_Carb'], 
        df_Merge_Carb['Peak_Height_Carb'], 'ok')
    plt.xlabel('Peak Area Carb')
    plt.ylabel('Peak Height Carb')
# plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ## Save to excel

# %%
if sum(Carb_filter)>0:
    df_Merge_Carb=df_Merge_Carb[ df_Merge_Carb['Peak_Area_Carb']>10]
    df_Merge_Carb['filename'] = df_Merge_Carb['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_Carb.to_excel('Carb_Peak_fits.xlsx', index=False )

# %%
df_Merge_Carb
# Out:
#                                  filename  Peak_Cent_Carb  Peak_Area_Carb  \
# 0       08 187-1-110-B--Spectrum--014.txt     1097.127641      244.820531
# 0       09 187-1-110-B--Spectrum--015.txt     1097.127641      268.731685
# 0       10 187-1-110-B--Spectrum--016.txt     1097.127641      222.592519
# 0       12 187-1-110-C--Spectrum--020.txt     1093.321700      165.763866
# 0       13 187-1-110-C--Spectrum--021.txt     1097.177068      233.893453
# 0       14 187-1-110-C--Spectrum--022.txt     1097.078213      212.207284
# 0  23 187-1-111-reg1-B--Spectrum--038.txt     1097.177068       78.794872
# 0  41 187-1-111-reg3-B--Spectrum--064.txt     1097.127641       87.036904
# 0  42 187-1-111-reg3-B--Spectrum--065.txt     1097.127641       35.385421
# 0  43 187-1-111-reg3-B--Spectrum--066.txt     1097.127641       41.653063
#
#    Peak_Height_Carb Model_name
# 0         24.101999     Spline
# 0         21.773877     Spline
# 0         22.663942     Spline
# 0         16.950808     Spline
# 0         23.638150     Spline
# 0         21.078477     Spline
# 0         12.710846     Spline
# 0         11.582550     Spline
# 0          9.980456     Spline
# 0         11.036389     Spline
