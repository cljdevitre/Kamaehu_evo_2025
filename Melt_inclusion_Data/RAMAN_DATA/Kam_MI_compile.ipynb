# %% [markdown]
# # This notebook just compiles the Raman data for the Melt inclusion bearing crystals at KAM

# %%
import pandas as pd
import os

# %%
if os.name=='posix':
    slash='/'
else:
    slash='\\'

MasterFolder=os.getcwd()

#Folder to save full datasets

compilation_folder=MasterFolder +slash+'Compiled_data'
if not os.path.exists(compilation_folder):
    os.mkdir(compilation_folder)

# %%
## This function compiles raman sessions found in the master folder (even in subdirectories of the specified folder)
def compile_Raman_sessions(*, path=None, sheet_name='Sheet1', keyword='Raman_session'):
    df = pd.DataFrame()

    for root, dirs, files in os.walk(path):
        for file in files:
            if keyword in file and file.endswith('.xlsx'):
                file_path = os.path.join(root, file)
                sheets = pd.read_excel(file_path, sheet_name)
                df = pd.concat([df, sheets], axis=0, ignore_index=True)
                unnamed_columns = [col for col in df.columns if 'Unnamed' in col]
                df = df.drop(columns=unnamed_columns)

    return df

# %%
kamaehu = compile_Raman_sessions(path=MasterFolder,sheet_name='Sheet1',keyword='Raman')

kamaehu = kamaehu[(~kamaehu['filename'].str.contains('test'))&(kamaehu['Density g/cm3']>0)&~(kamaehu['accumulations']<3)]

kamaehu['date_object']=pd.to_datetime(kamaehu['date'])

kamaehu=kamaehu.sort_values(by=['date_object', 'filename'])

kamaehu.to_clipboard(excel=True, index=False)

kamaehu.to_excel(compilation_folder+'/'+"Kam_MI.xlsx")

kamaehu
# Out:
#                    filename  Density g/cm3  σ Density g/cm3  \
# 7             187-1-201-FI2       0.583108         0.006781
# 8             187-1-201-FI3       0.544243         0.007259
# 9             187-1-201-FI4       0.600401         0.005654
# 10            187-1-201-FI5       0.582904         0.005578
# 4        187-1-201-MI1-rep1       0.093134         0.012689
# ..                      ...            ...              ...
# 247  187-9-220-MIB-edgecarb       0.076298         0.004055
# 248      187-9-220-MIB-rep2       0.080406         0.004074
# 249      187-9-220-MIB-rep3       0.079046         0.004049
# 273           FG04-A1-4-end       0.692735         0.003381
# 237         FG04-A1-4-start       0.685109         0.005579
#
#      σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 7                             0.006355                           0.002367
# 8                             0.006864                           0.002361
# 9                             0.005133                           0.002371
# 10                            0.005050                           0.002367
# 4                             0.012106                           0.003802
# ..                                 ...                                ...
# 247                           0.001403                           0.003804
# 248                           0.001464                           0.003802
# 249                           0.001391                           0.003803
# 273                           0.002391                           0.002391
# 237                           0.005042                           0.002389
#
#      Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 7             104.110746               0.013161                  0.000823
# 8             104.029477               0.014490                  0.000821
# 9             104.146410               0.010540                  0.000821
# 10            104.110325               0.010461                  0.000819
# 4             102.985300               0.030551                  0.000821
# ..                   ...                    ...                       ...
# 247           102.942811               0.003542                  0.002082
# 248           102.953177               0.003694                  0.002074
# 249           102.949747               0.003511                  0.002071
# 273           104.331702               0.004687                  0.002329
# 237           104.316721               0.009923                  0.002246
#
#      Corrected_Splitting_σ_peak_fit  power (mW)  ...  lower_values  \
# 7                          0.013162       6.019  ...      0.997940
# 8                          0.014496       6.018  ...      0.997940
# 9                          0.010530       6.018  ...      0.997939
# 10                         0.010450       6.012  ...      0.997939
# 4                          0.030603      11.953  ...      0.997942
# ..                              ...         ...  ...           ...
# 247                        0.002871      10.034  ...      0.997877
# 248                        0.003063      10.025  ...      0.997876
# 249                        0.002841      10.041  ...      0.997875
# 273                        0.004076       6.019  ...      0.997845
# 237                        0.009686       6.041  ...      0.997888
#
#      upper_values  Peak_Cent_SO2 Peak_Area_SO2 Peak_Height_SO2  Model_name_x  \
# 7        0.997956            NaN           NaN             NaN           NaN
# 8        0.997955            NaN           NaN             NaN           NaN
# 9        0.997955            NaN           NaN             NaN           NaN
# 10       0.997954            NaN           NaN             NaN           NaN
# 4        0.997958            NaN           NaN             NaN           NaN
# ..            ...            ...           ...             ...           ...
# 247      0.997918            NaN           NaN             NaN           NaN
# 248      0.997916            NaN           NaN             NaN           NaN
# 249      0.997916            NaN           NaN             NaN           NaN
# 273      0.997889            NaN           NaN             NaN           NaN
# 237      0.997931            NaN           NaN             NaN           NaN
#
#      Model_name_y  SO2_Diad_Ratio  SO2_mol_ratio  date_object
# 7             NaN             NaN            NaN   2024-04-25
# 8             NaN             NaN            NaN   2024-04-25
# 9             NaN             NaN            NaN   2024-04-25
# 10            NaN             NaN            NaN   2024-04-25
# 4             NaN             NaN            NaN   2024-04-25
# ..            ...             ...            ...          ...
# 247           NaN             NaN            NaN   2024-08-30
# 248           NaN             NaN            NaN   2024-08-30
# 249           NaN             NaN            NaN   2024-08-30
# 273           NaN             NaN            NaN   2024-08-30
# 237           NaN             NaN            NaN   2024-08-30
#
# [252 rows x 99 columns]
