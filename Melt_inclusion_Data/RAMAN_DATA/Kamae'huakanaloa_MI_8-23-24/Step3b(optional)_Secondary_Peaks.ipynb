# %% [markdown]
# # 3b. Fitting carbonate and SO$_2$ peaks
# - This notebook shows how to fit secondary peaks, such as carbonate and S-rich phases in vapour bubbles and fluid inclusions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
from tqdm import tqdm
pf.__version__
# Out:
# '1.0.1'

# %%
# Here, we are loading in the settings files from Step1. If all you want to do is find secondary phases, paste that code here
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()

# %%
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'diad','Spec', 'CRR', 'secphase','Series','unquant']
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
File_df=pd.DataFrame(data={'filename': Diad_Files})
# Out:
# ['03 FG04-A1-4-start.txt', '05 187-9-201-MIA-rep1.txt', '06 187-9-201-MIA-rep2.txt', '07 187-9-201-MIA-rep3.txt', '08 187-9-202-MIC-rep1.txt', '09 187-9-202-MIC-rep2.txt', '10 187-9-202-MIC-rep3.txt', '11 187-9-202-MIB-rep1.txt', '12 187-9-202-MIB-rep2.txt', '13 187-9-202-MIB-rep3.txt', '14 187-9-202-MID-rep1.txt', '15 187-9-202-MID-rep2.txt', '16 187-9-202-MID-rep3.txt', '18 187-9-213-MIA-rep1.txt', '19 187-9-213-MIA-rep2.txt', '20 187-9-213-MIA-rep3.txt', '21 187-9-213-FIB.txt', '22 187-9-213-FIA.txt', '23 187-9-215-MIA-rep1.txt', '24 187-9-215-MIA-rep2.txt', '25 187-9-215-MIA-rep3.txt', '26 187-9-215-FIA.txt', '27 187-9-215-FIB.txt', '28 187-9-215-FIC.txt', '29 187-9-215-FID.txt', '30 187-9-216-MIA-rep1.txt', '31 187-9-216-MIA-rep2.txt', '32 187-9-216-MIA-rep3.txt', '34 187-9-217-MIA-rep1.txt', '35 187-9-217-MIA-rep2.txt', '36 187-9-217-MIA-rep3.txt', '37 187-9-218-MIA-rep1.txt', '38 187-9-218-MIA-rep2.txt', '39 187-9-218-MIA-rep3.txt', '41 187-9-219-MIA-rep1.txt', '42 187-9-219-MIA-rep2.txt', '43 187-9-219-MIA-rep3.txt', '45 187-9-220-FIA.txt', '46 187-9-220-FIB.txt', '47 187-9-220-FIC.txt', '48 187-9-220-MIA.txt', '49 187-9-220-FIE.txt', '50 187-9-220-FID.txt', '51 FG04-A1-4-end.txt']

# %% [markdown]
# ## Plot spectra in a given region of space to examine secondary peaks or not

# %% [markdown]
# ### You'll need to tweak the peak parameters to find them
# - height = minimum height a peak should have to be identified
# - threshold = required vertical distance between a peak and its neighbours
# - distance = required horizontal distance bewteen neighbouring peaks.
# - prominence = required prominence of peaks
# - width = width of peaks

# %% [markdown]
# ## Example 1 - Using Scipy find peaks to look for SO2

# %%
prominence_SO2=20
height_SO2=20
width_SO2=2
threshold_SO2=1

SO2_peaks_scipy, x_data_scipy, y_data_scipy, fig_scipy=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
filetype=spectra_filetype, find_peaks_filter=True,  
xlim_peaks=[1148, 1152], xlim_plot=[1130, 1180], yscale=0.3,
prominence=prominence_SO2, height=height_SO2, width=width_SO2, threshold=threshold_SO2)

SO2_peaks=SO2_peaks_scipy

# %%
SO2_peaks
# Out:
#     pos  height  prom                 file_names
# 0   NaN     NaN   NaN     03 FG04-A1-4-start.txt
# 1   NaN     NaN   NaN  05 187-9-201-MIA-rep1.txt
# 2   NaN     NaN   NaN  06 187-9-201-MIA-rep2.txt
# 3   NaN     NaN   NaN  07 187-9-201-MIA-rep3.txt
# 4   NaN     NaN   NaN  08 187-9-202-MIC-rep1.txt
# 5   NaN     NaN   NaN  09 187-9-202-MIC-rep2.txt
# 6   NaN     NaN   NaN  10 187-9-202-MIC-rep3.txt
# 7   NaN     NaN   NaN  11 187-9-202-MIB-rep1.txt
# 8   NaN     NaN   NaN  12 187-9-202-MIB-rep2.txt
# 9   NaN     NaN   NaN  13 187-9-202-MIB-rep3.txt
# 10  NaN     NaN   NaN  14 187-9-202-MID-rep1.txt
# 11  NaN     NaN   NaN  15 187-9-202-MID-rep2.txt
# 12  NaN     NaN   NaN  16 187-9-202-MID-rep3.txt
# 13  NaN     NaN   NaN  18 187-9-213-MIA-rep1.txt
# 14  NaN     NaN   NaN  19 187-9-213-MIA-rep2.txt
# 15  NaN     NaN   NaN  20 187-9-213-MIA-rep3.txt
# 16  NaN     NaN   NaN       21 187-9-213-FIB.txt
# 17  NaN     NaN   NaN       22 187-9-213-FIA.txt
# 18  NaN     NaN   NaN  23 187-9-215-MIA-rep1.txt
# 19  NaN     NaN   NaN  24 187-9-215-MIA-rep2.txt
# 20  NaN     NaN   NaN  25 187-9-215-MIA-rep3.txt
# 21  NaN     NaN   NaN       26 187-9-215-FIA.txt
# 22  NaN     NaN   NaN       27 187-9-215-FIB.txt
# 23  NaN     NaN   NaN       28 187-9-215-FIC.txt
# 24  NaN     NaN   NaN       29 187-9-215-FID.txt
# 25  NaN     NaN   NaN  30 187-9-216-MIA-rep1.txt
# 26  NaN     NaN   NaN  31 187-9-216-MIA-rep2.txt
# 27  NaN     NaN   NaN  32 187-9-216-MIA-rep3.txt
# 28  NaN     NaN   NaN  34 187-9-217-MIA-rep1.txt
# 29  NaN     NaN   NaN  35 187-9-217-MIA-rep2.txt
# 30  NaN     NaN   NaN  36 187-9-217-MIA-rep3.txt
# 31  NaN     NaN   NaN  37 187-9-218-MIA-rep1.txt
# 32  NaN     NaN   NaN  38 187-9-218-MIA-rep2.txt
# 33  NaN     NaN   NaN  39 187-9-218-MIA-rep3.txt
# 34  NaN     NaN   NaN  41 187-9-219-MIA-rep1.txt
# 35  NaN     NaN   NaN  42 187-9-219-MIA-rep2.txt
# 36  NaN     NaN   NaN  43 187-9-219-MIA-rep3.txt
# 37  NaN     NaN   NaN       45 187-9-220-FIA.txt
# 38  NaN     NaN   NaN       46 187-9-220-FIB.txt
# 39  NaN     NaN   NaN       47 187-9-220-FIC.txt
# 40  NaN     NaN   NaN       48 187-9-220-MIA.txt
# 41  NaN     NaN   NaN       49 187-9-220-FIE.txt
# 42  NaN     NaN   NaN       50 187-9-220-FID.txt
# 43  NaN     NaN   NaN       51 FG04-A1-4-end.txt

# %% [markdown]
# ### Now filter out ones with no peaks, or low prominence before we loop through them

# %%
# Remove the ones where it didnt find SO2
SO2_notNa=np.isnan(SO2_peaks['pos'])
# Remove ones with a prominence less than this. 
prom_filt=35
SO2_filter=((SO2_peaks['prom']>prom_filt))&(~SO2_notNa)
print('Number kept with this filter:')
print(sum(SO2_filter))
print('Number discarded:')
print(sum(~SO2_filter&(~SO2_notNa)))
filenames_SO2=list(File_df['filename'].loc[SO2_filter])
print('filenames with SO2:')
print(filenames_SO2)
# Out:
# Number kept with this filter:
# 0
# Number discarded:
# 0
# filenames with SO2:
# []

# %% [markdown]
# ### Choose a filename to test peak fits

# %%
if sum(SO2_filter)>0:
    filename=filenames_SO2[0]

# %% [markdown]
# ### Set up configuration file for S peak fitting
# - Here, we are using a spline to quantify the area down to the 92% of the peak height (int_cut_of=0.08), there are differen options you can use for this

# %%
if sum(SO2_filter)>0:
    SO2_peak_config=pf.generic_peak_config(name='SO2', lower_bck=[1110, 1130],
    upper_bck=[1190, 1200], cent=1150, x_range_bck=20, N_peaks=1,   model_name='Spline', int_cut_off=0.05)
    print(SO2_peak_config)

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
    path=spectra_path, filename=filename, filetype=spectra_filetype, 
     plot_figure=True)

# %% [markdown]
# ## Now lets loop through files

# %%
files_to_fit=filenames_SO2
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_SO2 = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_SO2 = pd.concat([df_Merge_SO2, SO2_peak_fit], axis=0)
# Out:
# 0it [00:00, ?it/s]

# %%
df_Merge_SO2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Plot peak areas and peak heights

# %%
if sum(SO2_filter)>0:
    plt.plot(df_Merge_SO2['Peak_Area_SO2'], 
            df_Merge_SO2['Peak_Height_SO2'], 'ok')
    plt.xlabel('Peak Area SO2')
    plt.ylabel('Peak Height SO2')
    # plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ### Save this to excel

# %%
if sum(SO2_filter)>0:
    df_Merge_SO2['filename'] = df_Merge_SO2['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_SO2.to_excel('SO2_Peak_fits.xlsx', index=False)

# %% [markdown]
# ## Now do the same to ID any carbonate peaks

# %% [markdown]
# ### Using scipy find peaks methods
# - This method doesnt always work perfectly for broader carbonate peaks

# %%
prominence_carb=20
height_carb=10
width_carb=1
threshold_carb=1

Carb_peaks_scipy, x_data_scipy, y_data_scipy, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, find_peaks_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1070, 1100], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_scipy

# %%
prominence_carb=15
height_carb=10
width_carb=1
threshold_carb=1

Carb_peaks_prom, x_data_prom, y_data_prom, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, prominence_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1089, 1110], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_prom

# %% [markdown]
# ## Find ones with certain peak parameters to include

# %%
Carb_noNa=np.isnan(Carb_peaks['pos'])
prom_filter=10
Carb_filter=((Carb_peaks['prom']>prom_filter))&(~Carb_noNa)&(~Carb_peaks['file_names'].str.contains("201-MIA|216-MIA-rep2|215-MIA-rep2"))
print('Number kept with this filter:')
print(sum(Carb_filter))
print('Number discarded:')
print(sum(~Carb_filter&(~Carb_noNa)))
filenames_Carb=list(File_df['filename'].loc[Carb_filter])
print('filenames with carb:')
print(filenames_Carb)
# Out:
# Number kept with this filter:
# 11
# Number discarded:
# 4
# filenames with carb:
# ['03 FG04-A1-4-start.txt', '08 187-9-202-MIC-rep1.txt', '11 187-9-202-MIB-rep1.txt', '12 187-9-202-MIB-rep2.txt', '13 187-9-202-MIB-rep3.txt', '25 187-9-215-MIA-rep3.txt', '30 187-9-216-MIA-rep1.txt', '32 187-9-216-MIA-rep3.txt', '37 187-9-218-MIA-rep1.txt', '41 187-9-219-MIA-rep1.txt', '43 187-9-219-MIA-rep3.txt']

# %% [markdown]
# ### Fit one to tweak parameters

# %%
if sum(Carb_filter)>0:
    filename_carb=filenames_Carb[0]

    Carb_peak_config=pf.generic_peak_config(name='Carb', lower_bck=[1060, 1070],
    upper_bck=[1120, 1150], cent=1090, x_range_bck=50, N_poly_carb_bck=2, model_name='Spline')
    print(Carb_peak_config)

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
    path=spectra_path, filename=filename_carb, filetype=spectra_filetype,
     plot_figure=True)
# Out:
# generic_peak_config(name='Carb', lower_bck=[1060, 1070], upper_bck=[1120, 1150], model_name='Spline', x_range_bck=50, N_poly_carb_bck=2, amplitude=1000, cent=1090, outlier_sigma=12, distance=10, prominence=5, width=6, threshold=0.1, height=100, exclude_range=None, return_other_params=False, N_peaks=1, int_cut_off=0.05)

# %% [markdown]
# ### Loop over all carbonate files

# %%
files_to_fit=filenames_Carb
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_Carb = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_Carb = pd.concat([df_Merge_Carb, Carb_peak_fit], axis=0)
# Out:
# 100%|██████████| 11/11 [00:02<00:00,  4.55it/s]

# %%
if sum(Carb_filter)>0:
    plt.plot(df_Merge_Carb['Peak_Area_Carb'], 
        df_Merge_Carb['Peak_Height_Carb'], 'ok')
    plt.xlabel('Peak Area Carb')
    plt.ylabel('Peak Height Carb')
# plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ## Save to excel

# %%
df_Merge_Carb=df_Merge_Carb[~(df_Merge_Carb['Peak_Area_Carb']<70)]
df_Merge_Carb
# Out:
#                     filename  Peak_Cent_Carb  Peak_Area_Carb  \
# 0     03 FG04-A1-4-start.txt     1091.854015      321.739712
# 0  11 187-9-202-MIB-rep1.txt     1095.363607      779.283652
# 0  12 187-9-202-MIB-rep2.txt     1095.363607      766.947887
# 0  13 187-9-202-MIB-rep3.txt     1095.413038      817.999397
# 0  30 187-9-216-MIA-rep1.txt     1095.511900      153.769957
# 0  32 187-9-216-MIA-rep3.txt     1095.413038      131.222802
# 0  41 187-9-219-MIA-rep1.txt     1095.462469      194.825526
# 0  43 187-9-219-MIA-rep3.txt     1095.462469      295.743692
#
#    Peak_Height_Carb Model_name
# 0         25.420913     Spline
# 0         58.276423     Spline
# 0         56.059011     Spline
# 0         54.264402     Spline
# 0         27.434626     Spline
# 0         19.149525     Spline
# 0         22.989435     Spline
# 0         28.962494     Spline

# %%
if sum(Carb_filter)>0:
    df_Merge_Carb.loc[:,'filename'] = df_Merge_Carb['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_Carb.to_excel('Carb_Peak_fits.xlsx', index=False )

# %%
df_Merge_Carb
# Out:
#                     filename  Peak_Cent_Carb  Peak_Area_Carb  \
# 0     03 FG04-A1-4-start.txt     1091.854015      321.739712
# 0  11 187-9-202-MIB-rep1.txt     1095.363607      779.283652
# 0  12 187-9-202-MIB-rep2.txt     1095.363607      766.947887
# 0  13 187-9-202-MIB-rep3.txt     1095.413038      817.999397
# 0  30 187-9-216-MIA-rep1.txt     1095.511900      153.769957
# 0  32 187-9-216-MIA-rep3.txt     1095.413038      131.222802
# 0  41 187-9-219-MIA-rep1.txt     1095.462469      194.825526
# 0  43 187-9-219-MIA-rep3.txt     1095.462469      295.743692
#
#    Peak_Height_Carb Model_name
# 0         25.420913     Spline
# 0         58.276423     Spline
# 0         56.059011     Spline
# 0         54.264402     Spline
# 0         27.434626     Spline
# 0         19.149525     Spline
# 0         22.989435     Spline
# 0         28.962494     Spline
