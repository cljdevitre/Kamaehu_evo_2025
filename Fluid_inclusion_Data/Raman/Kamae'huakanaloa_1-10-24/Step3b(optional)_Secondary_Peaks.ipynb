# %% [markdown]
# # 3b. Fitting carbonate and SO$_2$ peaks
# - This notebook shows how to fit secondary peaks, such as carbonate and S-rich phases in vapour bubbles and fluid inclusions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
from tqdm import tqdm
pf.__version__
# Out:
# '1.0.2'

# %%
# Here, we are loading in the settings files from Step1. If all you want to do is find secondary phases, paste that code here
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()

# %%
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'diad', 'CRR', 'secphase','Series','unquant']
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
File_df=pd.DataFrame(data={'filename': Diad_Files})
# Out:
# ['06 187-1-102-A--Spectrum--019--Spec.Data 1.txt', '07 187-1-102-A--Spectrum--020--Spec.Data 1.txt', '08 187-1-102-A--Spectrum--021--Spec.Data 1.txt', '10 187-1-102-B--Spectrum--025--Spec.Data 1.txt', '11 187-1-102-B--Spectrum--026--Spec.Data 1.txt', '12 187-1-102-B--Spectrum--027--Spec.Data 1.txt', '14 187-1-102-C--Spectrum--031--Spec.Data 1.txt', '15 187-1-102-C--Spectrum--032--Spec.Data 1.txt', '16 187-1-102-C--Spectrum--033--Spec.Data 1.txt', '18 187-1-102-B--Spectrum--036--Spec.Data 1.txt', '19 187-1-102-B--Spectrum--037--Spec.Data 1.txt', '20 187-1-102-B--Spectrum--038--Spec.Data 1.txt', '22 187-1-103-A--Spectrum--044--Spec.Data 1.txt', '23 187-1-103-A--Spectrum--045--Spec.Data 1.txt', '24 187-1-103-A--Spectrum--046--Spec.Data 1.txt', '26 187-1-103-B--Spectrum--050--Spec.Data 1.txt', '27 187-1-103-B--Spectrum--051--Spec.Data 1.txt', '28 187-1-103-B--Spectrum--052--Spec.Data 1.txt', '30 187-1-103-C--Spectrum--056--Spec.Data 1.txt', '31 187-1-103-C--Spectrum--057--Spec.Data 1.txt', '32 187-1-103-C--Spectrum--058--Spec.Data 1.txt', '34 187-1-104-A--Spectrum--066--Spec.Data 1.txt', '35 187-1-104-A--Spectrum--067--Spec.Data 1.txt', '36 187-1-104-A--Spectrum--068--Spec.Data 1.txt', '39 187-1-105-reg1-A--Spectrum--077--Spec.Data 1.txt', '40 187-1-105-reg1-A--Spectrum--078--Spec.Data 1.txt', '41 187-1-105-reg1-A--Spectrum--079--Spec.Data 1.txt', '43 187-1-105-reg1-B--Spectrum--083--Spec.Data 1.txt', '44 187-1-105-reg1-B--Spectrum--084--Spec.Data 1.txt', '45 187-1-105-reg1-B--Spectrum--085--Spec.Data 1.txt', '46 187-1-105-reg1-C--Spectrum--088--Spec.Data 1.txt', '47 187-1-105-reg1-C--Spectrum--089--Spec.Data 1.txt', '48 187-1-105-reg1-C--Spectrum--090--Spec.Data 1.txt', '50 187-1-105-reg2-A--Spectrum--094--Spec.Data 1.txt', '51 187-1-105-reg2-A--Spectrum--095--Spec.Data 1.txt', '52 187-1-105-reg2-A--Spectrum--096--Spec.Data 1.txt']

# %% [markdown]
# ## Plot spectra in a given region of space to examine secondary peaks or not

# %% [markdown]
# ### You'll need to tweak the peak parameters to find them
# - height = minimum height a peak should have to be identified
# - threshold = required vertical distance between a peak and its neighbours
# - distance = required horizontal distance bewteen neighbouring peaks.
# - prominence = required prominence of peaks
# - width = width of peaks

# %% [markdown]
# ## Example 1 - Using Scipy find peaks to look for SO2

# %%
prominence_SO2=20
height_SO2=20
width_SO2=1
threshold_SO2=1

SO2_peaks_scipy, x_data_scipy, y_data_scipy, fig_scipy=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
filetype=spectra_filetype, find_peaks_filter=True,  
xlim_peaks=[1145, 1155], xlim_plot=[1130, 1180], yscale=0.3,
prominence=prominence_SO2, height=height_SO2, width=width_SO2, threshold=threshold_SO2)

SO2_peaks=SO2_peaks_scipy

# %%
SO2_peaks
# Out:
#     pos  height  prom                                         file_names
# 0   NaN     NaN   NaN     06 187-1-102-A--Spectrum--019--Spec.Data 1.txt
# 1   NaN     NaN   NaN     07 187-1-102-A--Spectrum--020--Spec.Data 1.txt
# 2   NaN     NaN   NaN     08 187-1-102-A--Spectrum--021--Spec.Data 1.txt
# 3   NaN     NaN   NaN     10 187-1-102-B--Spectrum--025--Spec.Data 1.txt
# 4   NaN     NaN   NaN     11 187-1-102-B--Spectrum--026--Spec.Data 1.txt
# 5   NaN     NaN   NaN     12 187-1-102-B--Spectrum--027--Spec.Data 1.txt
# 6   NaN     NaN   NaN     14 187-1-102-C--Spectrum--031--Spec.Data 1.txt
# 7   NaN     NaN   NaN     15 187-1-102-C--Spectrum--032--Spec.Data 1.txt
# 8   NaN     NaN   NaN     16 187-1-102-C--Spectrum--033--Spec.Data 1.txt
# 9   NaN     NaN   NaN     18 187-1-102-B--Spectrum--036--Spec.Data 1.txt
# 10  NaN     NaN   NaN     19 187-1-102-B--Spectrum--037--Spec.Data 1.txt
# 11  NaN     NaN   NaN     20 187-1-102-B--Spectrum--038--Spec.Data 1.txt
# 12  NaN     NaN   NaN     22 187-1-103-A--Spectrum--044--Spec.Data 1.txt
# 13  NaN     NaN   NaN     23 187-1-103-A--Spectrum--045--Spec.Data 1.txt
# 14  NaN     NaN   NaN     24 187-1-103-A--Spectrum--046--Spec.Data 1.txt
# 15  NaN     NaN   NaN     26 187-1-103-B--Spectrum--050--Spec.Data 1.txt
# 16  NaN     NaN   NaN     27 187-1-103-B--Spectrum--051--Spec.Data 1.txt
# 17  NaN     NaN   NaN     28 187-1-103-B--Spectrum--052--Spec.Data 1.txt
# 18  NaN     NaN   NaN     30 187-1-103-C--Spectrum--056--Spec.Data 1.txt
# 19  NaN     NaN   NaN     31 187-1-103-C--Spectrum--057--Spec.Data 1.txt
# 20  NaN     NaN   NaN     32 187-1-103-C--Spectrum--058--Spec.Data 1.txt
# 21  NaN     NaN   NaN     34 187-1-104-A--Spectrum--066--Spec.Data 1.txt
# 22  NaN     NaN   NaN     35 187-1-104-A--Spectrum--067--Spec.Data 1.txt
# 23  NaN     NaN   NaN     36 187-1-104-A--Spectrum--068--Spec.Data 1.txt
# 24  NaN     NaN   NaN  39 187-1-105-reg1-A--Spectrum--077--Spec.Data ...
# 25  NaN     NaN   NaN  40 187-1-105-reg1-A--Spectrum--078--Spec.Data ...
# 26  NaN     NaN   NaN  41 187-1-105-reg1-A--Spectrum--079--Spec.Data ...
# 27  NaN     NaN   NaN  43 187-1-105-reg1-B--Spectrum--083--Spec.Data ...
# 28  NaN     NaN   NaN  44 187-1-105-reg1-B--Spectrum--084--Spec.Data ...
# 29  NaN     NaN   NaN  45 187-1-105-reg1-B--Spectrum--085--Spec.Data ...
# 30  NaN     NaN   NaN  46 187-1-105-reg1-C--Spectrum--088--Spec.Data ...
# 31  NaN     NaN   NaN  47 187-1-105-reg1-C--Spectrum--089--Spec.Data ...
# 32  NaN     NaN   NaN  48 187-1-105-reg1-C--Spectrum--090--Spec.Data ...
# 33  NaN     NaN   NaN  50 187-1-105-reg2-A--Spectrum--094--Spec.Data ...
# 34  NaN     NaN   NaN  51 187-1-105-reg2-A--Spectrum--095--Spec.Data ...
# 35  NaN     NaN   NaN  52 187-1-105-reg2-A--Spectrum--096--Spec.Data ...

# %% [markdown]
# ### Now filter out ones with no peaks, or low prominence before we loop through them

# %%
# Remove the ones where it didnt find SO2
SO2_notNa=np.isnan(SO2_peaks['pos'])
# Remove ones with a prominence less than this. 
prom_filt=35
SO2_filter=((SO2_peaks['prom']>prom_filt))&(~SO2_notNa)
print('Number kept with this filter:')
print(sum(SO2_filter))
print('Number discarded:')
print(sum(~SO2_filter&(~SO2_notNa)))
filenames_SO2=list(File_df['filename'].loc[SO2_filter])
print('filenames with SO2:')
print(filenames_SO2)
# Out:
# Number kept with this filter:
# 0
# Number discarded:
# 0
# filenames with SO2:
# []

# %% [markdown]
# ### Choose a filename to test peak fits

# %%
if sum(SO2_filter)>0:
    filename=filenames_SO2[0]

# %% [markdown]
# ### Set up configuration file for S peak fitting
# - Here, we are using a spline to quantify the area down to the 92% of the peak height (int_cut_of=0.08), there are differen options you can use for this

# %%
if sum(SO2_filter)>0:
    SO2_peak_config=pf.generic_peak_config(name='SO2', lower_bck=[1110, 1130],
    upper_bck=[1190, 1200], cent=1150, x_range_bck=20, N_peaks=1,   model_name='Spline', int_cut_off=0.05)
    print(SO2_peak_config)

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
    path=spectra_path, filename=filename, filetype=spectra_filetype, 
     plot_figure=True)

# %% [markdown]
# ## Now lets loop through files

# %%
files_to_fit=filenames_SO2
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_SO2 = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_SO2 = pd.concat([df_Merge_SO2, SO2_peak_fit], axis=0)
# Out:
# 0it [00:00, ?it/s]

# %%
df_Merge_SO2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Plot peak areas and peak heights

# %%
if sum(SO2_filter)>0:
    plt.plot(df_Merge_SO2['Peak_Area_SO2'], 
            df_Merge_SO2['Peak_Height_SO2'], 'ok')
    plt.xlabel('Peak Area SO2')
    plt.ylabel('Peak Height SO2')
    # plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ### Save this to excel

# %%
if sum(SO2_filter)>0:
    df_Merge_SO2['filename'] = df_Merge_SO2['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_SO2.to_excel('SO2_Peak_fits.xlsx', index=False)

# %% [markdown]
# ## Now do the same to ID any carbonate peaks

# %% [markdown]
# ### Using scipy find peaks methods
# - This method doesnt always work perfectly for broader carbonate peaks

# %%
prominence_carb=20
height_carb=10
width_carb=5
threshold_carb=1

Carb_peaks_scipy, x_data_scipy, y_data_scipy, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, find_peaks_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1070, 1110], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_scipy

# %%
prominence_carb=30
height_carb=10
width_carb=4
threshold_carb=1

Carb_peaks_prom, x_data_prom, y_data_prom, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, prominence_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1080, 1110], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)

Carb_peaks=Carb_peaks_prom

# %%
Carb_peaks
# Out:
#             pos      height        prom  \
# 0           NaN         NaN   21.699982
# 1           NaN         NaN   13.199982
# 2           NaN         NaN   15.799988
# 3           NaN         NaN    6.400024
# 4           NaN         NaN    7.600006
# 5           NaN         NaN    5.500000
# 6           NaN         NaN    6.500030
# 7           NaN         NaN    7.900024
# 8           NaN         NaN    5.499970
# 9           NaN         NaN    5.599976
# 10          NaN         NaN    6.399994
# 11          NaN         NaN    4.800018
# 12          NaN         NaN   12.599976
# 13          NaN         NaN    7.999970
# 14          NaN         NaN    5.600006
# 15          NaN         NaN    5.100037
# 16  1102.734803  813.200012  106.000000
# 17          NaN         NaN    8.900024
# 18          NaN         NaN    8.000000
# 19          NaN         NaN    7.000000
# 20          NaN         NaN    6.899963
# 21          NaN         NaN   14.500030
# 22          NaN         NaN   16.100037
# 23          NaN         NaN   12.400024
# 24          NaN         NaN    4.199982
# 25          NaN         NaN   11.100037
# 26          NaN         NaN    6.800018
# 27          NaN         NaN    5.300049
# 28          NaN         NaN    8.299988
# 29          NaN         NaN    8.299988
# 30          NaN         NaN    5.600006
# 31          NaN         NaN    6.199982
# 32          NaN         NaN    5.400024
# 33          NaN         NaN    6.800018
# 34          NaN         NaN    7.899963
# 35          NaN         NaN   10.799988
#
#                                            file_names
# 0      06 187-1-102-A--Spectrum--019--Spec.Data 1.txt
# 1      07 187-1-102-A--Spectrum--020--Spec.Data 1.txt
# 2      08 187-1-102-A--Spectrum--021--Spec.Data 1.txt
# 3      10 187-1-102-B--Spectrum--025--Spec.Data 1.txt
# 4      11 187-1-102-B--Spectrum--026--Spec.Data 1.txt
# 5      12 187-1-102-B--Spectrum--027--Spec.Data 1.txt
# 6      14 187-1-102-C--Spectrum--031--Spec.Data 1.txt
# 7      15 187-1-102-C--Spectrum--032--Spec.Data 1.txt
# 8      16 187-1-102-C--Spectrum--033--Spec.Data 1.txt
# 9      18 187-1-102-B--Spectrum--036--Spec.Data 1.txt
# 10     19 187-1-102-B--Spectrum--037--Spec.Data 1.txt
# 11     20 187-1-102-B--Spectrum--038--Spec.Data 1.txt
# 12     22 187-1-103-A--Spectrum--044--Spec.Data 1.txt
# 13     23 187-1-103-A--Spectrum--045--Spec.Data 1.txt
# 14     24 187-1-103-A--Spectrum--046--Spec.Data 1.txt
# 15     26 187-1-103-B--Spectrum--050--Spec.Data 1.txt
# 16     27 187-1-103-B--Spectrum--051--Spec.Data 1.txt
# 17     28 187-1-103-B--Spectrum--052--Spec.Data 1.txt
# 18     30 187-1-103-C--Spectrum--056--Spec.Data 1.txt
# 19     31 187-1-103-C--Spectrum--057--Spec.Data 1.txt
# 20     32 187-1-103-C--Spectrum--058--Spec.Data 1.txt
# 21     34 187-1-104-A--Spectrum--066--Spec.Data 1.txt
# 22     35 187-1-104-A--Spectrum--067--Spec.Data 1.txt
# 23     36 187-1-104-A--Spectrum--068--Spec.Data 1.txt
# 24  39 187-1-105-reg1-A--Spectrum--077--Spec.Data ...
# 25  40 187-1-105-reg1-A--Spectrum--078--Spec.Data ...
# 26  41 187-1-105-reg1-A--Spectrum--079--Spec.Data ...
# 27  43 187-1-105-reg1-B--Spectrum--083--Spec.Data ...
# 28  44 187-1-105-reg1-B--Spectrum--084--Spec.Data ...
# 29  45 187-1-105-reg1-B--Spectrum--085--Spec.Data ...
# 30  46 187-1-105-reg1-C--Spectrum--088--Spec.Data ...
# 31  47 187-1-105-reg1-C--Spectrum--089--Spec.Data ...
# 32  48 187-1-105-reg1-C--Spectrum--090--Spec.Data ...
# 33  50 187-1-105-reg2-A--Spectrum--094--Spec.Data ...
# 34  51 187-1-105-reg2-A--Spectrum--095--Spec.Data ...
# 35  52 187-1-105-reg2-A--Spectrum--096--Spec.Data ...

# %% [markdown]
# ## Find ones with certain peak parameters to include

# %%
Carb_noNa=np.isnan(Carb_peaks['pos'])
prom_filter=100
Carb_filter=((Carb_peaks['prom']<prom_filter))&(~Carb_noNa)
print('Number kept with this filter:')
print(sum(Carb_filter))
print('Number discarded:')
print(sum(~Carb_filter&(~Carb_noNa)))
filenames_Carb=list(File_df['filename'].loc[Carb_filter])
print('filenames with carb:')
print(filenames_Carb)
# Out:
# Number kept with this filter:
# 0
# Number discarded:
# 1
# filenames with carb:
# []

# %% [markdown]
# ### Fit one to tweak parameters

# %%
if sum(Carb_filter)>0:
    filename_carb=filenames_Carb[0]

    Carb_peak_config=pf.generic_peak_config(name='Carb', lower_bck=[1050, 1070],
    upper_bck=[1120, 1150], cent=1090, x_range_bck=50, N_poly_carb_bck=2, model_name='Spline')
    print(Carb_peak_config)

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
    path=spectra_path, filename=filename_carb, filetype=spectra_filetype,
     plot_figure=True)

# %% [markdown]
# ### Loop over all carbonate files

# %%
files_to_fit=filenames_Carb
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_Carb = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_Carb = pd.concat([df_Merge_Carb, Carb_peak_fit], axis=0)
# Out:
# 0it [00:00, ?it/s]

# %%
if sum(Carb_filter)>0:
    plt.plot(df_Merge_Carb['Peak_Area_Carb'], 
        df_Merge_Carb['Peak_Height_Carb'], 'ok')
    plt.xlabel('Peak Area Carb')
    plt.ylabel('Peak Height Carb')
# plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ## Save to excel

# %%
if sum(Carb_filter)>0:
    df_Merge_Carb['filename'] = df_Merge_Carb['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_Carb.to_excel('Carb_Peak_fits.xlsx', index=False )

# %%
df_Merge_Carb
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os

if os.name=="posix":

    def mac_notification(title, subtitle, message):
        """
        Display a macOS notification with the default sound using AppleScript.
        
        Args:
        - title: Title of the notification.
        - subtitle: Subtitle of the notification.
        - message: Main message content of the notification.
        """
        os.system("""
                osascript -e 'display notification "{}" with title "{}" subtitle "{}" sound name "default"'
                """.format(message, title, subtitle))

    mac_notification("Notebook Completed", "VSCode", "Step3b Secondary peaks")

else:

    # %pip install winotify

    from winotify import Notification, audio

    toast= Notification(app_id="VSCode",title="Notebook completed",
                        msg="Step3b_Secondary_Peaks is done!",
                        duration="short")
    toast.set_audio(audio.Mail,loop=False)
    toast.show()
