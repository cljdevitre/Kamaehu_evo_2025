# %% [markdown]
# # 3b. Fitting carbonate and SO$_2$ peaks
# - This notebook shows how to fit secondary peaks, such as carbonate and S-rich phases in vapour bubbles and fluid inclusions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
from tqdm import tqdm
pf.__version__
# Out:
# '1.0.1'

# %%
# Here, we are loading in the settings files from Step1. If all you want to do is find secondary phases, paste that code here
meta_path, spectra_path, spectra_filetype, prefix, str_prefix, spectra_file_ext, meta_file_ext, TruPower=pf.get_settings()

# %%
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'diad', 'CRR', 'secphase','Series','unquant','Series','map','ol','away']
Diad_Files=pf.get_files(path=spectra_path, file_ext=spectra_file_ext, exclude_str=exclude_str)
print(Diad_Files)
File_df=pd.DataFrame(data={'filename': Diad_Files})
# Out:
# ['04 FG04-A1-4-start-rep1.txt', '05 FG04-A1-4-start-rep2.txt', '06 FG04-A1-4-start-rep3.txt', '08 KA961_c110_a1_FIA.txt', '10 KA961_c110_a1_FIB.txt', '11 KA961_c110_a2_FIC_r1.txt', '12 KA961_c110_a2_FIC_r2.txt', '13 KA961_c110_a2_FIC_r3.txt', '14 KA961_c111_a1_FIB.txt', '15 KA961_c111_a1_FIA.txt', '16 KA961_c111_a1_FIC.txt', '18 KA961_c112_a1_FIA.txt', '19 KA961_c112_a1_FIB.txt', '20 KA961_c113_a1_FIA.txt', '21 KA961_c114_a1_FIA.txt', '22 KA961_c115_a1_FIA.txt', '23 KA961_c150_a1_FIA.txt', '24 KA961_c150_a1_FIB.txt', '25 KA961_c150_a2_FIC.txt', '26 KA961_c150_a3_FID.txt', '27 KA961_c150_a3_FIE.txt', '29 KA961_c151_a1_FIA.txt', '30 KA961_c152_a1_FIA.txt', '31 KA961_c153_a1_FIA.txt', '32 KA961_c153_a1_FIB.txt', '33 KA961_c153_a2_FIC.txt', '34 KA961_c154_a1_FIA.txt', '35 KA961_c155_a1_FIA.txt', '36 KA961_c156_a1_FIA.txt', '37 KA961_c157_a1_FIA.txt', '38 KA961_c158_a1_FIA.txt', '39 KA961_c158_a2_FIB.txt', '40 KA961_c159_a1_FIA.txt', '42 FG04-A1-4-end-rep4.txt', '43 FG04-A1-4-end-rep5.txt', '44 FG04-A1-4-end-rep6.txt']

# %% [markdown]
# ## Plot spectra in a given region of space to examine secondary peaks or not

# %% [markdown]
# ### You'll need to tweak the peak parameters to find them
# - height = minimum height a peak should have to be identified
# - threshold = required vertical distance between a peak and its neighbours
# - distance = required horizontal distance bewteen neighbouring peaks.
# - prominence = required prominence of peaks
# - width = width of peaks

# %% [markdown]
# ## Example 1 - Using Scipy find peaks to look for SO2

# %%
prominence_SO2=15
height_SO2=15
width_SO2=1
threshold_SO2=1

SO2_peaks_scipy, x_data_scipy, y_data_scipy, fig_scipy=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
filetype=spectra_filetype, find_peaks_filter=True,  
xlim_peaks=[1144, 1155], xlim_plot=[1130, 1180], yscale=0.3,
prominence=prominence_SO2, height=height_SO2, width=width_SO2, threshold=threshold_SO2)

SO2_peaks=SO2_peaks_scipy

# %%
SO2_peaks
# Out:
#             pos  height     prom                   file_names
# 0           NaN     NaN      NaN  04 FG04-A1-4-start-rep1.txt
# 1           NaN     NaN      NaN  05 FG04-A1-4-start-rep2.txt
# 2           NaN     NaN      NaN  06 FG04-A1-4-start-rep3.txt
# 3   1150.678702  724.25   25.250     08 KA961_c110_a1_FIA.txt
# 4   1150.678702  707.00   31.500     10 KA961_c110_a1_FIB.txt
# 5           NaN     NaN      NaN  11 KA961_c110_a2_FIC_r1.txt
# 6           NaN     NaN      NaN  12 KA961_c110_a2_FIC_r2.txt
# 7           NaN     NaN      NaN  13 KA961_c110_a2_FIC_r3.txt
# 8   1150.123263  765.25   91.500     14 KA961_c111_a1_FIB.txt
# 9   1150.123263  692.50   22.375     15 KA961_c111_a1_FIA.txt
# 10          NaN     NaN      NaN     16 KA961_c111_a1_FIC.txt
# 11          NaN     NaN      NaN     18 KA961_c112_a1_FIA.txt
# 12          NaN     NaN      NaN     19 KA961_c112_a1_FIB.txt
# 13          NaN     NaN      NaN     20 KA961_c113_a1_FIA.txt
# 14          NaN     NaN      NaN     21 KA961_c114_a1_FIA.txt
# 15  1150.678702  715.75   41.375     22 KA961_c115_a1_FIA.txt
# 16  1150.123263  730.25   30.750     23 KA961_c150_a1_FIA.txt
# 17          NaN     NaN      NaN     24 KA961_c150_a1_FIB.txt
# 18          NaN     NaN      NaN     25 KA961_c150_a2_FIC.txt
# 19  1150.123263  678.75   12.125     26 KA961_c150_a3_FID.txt
# 20          NaN     NaN      NaN     27 KA961_c150_a3_FIE.txt
# 21  1150.678702  743.50   48.125     29 KA961_c151_a1_FIA.txt
# 22          NaN     NaN      NaN     30 KA961_c152_a1_FIA.txt
# 23          NaN     NaN      NaN     31 KA961_c153_a1_FIA.txt
# 24          NaN     NaN      NaN     32 KA961_c153_a1_FIB.txt
# 25          NaN     NaN      NaN     33 KA961_c153_a2_FIC.txt
# 26          NaN     NaN      NaN     34 KA961_c154_a1_FIA.txt
# 27          NaN     NaN      NaN     35 KA961_c155_a1_FIA.txt
# 28          NaN     NaN      NaN     36 KA961_c156_a1_FIA.txt
# 29          NaN     NaN      NaN     37 KA961_c157_a1_FIA.txt
# 30  1150.678702  824.00  143.625     38 KA961_c158_a1_FIA.txt
# 31          NaN     NaN      NaN     39 KA961_c158_a2_FIB.txt
# 32          NaN     NaN      NaN     40 KA961_c159_a1_FIA.txt
# 33          NaN     NaN      NaN    42 FG04-A1-4-end-rep4.txt
# 34          NaN     NaN      NaN    43 FG04-A1-4-end-rep5.txt
# 35          NaN     NaN      NaN    44 FG04-A1-4-end-rep6.txt

# %% [markdown]
# ### Now filter out ones with no peaks, or low prominence before we loop through them

# %%
# Remove the ones where it didnt find SO2
SO2_notNa=np.isnan(SO2_peaks['pos'])
# Remove ones with a prominence less than this. 
prom_filt=15
SO2_filter=((SO2_peaks['prom']>prom_filt))&(~SO2_notNa)
print('Number kept with this filter:')
print(sum(SO2_filter))
print('Number discarded:')
print(sum(~SO2_filter&(~SO2_notNa)))
filenames_SO2=list(File_df['filename'].loc[SO2_filter])
print('filenames with SO2:')
print(filenames_SO2)
# Out:
# Number kept with this filter:
# 8
# Number discarded:
# 1
# filenames with SO2:
# ['08 KA961_c110_a1_FIA.txt', '10 KA961_c110_a1_FIB.txt', '14 KA961_c111_a1_FIB.txt', '15 KA961_c111_a1_FIA.txt', '22 KA961_c115_a1_FIA.txt', '23 KA961_c150_a1_FIA.txt', '29 KA961_c151_a1_FIA.txt', '38 KA961_c158_a1_FIA.txt']

# %% [markdown]
# ### Choose a filename to test peak fits

# %%
if sum(SO2_filter)>0:
    filename=filenames_SO2[0]

# %% [markdown]
# ### Set up configuration file for S peak fitting
# - Here, we are using a spline to quantify the area down to the 92% of the peak height (int_cut_of=0.08), there are differen options you can use for this

# %%
if sum(SO2_filter)>0:
    SO2_peak_config=pf.generic_peak_config(name='SO2', lower_bck=[1125, 1135],
    upper_bck=[1165, 1180], cent=1150, x_range_bck=20, N_peaks=1,   model_name='Spline', int_cut_off=0.05)
    print(SO2_peak_config)

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
    path=spectra_path, filename=filename, filetype=spectra_filetype, 
     plot_figure=True)
# Out:
# generic_peak_config(name='SO2', lower_bck=[1125, 1135], upper_bck=[1165, 1180], model_name='Spline', x_range_bck=20, N_poly_carb_bck=1, amplitude=1000, cent=1150, outlier_sigma=12, distance=10, prominence=5, width=6, threshold=0.1, height=100, exclude_range=None, return_other_params=False, N_peaks=1, int_cut_off=0.05)

# %% [markdown]
# ## Now lets loop through files

# %%
files_to_fit=filenames_SO2
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_SO2 = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    SO2_peak_fit=pf.fit_generic_peak(config=SO2_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_SO2 = pd.concat([df_Merge_SO2, SO2_peak_fit], axis=0)
# Out:
# 100%|██████████| 8/8 [00:02<00:00,  2.80it/s]

# %%
df_Merge_SO2
# Out:
#                    filename  Peak_Cent_SO2  Peak_Area_SO2  Peak_Height_SO2  \
# 0  08 KA961_c110_a1_FIA.txt    1150.901117      37.503061        25.751950
# 0  10 KA961_c110_a1_FIB.txt    1150.753763      46.399697        32.597153
# 0  14 KA961_c111_a1_FIB.txt    1150.193817     118.733107        90.326820
# 0  15 KA961_c111_a1_FIA.txt    1150.105405      30.796833        21.946967
# 0  22 KA961_c115_a1_FIA.txt    1150.724292      59.701116        43.009125
# 0  23 KA961_c150_a1_FIA.txt    1150.134876      29.470507        29.188853
# 0  29 KA961_c151_a1_FIA.txt    1150.812704      61.095380        45.492784
# 0  38 KA961_c158_a1_FIA.txt    1150.724292     223.637646       147.176929
#
#   Model_name
# 0     Spline
# 0     Spline
# 0     Spline
# 0     Spline
# 0     Spline
# 0     Spline
# 0     Spline
# 0     Spline

# %% [markdown]
# ### Plot peak areas and peak heights

# %%
if sum(SO2_filter)>0:
    plt.plot(df_Merge_SO2['Peak_Area_SO2'], 
            df_Merge_SO2['Peak_Height_SO2'], 'ok')
    plt.xlabel('Peak Area SO2')
    plt.ylabel('Peak Height SO2')
    # plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ### Save this to excel

# %%
if sum(SO2_filter)>0:
    df_Merge_SO2['filename'] = df_Merge_SO2['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_SO2.to_excel('SO2_Peak_fits.xlsx', index=False)

# %% [markdown]
# ## Now do the same to ID any carbonate peaks

# %% [markdown]
# ### Using scipy find peaks methods
# - This method doesnt always work perfectly for broader carbonate peaks

# %%
prominence_carb=10
height_carb=10
width_carb=4
threshold_carb=1

Carb_peaks_scipy, x_data_scipy, y_data_scipy, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, find_peaks_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1070, 1110], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)
Carb_peaks=Carb_peaks_scipy

# %%
prominence_carb=30
height_carb=10
width_carb=4
threshold_carb=1

Carb_peaks_prom, x_data_prom, y_data_prom, fig=pf.plot_secondary_peaks(
Diad_Files=Diad_Files, path=spectra_path, 
 filetype=spectra_filetype, prominence_filter=True,  
xlim_plot=[1050, 1150], xlim_peaks=[1080, 1110], yscale=0.3,
prominence=prominence_carb, height=height_carb, width=width_carb, threshold=threshold_carb)

# Carb_peaks=Carb_peaks_prom

# %%
Carb_peaks
# Out:
#             pos      height  prom                   file_names
# 0           NaN         NaN   NaN  04 FG04-A1-4-start-rep1.txt
# 1           NaN         NaN   NaN  05 FG04-A1-4-start-rep2.txt
# 2           NaN         NaN   NaN  06 FG04-A1-4-start-rep3.txt
# 3           NaN         NaN   NaN     08 KA961_c110_a1_FIA.txt
# 4           NaN         NaN   NaN     10 KA961_c110_a1_FIB.txt
# 5           NaN         NaN   NaN  11 KA961_c110_a2_FIC_r1.txt
# 6           NaN         NaN   NaN  12 KA961_c110_a2_FIC_r2.txt
# 7           NaN         NaN   NaN  13 KA961_c110_a2_FIC_r3.txt
# 8           NaN         NaN   NaN     14 KA961_c111_a1_FIB.txt
# 9           NaN         NaN   NaN     15 KA961_c111_a1_FIA.txt
# 10          NaN         NaN   NaN     16 KA961_c111_a1_FIC.txt
# 11          NaN         NaN   NaN     18 KA961_c112_a1_FIA.txt
# 12          NaN         NaN   NaN     19 KA961_c112_a1_FIB.txt
# 13          NaN         NaN   NaN     20 KA961_c113_a1_FIA.txt
# 14          NaN         NaN   NaN     21 KA961_c114_a1_FIA.txt
# 15          NaN         NaN   NaN     22 KA961_c115_a1_FIA.txt
# 16          NaN         NaN   NaN     23 KA961_c150_a1_FIA.txt
# 17          NaN         NaN   NaN     24 KA961_c150_a1_FIB.txt
# 18          NaN         NaN   NaN     25 KA961_c150_a2_FIC.txt
# 19          NaN         NaN   NaN     26 KA961_c150_a3_FID.txt
# 20          NaN         NaN   NaN     27 KA961_c150_a3_FIE.txt
# 21          NaN         NaN   NaN     29 KA961_c151_a1_FIA.txt
# 22          NaN         NaN   NaN     30 KA961_c152_a1_FIA.txt
# 23          NaN         NaN   NaN     31 KA961_c153_a1_FIA.txt
# 24          NaN         NaN   NaN     32 KA961_c153_a1_FIB.txt
# 25          NaN         NaN   NaN     33 KA961_c153_a2_FIC.txt
# 26          NaN         NaN   NaN     34 KA961_c154_a1_FIA.txt
# 27          NaN         NaN   NaN     35 KA961_c155_a1_FIA.txt
# 28          NaN         NaN   NaN     36 KA961_c156_a1_FIA.txt
# 29          NaN         NaN   NaN     37 KA961_c157_a1_FIA.txt
# 30          NaN         NaN   NaN     38 KA961_c158_a1_FIA.txt
# 31          NaN         NaN   NaN     39 KA961_c158_a2_FIB.txt
# 32          NaN         NaN   NaN     40 KA961_c159_a1_FIA.txt
# 33  1095.412035  705.799988  14.0    42 FG04-A1-4-end-rep4.txt
# 34          NaN         NaN   NaN    43 FG04-A1-4-end-rep5.txt
# 35          NaN         NaN   NaN    44 FG04-A1-4-end-rep6.txt

# %% [markdown]
# ## Find ones with certain peak parameters to include

# %%
Carb_noNa=np.isnan(Carb_peaks['pos'])
prom_filter=10
Carb_filter=((Carb_peaks['prom']>prom_filter))&(~Carb_noNa)
print('Number kept with this filter:')
print(sum(Carb_filter))
print('Number discarded:')
print(sum(~Carb_filter&(~Carb_noNa)))
filenames_Carb=list(File_df['filename'].loc[Carb_filter])
print('filenames with carb:')
print(filenames_Carb)
# Out:
# Number kept with this filter:
# 1
# Number discarded:
# 0
# filenames with carb:
# ['42 FG04-A1-4-end-rep4.txt']

# %% [markdown]
# ### Fit one to tweak parameters

# %%
if sum(Carb_filter)>0:
    filename_carb=filenames_Carb[0]

    Carb_peak_config=pf.generic_peak_config(name='Carb', lower_bck=[1050, 1070],
    upper_bck=[1120, 1150], cent=1090, x_range_bck=50, N_poly_carb_bck=2, model_name='Spline')
    print(Carb_peak_config)

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
    path=spectra_path, filename=filename_carb, filetype=spectra_filetype,
     plot_figure=True)
# Out:
# generic_peak_config(name='Carb', lower_bck=[1050, 1070], upper_bck=[1120, 1150], model_name='Spline', x_range_bck=50, N_poly_carb_bck=2, amplitude=1000, cent=1090, outlier_sigma=12, distance=10, prominence=5, width=6, threshold=0.1, height=100, exclude_range=None, return_other_params=False, N_peaks=1, int_cut_off=0.05)

# %% [markdown]
# ### Loop over all carbonate files

# %%
files_to_fit=filenames_Carb
plot_figure=True # If False, Means doesnt have to make figures, lot faster. 
close_figure=False # Means shows figures in the notebook itself

df_Merge_Carb = pd.DataFrame([])

for i in tqdm(range(0, len(files_to_fit))): #
    
    ## Diad 1 fit
    filename=files_to_fit[i]

    Carb_peak_fit=pf.fit_generic_peak(config=Carb_peak_config, 
path=spectra_path, filename=filename, filetype=spectra_filetype,
 plot_figure=plot_figure)
 
    df_Merge_Carb = pd.concat([df_Merge_Carb, Carb_peak_fit], axis=0)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]

# %%
if sum(Carb_filter)>0:
    plt.plot(df_Merge_Carb['Peak_Area_Carb'], 
        df_Merge_Carb['Peak_Height_Carb'], 'ok')
    plt.xlabel('Peak Area Carb')
    plt.ylabel('Peak Height Carb')
# plt.yscale('log')
# plt.xscale('log')

# %% [markdown]
# ## Save to excel

# %%
if sum(Carb_filter)>0:
    df_Merge_Carb['filename'] = df_Merge_Carb['filename'].str.replace('--Spec.Data 1', '')
    df_Merge_Carb.to_excel('Carb_Peak_fits.xlsx', index=False )

# %%
df_Merge_Carb
# Out:
#                     filename  Peak_Cent_Carb  Peak_Area_Carb  \
# 0  42 FG04-A1-4-end-rep4.txt     1095.413038      121.433539
#
#    Peak_Height_Carb Model_name
# 0          15.63313     Spline

# %%
import os

if os.name=="posix":

    def mac_notification(title, subtitle, message):
        """
        Display a macOS notification with the default sound using AppleScript.
        
        Args:
        - title: Title of the notification.
        - subtitle: Subtitle of the notification.
        - message: Main message content of the notification.
        """
        os.system("""
                osascript -e 'display notification "{}" with title "{}" subtitle "{}" sound name "default"'
                """.format(message, title, subtitle))

    mac_notification("Notebook Completed", "VSCode", "Step3b Secondary peaks")

else:

    # %pip install winotify

    from winotify import Notification, audio

    toast= Notification(app_id="VSCode",title="Notebook completed",
                        msg="Step3b_Secondary_Peaks is done!",
                        duration="short")
    toast.set_audio(audio.Mail,loop=False)
    toast.show()
