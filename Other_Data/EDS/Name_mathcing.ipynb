# %%
import pandas as pd
## Lets do the look up code.
# 
lookup_key = {
'filename': 'name of file',
'Density g/cm3': 'Density of CO2 in g/cm3',
'σ Density g/cm3': '1 sigma error on density (combined from peak fitting, Ne correction model, and densimeter equation)',
'σ Density g/cm3 (from Ne+peakfit)': '1 sigma error on density (from just peak fitting + Ne correction model)',
'σ Density g/cm3 (from densimeter)': '1 sigma error on density (from just the densimeter equation)',
'Corrected_Splitting': 'Splitting in cm-1 after correcting for instrument drift',
'Corrected_Splitting_σ': '1 sigma error on splitting (combined from peak fitting, Ne correction model)',
'Corrected_Splitting_σ_Ne': '1 sigma error on splitting just from Ne correction model',
'Corrected_Splitting_σ_peak_fit': '1 sigma error on splitting just from peak fitting',
'power (mW)': 'Laser power used in mW measured by WITEC TruPower',
'Spectral Center': 'Spectral Center used for analysis',
'Preferred D_σ_Ne': 'CHECK!!!',
'Preferred D_σ_pkfit': 'CHECK!!!',
'in range': 'Y or N - Is the corrected splitting within the calibration range of the densimeter?',
'Notes': 'Which segment of the densimeter was used (e.g. which of several polynomials)',
'LowD_RT': 'Density calculated using the low density part of the Room Temp densimeter',
'HighD_RT': 'Density calculated using the high density part of the Room Temp densimeter',
'LowD_SC': 'Density calculated using the low density segment of the 37C densimeter',
'LowD_SC_σ': 'Error on density calculated using the low density segment of the 37C densimeter',
'MedD_RC': 'Density calculated using the medium density segment of the 37C densimeter',
'MedD_SC_σ': 'Error on density calculated using the medium density segment of the 37C densimeter',
'HighD_SC': 'Density calculated using the high density segment of the 37C densimeter',
'HighD_SC_σ': 'Error on density calculated using the high density segment of the 37C densimeter',
'Temperature': 'User entered Temp description: SupCrit or RoomT ',
'Splitting': 'Distance between fitted peak centers of Diad 1 and Diad 2 (cm-1)',
'Split_σ': 'Error on splitting',
'Diad1_Combofit_Cent': 'Fitted peak center (cm-1) of Diad1 (combined fit of diad, HB, gaussian background etc. )',
'Diad1_cent_err': 'Error on peak center of Diad1 (cm-1, calculated using lmfit)',
'Diad1_Combofit_Height': 'Height (intensity) of Diad1 combined fit',
'Diad1_Voigt_Cent': 'Fitted peak center (cm-1) of Diad1 for just the main peak',
'Diad1_Voigt_Area': 'Fitted area of Diad1 for just the main peak',
'Diad1_Voigt_Sigma': 'Fitted sigma of Diad1 for just the main peak',
'Diad1_Residual': 'Residual of fit to Diad1 (see DiadFit paper for explanation)',
'Diad1_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad1',
'Diad1_fwhm': 'Full Width Half Maximum of the fit to Diad1',
'Diad1_refit': 'Notes any warnings that flagged during iterative fitting',
'Diad2_Combofit_Cent': 'Fitted peak center (cm-1) of Diad2 (combined fit of diad, HB, gaussian background etc. )',
'Diad2_cent_err': 'Error on peak center of Diad2 (cm-1, calculated using lmfit)',
'Diad2_Combofit_Height': 'Height (intensity) of Diad2 combined fit',
'Diad2_Voigt_Cent': 'Fitted peak center (cm-1) of Diad2 for just the main peak',
'Diad2_Voigt_Area': 'Fitted area of Diad2 for just the main peak',
'Diad2_Voigt_Sigma': 'Fitted sigma of Diad2 for just the main peak',
'Diad2_Residual': 'Residual of fit to Diad2 (see DiadFit paper for explanation)',
'Diad2_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad2',
'Diad2_fwhm': 'Full Width Half Maximum of the fit to Diad2',
'Diad2_refit': 'Notes any warnings that flagged during iterative fitting',
'HB1_Cent': 'Fitted peak center of HB1 (cm-1)',
'HB1_Area': 'Fitted area of HB1',
'HB1_Sigma': 'Fitted sigma of HB1',
'HB2_Cent': 'Fitted peak center of HB2 (cm-1)',
'HB2_Area': 'Fitted area of HB2',
'HB2_Sigma': 'Fitted sigma of HB2',
'C13_Cent':  'Fitted peak center of the C13 peak (cm-1)',
'C13_Area': 'Fitted area of the C13 peak',
'C13_Sigma': 'Fitted sigma of the C13 peak',
'Diad2_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad2 (if used)',
'Diad2_Gauss_Area': 'Fitted area of the Gaussian background on Diad2',
'Diad2_Gauss_Sigma': 'Fitted sigma of the Gaussian backgroun on Diad2',
'Diad1_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad1 (if used)',
'Diad1_Gauss_Area': 'Fitted area of the Gaussian background on Diad1',
'Diad1_Gauss_Sigma': 'Fitted sigma of the Gaussian backgroun on Diad1',
'Diad1_Asym50': 'Asymmetry of Diad1 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
'Diad1_Asym70': 'Asymmetry of Diad1 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
'Diad1_Yuan2017_sym_factor': 'Symmetry factor of Diad1 following Yuan 2017',
'Diad1_Remigi2021_BSF': 'BSF factor of Diad1 following Remigi (2021)',
'Diad2_Asym50': 'Asymmetry of Diad2 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
'Diad2_Asym70': 'Asymmetry of Diad2 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
'Diad2_Yuan2017_sym_factor': 'Symmetry factor of Diad2 following Yuan 2017',
'Diad2_Remigi2021_BSF': 'BSF factor of Diad2 following Remigi (2021)',
'Diad1_PDF_Model': 'Name of the probability density function used to fit Diad1',
'Diad2_PDF_Model': 'Name of the probability density function used to fit Diad2',
'Standard': 'Is the analysis a standard (Yes/No)',
'date': 'Full date of analysis',
'Month': 'Month of analysis',
'Day': 'Day of the week of analysis',
'Int_time (s)': 'Integration time of each individual spectra in s',
'accumulations':'How many individual spectra are collected and averaged for a single reported spectra',
'Mag (X)': 'Objective used during analysis',
'duration': 'Duration of analysis as a string from WITEC',
'24hr_time': 'Time converted to a 24 hr clock',
'sec since midnight': 'time of acquisition as seconds after midnight on the day of analysis',
'Peak_Cent_SO2': 'Fitted peak center (cm-1) of the SO2 peak',
'Peak_Area_SO2': 'Fitted peak area (cm-1) of the SO2 peak',
'Peak_Height_SO2':  'Fitted peak height (cm-1) of the SO2 peak',
'Model_name_x': 'Model used to fit the SO2 peak',
'Peak_Cent_Carb': 'Fitted peak center (cm-1) of the Carb peak',
'Peak_Area_Carb': 'Fitted peak area (cm-1) of the Carb peak',
'Peak_Height_Carb':  'Fitted peak height (cm-1) of the Carb peak',
'Model_name_y': 'Model used to fit the SO2 peak',
'Carb_Diad_Ratio': 'Area of carbonate peak divided by sum of area of Diad1 and Diad2 ',
'SO2_Diad_Ratio': 'Area of the SO2 peak divided by sum of area of Diad1 and Diad2',
'SO2_mol_ratio': 'Molar proportion of SO2 in the gas species',
'time': 'seconds after midnight used for Ne correction ',
'preferred_values': 'Preferred value for Ne correction',
'lower_values': 'Preferred value - 1 sigma for Ne correction',
'upper_values': 'Preferred value + 1 sigma for Ne correction',
}

lookup_dict = {
    "py_index": "Python index number",
    "Crystal Name": "Crystal host name",
    "FI Name": "Fluid inclusion name",
    "Reported density mean of reps?": "Is the data in this row a mean of repeated analyses? (Yes or No)",
    "Density g/cm3": "Density of CO2 in g/cm3",
    "σ Density g/cm3": "1 sigma error on density (combined from peak fitting, Ne correction model, and densimeter equation)",
    "σ Density g/cm3 (as plotted, from DiadFit for individual, Std dev for averaged FI)": "This is the uncertainty on density that is used for plotting in the article.",
    "STDofreps_Density g/cm3": "Uncertainty in CO2 density for FI that had repeated analyses and for which a mean CO2 density is reported.",
    "σ Density g/cm3 (from Ne+peakfit)": "1 sigma error on density (from just peak fitting + Ne correction model).",
    "σ Density g/cm3 (from densimeter)": "1 sigma error on density (from just the densimeter equation).",
    "Corrected_Splitting (cm-1)": "Fermi diad splitting in cm-1 after correcting for instrument drift.",
    "Corrected_Splitting": "Splitting in cm-1 after correcting for instrument drift.",
    "Corrected_Splitting_σ": "1 sigma error on splitting (combined from peak fitting, Ne correction model).",
    "Corrected_Splitting_σ_Ne": "1 sigma error on splitting just from Ne correction model.",
    "Corrected_Splitting_σ_peak_fit": "1 sigma error on splitting just from peak fitting.",
    "power (mW)": "Laser power used in mW measured by WITEC TruPower.",
    "Spectral Center": "Spectral Center used for analysis.",
    "LowD_SC": "Density calculated using the low density segment of the 37C densimeter.",
    "LowD_SC_σ": "Error on density calculated using the low density segment of the 37C densimeter.",
    "MedD_RC": "Density calculated using the medium density segment of the 37C densimeter.",
    "MedD_SC_σ": "Error on density calculated using the medium density segment of the 37C densimeter.",
    "HighD_SC": "Density calculated using the high density segment of the 37C densimeter.",
    "HighD_SC_σ": "Error on density calculated using the high density segment of the 37C densimeter.",
    "Temperature": "Fluid inclusion estimated entrapment temperature in Celsius.",
    "Notes": "Which segment of the densimeter was used (e.g. which of several polynomials)",
    "Splitting (cm-1)": "Distance between fitted peak centers of Diad 1 and Diad 2 (cm-1).",
    "Split_σ": "Error on splitting.",
    "Diad1_Combofit_Cent": "Fitted peak center (cm-1) of Diad1 (combined fit of diad, HB, gaussian background etc.)",
    "Diad1_cent_err": "Error on peak center of Diad1 (cm-1, calculated using lmfit).",
    "Diad1_Combofit_Height": "Height (intensity) of Diad1 combined fit.",
    "Diad1_Voigt_Cent": "Fitted peak center (cm-1) of Diad1 for just the main peak.",
    "Diad1_Voigt_Area": "Fitted area of Diad1 for just the main peak.",
    "Diad1_Voigt_Sigma": "Fitted sigma of Diad1 for just the main peak.",
    "Diad1_Residual": "Residual of fit to Diad1.",
    "Diad1_Prop_Lor": "Proportion of Lorentzian in Psuedovoigt peak for Diad1.",
    "Diad1_fwhm": "Full Width Half Maximum of the fit to Diad1.",
    "Diad1_refit": "Notes any warnings that flagged during iterative fitting.",
    "Diad2_Combofit_Cent": "Fitted peak center (cm-1) of Diad2 (combined fit of diad, HB, gaussian background etc.)",
    "Diad2_cent_err": "Error on peak center of Diad2 (cm-1, calculated using lmfit).",
    "Diad2_Combofit_Height": "Height (intensity) of Diad2 combined fit.",
    "Diad2_Voigt_Cent": "Fitted peak center (cm-1) of Diad2 for just the main peak.",
    "Diad2_Voigt_Area": "Fitted area of Diad2 for just the main peak.",
    "Diad2_Voigt_Sigma": "Fitted sigma of Diad2 for just the main peak.",
    "Diad2_Residual": "Residual of fit to Diad2.",
    "Diad2_Prop_Lor": "Proportion of Lorentzian in Psuedovoigt peak for Diad2.",
    "Diad2_fwhm": "Full Width Half Maximum of the fit to Diad2.",
    "Diad2_refit": "Notes any warnings that flagged during iterative fitting.",
    "HB1_Cent": "Fitted peak center of HB1 (cm-1).",
    "HB1_Area": "Fitted area of HB1.",
    "HB1_Sigma": "Fitted sigma of HB1.",
    "HB2_Cent": "Fitted peak center of HB2 (cm-1).",
    "HB2_Area": "Fitted area of HB2.",
    "HB2_Sigma": "Fitted sigma of HB2.",
    "C13_Cent":  "Fitted peak center of the C13 peak (cm-1).",
    "C13_Area": "Fitted area of the C13 peak.",
    "C13_Sigma": "Fitted sigma of the C13 peak.",
    "Diad2_Gauss_Cent": "Fitted peak center (cm-1) of the Gaussian background on Diad2 (if used).",
    "Diad2_Gauss_Area": "Fitted area of the Gaussian background on Diad2.",
    "Diad2_Gauss_Sigma": "Fitted sigma of the Gaussian background on Diad2.",
    "Diad1_Gauss_Cent": "Fitted peak center (cm-1) of the Gaussian background on Diad1 (if used).",
    "Diad1_Gauss_Area": "Fitted area of the Gaussian background on Diad1.",
    "Diad1_Gauss_Sigma": "Fitted sigma of the Gaussian background on Diad1.",
    "Diad1_Asym50": "Asymmetry of Diad1 using a 50% intensity cut off.",
    "Diad1_Asym70": "Asymmetry of Diad1 using a 70% intensity cut off.",
    "Diad1_Yuan2017_sym_factor": "Symmetry factor of Diad1 following Yuan 2017.",
    "Diad1_Remigi2021_BSF": "BSF factor of Diad1 following Remigi (2021).",
    "Diad2_Asym50": "Asymmetry of Diad2 using a 50% intensity cut off.",
    "Diad2_Asym70": "Asymmetry of Diad2 using a 70% intensity cut off.",
    "Diad2_Yuan2017_sym_factor": "Symmetry factor of Diad2 following Yuan 2017.",
    "Diad2_Remigi2021_BSF": "BSF factor of Diad2 following Remigi (2021).",
    "Diad1_PDF_Model": "Name of the probability density function used to fit Diad1.",
    "Diad2_PDF_Model": "Name of the probability density function used to fit Diad2.",
    "Standard": "Is the analysis a standard (Yes/No).",
    "Day": "Day of the week of analysis.",
    "Int_time (s)": "Integration time of each individual spectra in s.",
    "accumulations": "How many individual spectra are collected and averaged for a single reported spectra.",
    "Mag (X)": "Objective used during analysis.",
    "duration": "Duration of analysis as a string from WITEC.",
    "24hr_time": "Time converted to a 24 hr clock.",
    "sec since midnight": "Time of acquisition as seconds after midnight on the day of analysis.",
    "Peak_Cent_SO2": "Fitted peak center (cm-1) of the SO2 peak.",
    "Peak_Area_SO2": "Fitted peak area (cm-1) of the SO2 peak.",
    "Peak_Height_SO2": "Fitted peak height (cm-1) of the SO2 peak.",
    "Model_name_x": "Model used to fit the SO2 peak.",
    "Peak_Cent_Carb": "Fitted peak center (cm-1) of the Carb peak.",
    "Peak_Area_Carb": "Fitted peak area (cm-1) of the Carb peak.",
    "Peak_Height_Carb": "Fitted peak height (cm-1) of the Carb peak.",
    "Model_name_y": "Model used to fit the Carb peak.",
    "Carb_Diad_Ratio": "Area of carbonate peak divided by sum of area of Diad1 and Diad2.",
    "SO2_Diad_Ratio": "Area of the SO2 peak divided by sum of area of Diad1 and Diad2.",
    "SO2_mol_ratio": "Molar proportion of SO2 in the gas species.",
    "time": "Seconds after midnight used for Ne correction.",
    "preferred_values": "Preferred value for Ne correction.",
    "lower_values": "Preferred value - 1 sigma for Ne correction.",
    "upper_values": "Preferred value + 1 sigma for Ne correction.",
    "filename": "Name of file",
    "SingleFI_D_km": "Calculated fluid inclusion depth in km.",
    "SingleFI_P_kbar": "Calculated fluid inclusion pressure in kbar.",
    "Mean_MC_P_kbar": "Mean pressure of simulated fluid inclusions in kbar.",
    "Med_MC_P_kbar": "Median pressure of simulated fluid inclusions in kbar.",
    "std_dev_MC_P_kbar": "Standard deviation of simulated fluid inclusion pressures in kbar.",
    "Mean_MC_D_km": "Mean depth of simulated fluid inclusions in km.",
    "Med_MC_D_km": "Median depth of simulated fluid inclusions in km.",
    "std_dev_MC_D_km": "Standard deviation of simulated fluid inclusion depths in km.",
    "error_T_K": "Input temperature uncertainty in K.",
    "error_CO2_dens_gcm3": "Input uncertainty on CO2 density in g/cm3.",
    "error_crust_dens_kgm3": "Input uncertainty in crustal density in kg/m3.",
    "T_K": "Input entrapment temperature in K.",
    "crust_dens_kgm3": "Input crustal density in kg/m3.",
    "EOS": "Equation of State used for calculations in Diad Fit.",
    "Results from Monte Carlo Simulations for CO2-H2O (5 iterations of pressure and XH2O) --->": "These are recalculated fluid inclusion pressures and depths considering the likely presence of H2O in the exsolved fluid.",
    "XH2O_mol_min": "Minimum estimated fraction of H2O in the fluid inclusion.",
    "XH2O_mol_av": "Average estimated fraction of H2O in the fluid inclusion.",
    "XH2O_mol_max": "Maximum estimated fraction of H2O in the fluid inclusion.",
    "P_kbar_mixCO2_DZ06_Hloss_iteration5_min": "Calculated fluid inclusion pressure using the minimum XH2O in the fluid inclusion.",
    "XH2O_iteration5_min": "Minimum XH2O in the fluid inclusion updated over 5 iterations.",
    "P_mix_min/P_pureCO2": "This column compares the recalculated pressures using the minimum XH2O in the FI to the pure CO2 pressures.",
    "P_kbar_mixCO2_DZ06_Hloss_iteration5_av": "Calculated fluid inclusion pressure using the average XH2O in the fluid inclusion.",
    "XH2O_iteration5_av": "Average XH2O in the fluid inclusion updated over 5 iterations.",
    "P_mix_av/P_pureCO2": "This column compares the recalculated pressures using the average XH2O in the FI to the pure CO2 pressures.",
    "P_kbar_mixCO2_DZ06_Hloss_iteration5_max": "Calculated fluid inclusion pressure using the maximum XH2O in the fluid inclusion.",
    "XH2O_iteration5_max": "Maximum XH2O in the fluid inclusion updated over 5 iterations.",
    "P_mix_max/P_pureCO2": "This column compares the recalculated pressures using the maximum XH2O in the FI to the pure CO2 pressures."
}



df=pd.read_excel(r"C:\Users\charl\Documents\Python dev\2023_Kilauea-rapid-response-simulation\Data+notebooks\Sub_files\Re-submitted_JPET_042324\Revisions\ROUND2_preacceptance\S2_SI_Dataset_final.xlsx",
                 sheet_name="Raman_Reps_averaged")

# Create a list of descriptions based on the lookup key
description_row = [lookup_dict.get(col, '') for col in df.columns]

# Create a new DataFrame from the description row
description_df = pd.DataFrame([description_row], columns=df.columns)

# Use pd.concat to combine the description row and original DataFrame
df_with_descriptions = pd.concat([description_df, df], ignore_index=True)

# Display the DataFrame with descriptions
df_with_descriptions.to_clipboard(excel=True,index=False)

# %%
headers = [
    "Crystal Name", "FI Name", "Reported density mean of reps?", "Density g/cm3", 
    "σ Density g/cm3 (as plotted, from DiadFit for individual, Std dev for averaged FI)", 
    "STDofreps_Density g/cm3", "σ Density g/cm3 (DiadFit)", 
    "σ Density g/cm3 (from Ne+peakfit)", "σ Density g/cm3 (from densimeter)", 
    "Corrected_Splitting (cm-1)", "Corrected_Splitting_σ", 
    "Corrected_Splitting_σ_Ne", "Corrected_Splitting_σ_peak_fit", 
    "power (mW)", "Spectral Center", "Preferred D_σ_Ne", 
    "Preferred D_σ_pkfit", "LowD_RT", "HighD_RT", 
    "LowD_SC", "LowD_SC_σ", "MedD_SC", "MedD_SC_σ", 
    "HighD_SC", "HighD_SC_σ", "Splitting (cm-1)", "Split_σ", 
    "Diad1_Combofit_Cent", "Diad1_cent_err", "Diad1_Combofit_Height", 
    "Diad1_Voigt_Cent", "Diad1_Voigt_Area", "Diad1_Voigt_Sigma", 
    "Diad1_Residual", "Diad1_Prop_Lor", "Diad1_fwhm", 
    "Diad2_Combofit_Cent", "Diad2_cent_err", "Diad2_Combofit_Height", 
    "Diad2_Voigt_Cent", "Diad2_Voigt_Area", "Diad2_Voigt_Sigma", 
    "Diad2_Voigt_Gamma", "Diad2_Residual", "Diad2_Prop_Lor", 
    "Diad2_fwhm", "HB1_Cent", "HB1_Area", "HB1_Sigma", 
    "HB2_Cent", "HB2_Area", "HB2_Sigma", "C13_Cent", 
    "C13_Area", "C13_Sigma", "Diad2_Gauss_Cent", 
    "Diad2_Gauss_Area", "Diad2_Gauss_Sigma", "Diad1_Gauss_Cent", 
    "Diad1_Gauss_Area", "Diad1_Gauss_Sigma", "Day", 
    "Int_time (s)", "accumulations", "Mag (X)", "sec since midnight", 
    "Peak_Cent_SO2", "Peak_Area_SO2", "Peak_Height_SO2", 
    "Peak_Cent_Carb", "Peak_Area_Carb", "Peak_Height_Carb", 
    "Carb_Diad_Ratio", "SO2_Diad_Ratio", "SO2_mol%", 
    "time", "preferred_values", "lower_values", "upper_values", 
    "in range", "Notes", "Temperature", "Diad1_refit", 
    "Diad2_refit", "date", "Month", "duration", 
    "24hr_time", "Model_name", "Texture", "near crack", 
    "Melt film?", "T_C", "P_kbar_1150C", "Depth (km)_ryanlerner",
    "Discarded", "filename", 
    "STDEVS", "STD_Density g/cm3", "STD_σ Density g/cm3", 
    "STD_σ Density g/cm3 (from Ne+peakfit)", 
    "STD_σ Density g/cm3 (from densimeter)", 
    "STD_Corrected_Splitting", "STD_Corrected_Splitting_σ", 
    "STD_Corrected_Splitting_σ_Ne", 
    "STD_Corrected_Splitting_σ_peak_fit", 
    "STD_Preferred D_σ_Ne", "STD_Preferred D_σ_pkfit", 
    "STD_LowD_RT", "STD_HighD_RT", "STD_LowD_SC", 
    "STD_LowD_SC_σ", "STD_MedD_SC", "STD_MedD_SC_σ", 
    "STD_HighD_SC", "STD_HighD_SC_σ", "STD_Splitting", 
    "STD_Split_σ", "STD_Diad1_Combofit_Cent", 
    "STD_Diad1_cent_err", "STD_Diad1_Combofit_Height", 
    "STD_Diad1_Voigt_Cent", "STD_Diad1_Voigt_Area", 
    "STD_Diad1_Voigt_Sigma", "STD_Diad1_Residual", 
    "STD_Diad1_Prop_Lor", "STD_Diad1_fwhm", 
    "STD_Diad2_Combofit_Cent", "STD_Diad2_cent_err", 
    "STD_Diad2_Combofit_Height", "STD_Diad2_Voigt_Cent", 
    "STD_Diad2_Voigt_Area", "STD_Diad2_Voigt_Sigma", 
    "STD_Diad2_Voigt_Gamma", "STD_Diad2_Residual", 
    "STD_Diad2_Prop_Lor", "STD_Diad2_fwhm", 
    "STD_HB1_Cent", "STD_HB1_Area", "STD_HB1_Sigma", 
    "STD_HB2_Cent", "STD_HB2_Area", "STD_HB2_Sigma", 
    "STD_C13_Cent", "STD_C13_Area", "STD_C13_Sigma", 
    "STD_Diad2_Gauss_Cent", "STD_Diad2_Gauss_Area", 
    "STD_Diad2_Gauss_Sigma", "STD_Diad1_Gauss_Cent", 
    "STD_Diad1_Gauss_Area", "STD_Diad1_Gauss_Sigma", 
    "STD_Day", "STD_Int_time (s)", "STD_accumulations", 
    "STD_Mag (X)", "STD_sec since midnight", 
    "STD_Peak_Cent_SO2", "STD_Peak_Area_SO2", 
    "STD_Peak_Height_SO2", "STD_Peak_Cent_Carb", 
    "STD_Peak_Area_Carb", "STD_Peak_Height_Carb", 
    "STD_Carb_Diad_Ratio", "STD_SO2_Diad_Ratio", 
    "STD_preferred_values", "STD_lower_values", 
    "STD_upper_values", "STD_P_kbar_1150C", 
    "STD_Depth (km)_ryanlerner"
]

# %%
# Existing lookup dictionary
lookup_key = {
    'filename': 'name of file',
    'Density g/cm3': 'Density of CO2 in g/cm3',
    'σ Density g/cm3': '1 sigma error on density (combined from peak fitting, Ne correction model, and densimeter equation)',
    'σ Density g/cm3 (from Ne+peakfit)': '1 sigma error on density (from just peak fitting + Ne correction model)',
    'σ Density g/cm3 (from densimeter)': '1 sigma error on density (from just the densimeter equation)',
    'Corrected_Splitting': 'Splitting in cm-1 after correcting for instrument drift',
    'Corrected_Splitting_σ': '1 sigma error on splitting (combined from peak fitting, Ne correction model)',
    'Corrected_Splitting_σ_Ne': '1 sigma error on splitting just from Ne correction model',
    'Corrected_Splitting_σ_peak_fit': '1 sigma error on splitting just from peak fitting',
    'power (mW)': 'Laser power used in mW measured by WITEC TruPower',
    'Spectral Center': 'Spectral Center used for analysis',
    'Preferred D_σ_Ne': 'CHECK!!!',
    'Preferred D_σ_pkfit': 'CHECK!!!',
    'in range': 'Y or N - Is the corrected splitting within the calibration range of the densimeter?',
    'Notes': 'Which segment of the densimeter was used (e.g. which of several polynomials)',
    'LowD_RT': 'Density calculated using the low density part of the Room Temp densimeter',
    'HighD_RT': 'Density calculated using the high density part of the Room Temp densimeter',
    'LowD_SC': 'Density calculated using the low density segment of the 37C densimeter',
    'LowD_SC_σ': 'Error on density calculated using the low density segment of the 37C densimeter',
    'MedD_RC': 'Density calculated using the medium density segment of the 37C densimeter',
    'MedD_SC_σ': 'Error on density calculated using the medium density segment of the 37C densimeter',
    'HighD_SC': 'Density calculated using the high density segment of the 37C densimeter',
    'HighD_SC_σ': 'Error on density calculated using the high density segment of the 37C densimeter',
    'Temperature': 'User entered Temp description: SupCrit or RoomT',
    'Splitting': 'Distance between fitted peak centers of Diad 1 and Diad 2 (cm-1)',
    'Split_σ': 'Error on splitting',
    'Diad1_Combofit_Cent': 'Fitted peak center (cm-1) of Diad1 (combined fit of diad, HB, gaussian background etc.)',
    'Diad1_cent_err': 'Error on peak center of Diad1 (cm-1, calculated using lmfit)',
    'Diad1_Combofit_Height': 'Height (intensity) of Diad1 combined fit',
    'Diad1_Voigt_Cent': 'Fitted peak center (cm-1) of Diad1 for just the main peak',
    'Diad1_Voigt_Area': 'Fitted area of Diad1 for just the main peak',
    'Diad1_Voigt_Sigma': 'Fitted sigma of Diad1 for just the main peak',
    'Diad1_Residual': 'Residual of fit to Diad1 (see DiadFit paper for explanation)',
    'Diad1_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad1',
    'Diad1_fwhm': 'Full Width Half Maximum of the fit to Diad1',
    'Diad1_refit': 'Notes any warnings that flagged during iterative fitting',
    'Diad2_Combofit_Cent': 'Fitted peak center (cm-1) of Diad2 (combined fit of diad, HB, gaussian background etc.)',
    'Diad2_cent_err': 'Error on peak center of Diad2 (cm-1, calculated using lmfit)',
    'Diad2_Combofit_Height': 'Height (intensity) of Diad2 combined fit',
    'Diad2_Voigt_Cent': 'Fitted peak center (cm-1) of Diad2 for just the main peak',
    'Diad2_Voigt_Area': 'Fitted area of Diad2 for just the main peak',
    'Diad2_Voigt_Sigma': 'Fitted sigma of Diad2 for just the main peak',
    'Diad2_Residual': 'Residual of fit to Diad2 (see DiadFit paper for explanation)',
    'Diad2_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad2',
    'Diad2_fwhm': 'Full Width Half Maximum of the fit to Diad2',
    'Diad2_refit': 'Notes any warnings that flagged during iterative fitting',
    'HB1_Cent': 'Fitted peak center of HB1 (cm-1)',
    'HB1_Area': 'Fitted area of HB1',
    'HB1_Sigma': 'Fitted sigma of HB1',
    'HB2_Cent': 'Fitted peak center of HB2 (cm-1)',
    'HB2_Area': 'Fitted area of HB2',
    'HB2_Sigma': 'Fitted sigma of HB2',
    'C13_Cent':  'Fitted peak center of the C13 peak (cm-1)',
    'C13_Area': 'Fitted area of the C13 peak',
    'C13_Sigma': 'Fitted sigma of the C13 peak',
    'Diad2_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad2 (if used)',
    'Diad2_Gauss_Area': 'Fitted area of the Gaussian background on Diad2',
    'Diad2_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad2',
    'Diad1_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad1 (if used)',
    'Diad1_Gauss_Area': 'Fitted area of the Gaussian background on Diad1',
    'Diad1_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad1',
    'Diad1_Asym50': 'Asymmetry of Diad1 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad1_Asym70': 'Asymmetry of Diad1 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad1_Yuan2017_sym_factor': 'Symmetry factor of Diad1 following Yuan 2017',
    'Diad1_Remigi2021_BSF': 'BSF factor of Diad1 following Remigi (2021)',
    'Diad2_Asym50': 'Asymmetry of Diad2 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad2_Asym70': 'Asymmetry of Diad2 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad2_Yuan2017_sym_factor': 'Symmetry factor of Diad2 following Yuan 2017',
    'Diad2_Remigi2021_BSF': 'BSF factor of Diad2 following Remigi (2021)',
    'Diad1_PDF_Model': 'Name of the probability density function used to fit Diad1',
    'Diad2_PDF_Model': 'Name of the probability density function used to fit Diad2',
    'Standard': 'Is the analysis a standard (Yes/No)',
    'date': 'Full date of analysis',
    'Month': 'Month of analysis',
    'Day': 'Day of the week of analysis',
    'Int_time (s)': 'Integration time of each individual spectra in s',
    'accumulations': 'How many individual spectra are collected and averaged for a single reported spectra',
    'Mag (X)': 'Objective used during analysis',
    'duration': 'Duration of analysis as a string from WITEC',
    '24hr_time': 'Time converted to a 24 hr clock',
    'sec since midnight': 'time of acquisition as seconds after midnight on the day of analysis',
    'Peak_Cent_SO2': 'Fitted peak center (cm-1) of the SO2 peak',
    'Peak_Area_SO2': 'Fitted peak area (cm-1) of the SO2 peak',
    'Peak_Height_SO2':  'Fitted peak height (cm-1) of the SO2 peak',
    'Model_name_x': 'Model used to fit the SO2 peak',
    'Peak_Cent_Carb': 'Fitted peak center (cm-1) of the Carb peak',
    'Peak_Area_Carb': 'Fitted peak area (cm-1) of the Carb peak',
    'Peak_Height_Carb':  'Fitted peak height (cm-1) of the Carb peak',
    'Model_name_y': 'Model used to fit the SO2 peak',
    'Carb_Diad_Ratio': 'Area of carbonate peak divided by sum of area of Diad1 and Diad2',
    'SO2_Diad_Ratio': 'Area of the SO2 peak divided by sum of area of Diad1 and Diad2',
    'SO2_mol_ratio': 'Molar proportion of SO2 in the gas species',
    'time': 'seconds after midnight used for Ne correction ',
    'preferred_values': 'Preferred value for Ne correction',
    'lower_values': 'Preferred value - 1 sigma for Ne correction',
    'upper_values': 'Preferred value + 1 sigma for Ne correction',
}

# Headers that are not in the lookup dictionary
new_headers = [
    "Crystal Name", "FI Name", "Reported density mean of reps?", "Density g/cm3", 
    "σ Density g/cm3 (as plotted, from DiadFit for individual, Std dev for averaged FI)", 
    "STDofreps_Density g/cm3", "σ Density g/cm3 (DiadFit)", 
    "σ Density g/cm3 (from Ne+peakfit)", "σ Density g/cm3 (from densimeter)", 
    "Corrected_Splitting (cm-1)", "Corrected_Splitting_σ", 
    "Corrected_Splitting_σ_Ne", "Corrected_Splitting_σ_peak_fit", 
    "power (mW)", "Spectral Center", "Preferred D_σ_Ne", 
    "Preferred D_σ_pkfit", "LowD_RT", "HighD_RT", 
    "LowD_SC", "LowD_SC_σ", "MedD_SC", "MedD_SC_σ", 
    "HighD_SC", "HighD_SC_σ", "Splitting (cm-1)", "Split_σ", 
    "Diad1_Combofit_Cent", "Diad1_cent_err", "Diad1_Combofit_Height", 
    "Diad1_Voigt_Cent", "Diad1_Voigt_Area", "Diad1_Voigt_Sigma", 
    "Diad1_Residual", "Diad1_Prop_Lor", "Diad1_fwhm", 
    "Diad2_Combofit_Cent", "Diad2_cent_err", "Diad2_Combofit_Height", 
    "Diad2_Voigt_Cent", "Diad2_Voigt_Area", "Diad2_Voigt_Sigma", 
    "Diad2_Voigt_Gamma", "Diad2_Residual", "Diad2_Prop_Lor", 
    "Diad2_fwhm", "HB1_Cent", "HB1_Area", "HB1_Sigma", 
    "HB2_Cent", "HB2_Area", "HB2_Sigma", "C13_Cent", 
    "C13_Area", "C13_Sigma", "Diad2_Gauss_Cent", 
    "Diad2_Gauss_Area", "Diad2_Gauss_Sigma", "Diad1_Gauss_Cent", 
    "Diad1_Gauss_Area", "Diad1_Gauss_Sigma", "Day", 
    "Int_time (s)", "accumulations", "Mag (X)", "sec since midnight", 
    "Peak_Cent_SO2", "Peak_Area_SO2", "Peak_Height_SO2", 
    "Peak_Cent_Carb", "Peak_Area_Carb", "Peak_Height_Carb", 
    "Carb_Diad_Ratio", "SO2_Diad_Ratio", "SO2_mol%", 
    "time", "preferred_values", "lower_values", "upper_values", 
    "in range", "Notes", "Temperature", "Diad1_refit", 
    "Diad2_refit", "date", "Month", "duration", 
    "24hr_time", "Model_name", "Texture", "near crack", 
    "Melt film?", "T_C", "P_kbar_1150C", "Depth (km)_ryanlerner",
    "Discarded", "filename", 
    "STDEVS", "STD_Density g/cm3", "STD_σ Density g/cm3", 
    "STD_σ Density g/cm3 (from Ne+peakfit)", 
    "STD_σ Density g/cm3 (from densimeter)", 
    "STD_Corrected_Splitting", "STD_Corrected_Splitting_σ", 
    "STD_Corrected_Splitting_σ_Ne", 
    "STD_Corrected_Splitting_σ_peak_fit", 
    "STD_Preferred D_σ_Ne", "STD_Preferred D_σ_pkfit", 
    "STD_LowD_RT", "STD_HighD_RT", "STD_LowD_SC", 
    "STD_LowD_SC_σ", "STD_MedD_SC", "STD_MedD_SC_σ", 
    "STD_HighD_SC", "STD_HighD_SC_σ", "STD_Splitting", 
    "STD_Split_σ", "STD_Diad1_Combofit_Cent", 
    "STD_Diad1_cent_err", "STD_Diad1_Combofit_Height", 
    "STD_Diad1_Voigt_Cent", "STD_Diad1_Voigt_Area", 
    "STD_Diad1_Voigt_Sigma", "STD_Diad1_Residual", 
    "STD_Diad1_Prop_Lor", "STD_Diad1_fwhm", 
    "STD_Diad2_Combofit_Cent", "STD_Diad2_cent_err", 
    "STD_Diad2_Combofit_Height", "STD_Diad2_Voigt_Cent", 
    "STD_Diad2_Voigt_Area", "STD_Diad2_Voigt_Sigma", 
    "STD_Diad2_Voigt_Gamma", "STD_Diad2_Residual", 
    "STD_Diad2_Prop_Lor", "STD_Diad2_fwhm", 
    "STD_HB1_Cent", "STD_HB1_Area", "STD_HB1_Sigma", 
    "STD_HB2_Cent", "STD_HB2_Area", "STD_HB2_Sigma", 
    "STD_C13_Cent", "STD_C13_Area", "STD_C13_Sigma", 
    "STD_Diad2_Gauss_Cent", "STD_Diad2_Gauss_Area", 
    "STD_Diad2_Gauss_Sigma", "STD_Diad1_Gauss_Cent", 
    "STD_Diad1_Gauss_Area", "STD_Diad1_Gauss_Sigma", 
    "STD_Day", "STD_Int_time (s)", "STD_accumulations", 
    "STD_Mag (X)", "STD_sec since midnight", 
    "STD_Peak_Cent_SO2", "STD_Peak_Area_SO2", 
    "STD_Peak_Height_SO2", "STD_Peak_Cent_Carb", 
    "STD_Peak_Area_Carb", "STD_Peak_Height_Carb", 
    "STD_Carb_Diad_Ratio", "STD_SO2_Diad_Ratio", 
    "STD_preferred_values", "STD_lower_values", 
    "STD_upper_values", "STD_P_kbar_1150C", 
    "STD_Depth (km)_ryanlerner"
]


# Add new entries to the lookup dictionary for missing headers
for header in new_headers:
    if header not in lookup_key:
        lookup_key[header] = 'Description needed'

lookup_key
# Out:
# {'filename': 'name of file',
#  'Density g/cm3': 'Density of CO2 in g/cm3',
#  'σ Density g/cm3': '1 sigma error on density (combined from peak fitting, Ne correction model, and densimeter equation)',
#  'σ Density g/cm3 (from Ne+peakfit)': '1 sigma error on density (from just peak fitting + Ne correction model)',
#  'σ Density g/cm3 (from densimeter)': '1 sigma error on density (from just the densimeter equation)',
#  'Corrected_Splitting': 'Splitting in cm-1 after correcting for instrument drift',
#  'Corrected_Splitting_σ': '1 sigma error on splitting (combined from peak fitting, Ne correction model)',
#  'Corrected_Splitting_σ_Ne': '1 sigma error on splitting just from Ne correction model',
#  'Corrected_Splitting_σ_peak_fit': '1 sigma error on splitting just from peak fitting',
#  'power (mW)': 'Laser power used in mW measured by WITEC TruPower',
#  'Spectral Center': 'Spectral Center used for analysis',
#  'Preferred D_σ_Ne': 'CHECK!!!',
#  'Preferred D_σ_pkfit': 'CHECK!!!',
#  'in range': 'Y or N - Is the corrected splitting within the calibration range of the densimeter?',
#  'Notes': 'Which segment of the densimeter was used (e.g. which of several polynomials)',
#  'LowD_RT': 'Density calculated using the low density part of the Room Temp densimeter',
#  'HighD_RT': 'Density calculated using the high density part of the Room Temp densimeter',
#  'LowD_SC': 'Density calculated using the low density segment of the 37C densimeter',
#  'LowD_SC_σ': 'Error on density calculated using the low density segment of the 37C densimeter',
#  'MedD_RC': 'Density calculated using the medium density segment of the 37C densimeter',
#  'MedD_SC_σ': 'Error on density calculated using the medium density segment of the 37C densimeter',
#  'HighD_SC': 'Density calculated using the high density segment of the 37C densimeter',
#  'HighD_SC_σ': 'Error on density calculated using the high density segment of the 37C densimeter',
#  'Temperature': 'User entered Temp description: SupCrit or RoomT',
#  'Splitting': 'Distance between fitted peak centers of Diad 1 and Diad 2 (cm-1)',
#  'Split_σ': 'Error on splitting',
#  'Diad1_Combofit_Cent': 'Fitted peak center (cm-1) of Diad1 (combined fit of diad, HB, gaussian background etc.)',
#  'Diad1_cent_err': 'Error on peak center of Diad1 (cm-1, calculated using lmfit)',
#  'Diad1_Combofit_Height': 'Height (intensity) of Diad1 combined fit',
#  'Diad1_Voigt_Cent': 'Fitted peak center (cm-1) of Diad1 for just the main peak',
#  'Diad1_Voigt_Area': 'Fitted area of Diad1 for just the main peak',
#  'Diad1_Voigt_Sigma': 'Fitted sigma of Diad1 for just the main peak',
#  'Diad1_Residual': 'Residual of fit to Diad1 (see DiadFit paper for explanation)',
#  'Diad1_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad1',
#  'Diad1_fwhm': 'Full Width Half Maximum of the fit to Diad1',
#  'Diad1_refit': 'Notes any warnings that flagged during iterative fitting',
#  'Diad2_Combofit_Cent': 'Fitted peak center (cm-1) of Diad2 (combined fit of diad, HB, gaussian background etc.)',
#  'Diad2_cent_err': 'Error on peak center of Diad2 (cm-1, calculated using lmfit)',
#  'Diad2_Combofit_Height': 'Height (intensity) of Diad2 combined fit',
#  'Diad2_Voigt_Cent': 'Fitted peak center (cm-1) of Diad2 for just the main peak',
#  'Diad2_Voigt_Area': 'Fitted area of Diad2 for just the main peak',
#  'Diad2_Voigt_Sigma': 'Fitted sigma of Diad2 for just the main peak',
#  'Diad2_Residual': 'Residual of fit to Diad2 (see DiadFit paper for explanation)',
#  'Diad2_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad2',
#  'Diad2_fwhm': 'Full Width Half Maximum of the fit to Diad2',
#  'Diad2_refit': 'Notes any warnings that flagged during iterative fitting',
#  'HB1_Cent': 'Fitted peak center of HB1 (cm-1)',
#  'HB1_Area': 'Fitted area of HB1',
#  'HB1_Sigma': 'Fitted sigma of HB1',
#  'HB2_Cent': 'Fitted peak center of HB2 (cm-1)',
#  'HB2_Area': 'Fitted area of HB2',
#  'HB2_Sigma': 'Fitted sigma of HB2',
#  'C13_Cent': 'Fitted peak center of the C13 peak (cm-1)',
#  'C13_Area': 'Fitted area of the C13 peak',
#  'C13_Sigma': 'Fitted sigma of the C13 peak',
#  'Diad2_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad2 (if used)',
#  'Diad2_Gauss_Area': 'Fitted area of the Gaussian background on Diad2',
#  'Diad2_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad2',
#  'Diad1_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad1 (if used)',
#  'Diad1_Gauss_Area': 'Fitted area of the Gaussian background on Diad1',
#  'Diad1_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad1',
#  'Diad1_Asym50': 'Asymmetry of Diad1 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
#  'Diad1_Asym70': 'Asymmetry of Diad1 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
#  'Diad1_Yuan2017_sym_factor': 'Symmetry factor of Diad1 following Yuan 2017',
#  'Diad1_Remigi2021_BSF': 'BSF factor of Diad1 following Remigi (2021)',
#  'Diad2_Asym50': 'Asymmetry of Diad2 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
#  'Diad2_Asym70': 'Asymmetry of Diad2 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
#  'Diad2_Yuan2017_sym_factor': 'Symmetry factor of Diad2 following Yuan 2017',
#  'Diad2_Remigi2021_BSF': 'BSF factor of Diad2 following Remigi (2021)',
#  'Diad1_PDF_Model': 'Name of the probability density function used to fit Diad1',
#  'Diad2_PDF_Model': 'Name of the probability density function used to fit Diad2',
#  'Standard': 'Is the analysis a standard (Yes/No)',
#  'date': 'Full date of analysis',
#  'Month': 'Month of analysis',
#  'Day': 'Day of the week of analysis',
#  'Int_time (s)': 'Integration time of each individual spectra in s',
#  'accumulations': 'How many individual spectra are collected and averaged for a single reported spectra',
#  'Mag (X)': 'Objective used during analysis',
#  'duration': 'Duration of analysis as a string from WITEC',
#  '24hr_time': 'Time converted to a 24 hr clock',
#  'sec since midnight': 'time of acquisition as seconds after midnight on the day of analysis',
#  'Peak_Cent_SO2': 'Fitted peak center (cm-1) of the SO2 peak',
#  'Peak_Area_SO2': 'Fitted peak area (cm-1) of the SO2 peak',
#  'Peak_Height_SO2': 'Fitted peak height (cm-1) of the SO2 peak',
#  'Model_name_x': 'Model used to fit the SO2 peak',
#  'Peak_Cent_Carb': 'Fitted peak center (cm-1) of the Carb peak',
#  'Peak_Area_Carb': 'Fitted peak area (cm-1) of the Carb peak',
#  'Peak_Height_Carb': 'Fitted peak height (cm-1) of the Carb peak',
#  'Model_name_y': 'Model used to fit the SO2 peak',
#  'Carb_Diad_Ratio': 'Area of carbonate peak divided by sum of area of Diad1 and Diad2',
#  'SO2_Diad_Ratio': 'Area of the SO2 peak divided by sum of area of Diad1 and Diad2',
#  'SO2_mol_ratio': 'Molar proportion of SO2 in the gas species',
#  'time': 'seconds after midnight used for Ne correction ',
#  'preferred_values': 'Preferred value for Ne correction',
#  'lower_values': 'Preferred value - 1 sigma for Ne correction',
#  'upper_values': 'Preferred value + 1 sigma for Ne correction',
#  'Crystal Name': 'Description needed',
#  'FI Name': 'Description needed',
#  'Reported density mean of reps?': 'Description needed',
#  'σ Density g/cm3 (as plotted, from DiadFit for individual, Std dev for averaged FI)': 'Description needed',
#  'STDofreps_Density g/cm3': 'Description needed',
#  'σ Density g/cm3 (DiadFit)': 'Description needed',
#  'Corrected_Splitting (cm-1)': 'Description needed',
#  'MedD_SC': 'Description needed',
#  'Splitting (cm-1)': 'Description needed',
#  'Diad2_Voigt_Gamma': 'Description needed',
#  'SO2_mol%': 'Description needed',
#  'Model_name': 'Description needed',
#  'Texture': 'Description needed',
#  'near crack': 'Description needed',
#  'Melt film?': 'Description needed',
#  'T_C': 'Description needed',
#  'P_kbar_1150C': 'Description needed',
#  'Depth (km)_ryanlerner': 'Description needed',
#  'Discarded': 'Description needed',
#  'STDEVS': 'Description needed',
#  'STD_Density g/cm3': 'Description needed',
#  'STD_σ Density g/cm3': 'Description needed',
#  'STD_σ Density g/cm3 (from Ne+peakfit)': 'Description needed',
#  'STD_σ Density g/cm3 (from densimeter)': 'Description needed',
#  'STD_Corrected_Splitting': 'Description needed',
#  'STD_Corrected_Splitting_σ': 'Description needed',
#  'STD_Corrected_Splitting_σ_Ne': 'Description needed',
#  'STD_Corrected_Splitting_σ_peak_fit': 'Description needed',
#  'STD_Preferred D_σ_Ne': 'Description needed',
#  'STD_Preferred D_σ_pkfit': 'Description needed',
#  'STD_LowD_RT': 'Description needed',
#  'STD_HighD_RT': 'Description needed',
#  'STD_LowD_SC': 'Description needed',
#  'STD_LowD_SC_σ': 'Description needed',
#  'STD_MedD_SC': 'Description needed',
#  'STD_MedD_SC_σ': 'Description needed',
#  'STD_HighD_SC': 'Description needed',
#  'STD_HighD_SC_σ': 'Description needed',
#  'STD_Splitting': 'Description needed',
#  'STD_Split_σ': 'Description needed',
#  'STD_Diad1_Combofit_Cent': 'Description needed',
#  'STD_Diad1_cent_err': 'Description needed',
#  'STD_Diad1_Combofit_Height': 'Description needed',
#  'STD_Diad1_Voigt_Cent': 'Description needed',
#  'STD_Diad1_Voigt_Area': 'Description needed',
#  'STD_Diad1_Voigt_Sigma': 'Description needed',
#  'STD_Diad1_Residual': 'Description needed',
#  'STD_Diad1_Prop_Lor': 'Description needed',
#  'STD_Diad1_fwhm': 'Description needed',
#  'STD_Diad2_Combofit_Cent': 'Description needed',
#  'STD_Diad2_cent_err': 'Description needed',
#  'STD_Diad2_Combofit_Height': 'Description needed',
#  'STD_Diad2_Voigt_Cent': 'Description needed',
#  'STD_Diad2_Voigt_Area': 'Description needed',
#  'STD_Diad2_Voigt_Sigma': 'Description needed',
#  'STD_Diad2_Voigt_Gamma': 'Description needed',
#  'STD_Diad2_Residual': 'Description needed',
#  'STD_Diad2_Prop_Lor': 'Description needed',
#  'STD_Diad2_fwhm': 'Description needed',
#  'STD_HB1_Cent': 'Description needed',
#  'STD_HB1_Area': 'Description needed',
#  'STD_HB1_Sigma': 'Description needed',
#  'STD_HB2_Cent': 'Description needed',
#  'STD_HB2_Area': 'Description needed',
#  'STD_HB2_Sigma': 'Description needed',
#  'STD_C13_Cent': 'Description needed',
#  'STD_C13_Area': 'Description needed',
#  'STD_C13_Sigma': 'Description needed',
#  'STD_Diad2_Gauss_Cent': 'Description needed',
#  'STD_Diad2_Gauss_Area': 'Description needed',
#  'STD_Diad2_Gauss_Sigma': 'Description needed',
#  'STD_Diad1_Gauss_Cent': 'Description needed',
#  'STD_Diad1_Gauss_Area': 'Description needed',
#  'STD_Diad1_Gauss_Sigma': 'Description needed',
#  'STD_Day': 'Description needed',
#  'STD_Int_time (s)': 'Description needed',
#  'STD_accumulations': 'Description needed',
#  'STD_Mag (X)': 'Description needed',
#  'STD_sec since midnight': 'Description needed',
#  'STD_Peak_Cent_SO2': 'Description needed',
#  'STD_Peak_Area_SO2': 'Description needed',
#  'STD_Peak_Height_SO2': 'Description needed',
#  'STD_Peak_Cent_Carb': 'Description needed',
#  'STD_Peak_Area_Carb': 'Description needed',
#  'STD_Peak_Height_Carb': 'Description needed',
#  'STD_Carb_Diad_Ratio': 'Description needed',
#  'STD_SO2_Diad_Ratio': 'Description needed',
#  'STD_preferred_values': 'Description needed',
#  'STD_lower_values': 'Description needed',
#  'STD_upper_values': 'Description needed',
#  'STD_P_kbar_1150C': 'Description needed',
#  'STD_Depth (km)_ryanlerner': 'Description needed'}

# %%
lookup_key = {
    'filename': 'name of file',
    'Density g/cm3': 'Density of CO2 in g/cm3',
    'σ Density g/cm3': '1 sigma error on density (combined from peak fitting, Ne correction model, and densimeter equation)',
    'σ Density g/cm3 (from Ne+peakfit)': '1 sigma error on density (from just peak fitting + Ne correction model)',
    'σ Density g/cm3 (from densimeter)': '1 sigma error on density (from just the densimeter equation)',
    'Corrected_Splitting': 'Splitting in cm-1 after correcting for instrument drift',
    'Corrected_Splitting_σ': '1 sigma error on splitting (combined from peak fitting, Ne correction model)',
    'Corrected_Splitting_σ_Ne': '1 sigma error on splitting just from Ne correction model',
    'Corrected_Splitting_σ_peak_fit': '1 sigma error on splitting just from peak fitting',
    'power (mW)': 'Laser power used in mW measured by WITEC TruPower',
    'Spectral Center': 'Spectral Center used for analysis',
    'Preferred D_σ_Ne': 'CHECK!!!',
    'Preferred D_σ_pkfit': 'CHECK!!!',
    'in range': 'Y or N - Is the corrected splitting within the calibration range of the densimeter?',
    'Notes': 'Which segment of the densimeter was used (e.g. which of several polynomials)',
    'LowD_RT': 'Density calculated using the low density part of the Room Temp densimeter',
    'HighD_RT': 'Density calculated using the high density part of the Room Temp densimeter',
    'LowD_SC': 'Density calculated using the low density segment of the 37C densimeter',
    'LowD_SC_σ': 'Error on density calculated using the low density segment of the 37C densimeter',
    'MedD_RC': 'Density calculated using the medium density segment of the 37C densimeter',
    'MedD_SC_σ': 'Error on density calculated using the medium density segment of the 37C densimeter',
    'HighD_SC': 'Density calculated using the high density segment of the 37C densimeter',
    'HighD_SC_σ': 'Error on density calculated using the high density segment of the 37C densimeter',
    'Temperature': 'User entered Temp description: SupCrit or RoomT',
    'Splitting': 'Distance between fitted peak centers of Diad 1 and Diad 2 (cm-1)',
    'Split_σ': 'Error on splitting',
    'Diad1_Combofit_Cent': 'Fitted peak center (cm-1) of Diad1 (combined fit of diad, HB, gaussian background etc.)',
    'Diad1_cent_err': 'Error on peak center of Diad1 (cm-1, calculated using lmfit)',
    'Diad1_Combofit_Height': 'Height (intensity) of Diad1 combined fit',
    'Diad1_Voigt_Cent': 'Fitted peak center (cm-1) of Diad1 for just the main peak',
    'Diad1_Voigt_Area': 'Fitted area of Diad1 for just the main peak',
    'Diad1_Voigt_Sigma': 'Fitted sigma of Diad1 for just the main peak',
    'Diad1_Residual': 'Residual of fit to Diad1 (see DiadFit paper for explanation)',
    'Diad1_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad1',
    'Diad1_fwhm': 'Full Width Half Maximum of the fit to Diad1',
    'Diad1_refit': 'Notes any warnings that flagged during iterative fitting',
    'Diad2_Combofit_Cent': 'Fitted peak center (cm-1) of Diad2 (combined fit of diad, HB, gaussian background etc.)',
    'Diad2_cent_err': 'Error on peak center of Diad2 (cm-1, calculated using lmfit)',
    'Diad2_Combofit_Height': 'Height (intensity) of Diad2 combined fit',
    'Diad2_Voigt_Cent': 'Fitted peak center (cm-1) of Diad2 for just the main peak',
    'Diad2_Voigt_Area': 'Fitted area of Diad2 for just the main peak',
    'Diad2_Voigt_Sigma': 'Fitted sigma of Diad2 for just the main peak',
    'Diad2_Residual': 'Residual of fit to Diad2 (see DiadFit paper for explanation)',
    'Diad2_Prop_Lor': 'Proportion of Lorentzian in Psuedovoigt peak for Diad2',
    'Diad2_fwhm': 'Full Width Half Maximum of the fit to Diad2',
    'Diad2_refit': 'Notes any warnings that flagged during iterative fitting',
    'HB1_Cent': 'Fitted peak center of HB1 (cm-1)',
    'HB1_Area': 'Fitted area of HB1',
    'HB1_Sigma': 'Fitted sigma of HB1',
    'HB2_Cent': 'Fitted peak center of HB2 (cm-1)',
    'HB2_Area': 'Fitted area of HB2',
    'HB2_Sigma': 'Fitted sigma of HB2',
    'C13_Cent':  'Fitted peak center of the C13 peak (cm-1)',
    'C13_Area': 'Fitted area of the C13 peak',
    'C13_Sigma': 'Fitted sigma of the C13 peak',
    'Diad2_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad2 (if used)',
    'Diad2_Gauss_Area': 'Fitted area of the Gaussian background on Diad2',
    'Diad2_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad2',
    'Diad1_Gauss_Cent': 'Fitted peak center (cm-1) of the Gaussian background on Diad1 (if used)',
    'Diad1_Gauss_Area': 'Fitted area of the Gaussian background on Diad1',
    'Diad1_Gauss_Sigma': 'Fitted sigma of the Gaussian background on Diad1',
    'Diad1_Asym50': 'Asymmetry of Diad1 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad1_Asym70': 'Asymmetry of Diad1 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad1_Yuan2017_sym_factor': 'Symmetry factor of Diad1 following Yuan 2017',
    'Diad1_Remigi2021_BSF': 'BSF factor of Diad1 following Remigi (2021)',
    'Diad2_Asym50': 'Asymmetry of Diad2 using a 50% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad2_Asym70': 'Asymmetry of Diad2 using a 70% intensity cut off (see DeVitre et al. 2023, Volcanica)',
    'Diad2_Yuan2017_sym_factor': 'Symmetry factor of Diad2 following Yuan 2017',
    'Diad2_Remigi2021_BSF': 'BSF factor of Diad2 following Remigi (2021)',
    'Diad1_PDF_Model': 'Name of the probability density function used to fit Diad1',
    'Diad2_PDF_Model': 'Name of the probability density function used to fit Diad2',
    'Standard': 'Is the analysis a standard (Yes/No)',
    'date': 'Full date of analysis',
    'Month': 'Month of analysis',
    'Day': 'Day of the week of analysis',
    'Int_time (s)': 'Integration time of each individual spectra in s',
    'accumulations': 'How many individual spectra are collected and averaged for a single reported spectra',
    'Mag (X)': 'Objective used during analysis',
    'duration': 'Duration of analysis as a string from WITEC',
    '24hr_time': 'Time converted to a 24 hr clock',
    'sec since midnight': 'time of acquisition as seconds after midnight on the day of analysis',
    'Peak_Cent_SO2': 'Fitted peak center (cm-1) of the SO2 peak',
    'Peak_Area_SO2': 'Fitted peak area (cm-1) of the SO2 peak',
    'Peak_Height_SO2':  'Fitted peak height (cm-1) of the SO2 peak',
    'Model_name_x': 'Model used to fit the SO2 peak',
    'Peak_Cent_Carb': 'Fitted peak center (cm-1) of the Carb peak',
    'Peak_Area_Carb': 'Fitted peak area (cm-1) of the Carb peak',
    'Peak_Height_Carb':  'Fitted peak height (cm-1) of the Carb peak',
    'Model_name_y': 'Model used to fit the SO2 peak',
    'Carb_Diad_Ratio': 'Area of carbonate peak divided by sum of area of Diad1 and Diad2',
    'SO2_Diad_Ratio': 'Area of the SO2 peak divided by sum of area of Diad1 and Diad2',
    'SO2_mol_ratio': 'Molar proportion of SO2 in the gas species',
    'time': 'seconds after midnight used for Ne correction ',
    'preferred_values': 'Preferred value for Ne correction',
    'lower_values': 'Preferred value - 1 sigma for Ne correction',
    'upper_values': 'Preferred value + 1 sigma for Ne correction',
}
