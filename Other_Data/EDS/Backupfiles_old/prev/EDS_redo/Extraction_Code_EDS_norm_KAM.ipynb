# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import mineralML as mm
#import Thermobar as pt

# %%
#mm.__version__

# %%
def process_excel_file(file_path, sheet_name=1):
    # Load the Excel file from the specified sheet without headers
    data = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    
    # Find indices where 'Element' is found in column 0 to determine the start of data blocks
    data_blocks_indices = data.index[data[0] == 'Element'].tolist()
    
    # Initialize an empty DataFrame to store processed data
    processed_data = []

    # Iterate through each data block
    for i, start in enumerate(data_blocks_indices):
        print(f"Processing row: {start + 1}")
        # The label for the block is in the row just before the 'Element' row
        label = data.iloc[start - 1, 0]
        
        # Identify the end of the block by finding the next 'Total' row after 'Element'
        total_index = data.index[(data[0] == 'Total') & (data.index > start)].min()
        end = total_index  # Set end to the row before 'Total
        
        # Extract data block for current sample
        block = data.iloc[start + 1:end]  # Extract rows between 'Element' and 'Total'
        headers = ['Element'] + data.iloc[start, 1:].dropna().values.tolist()  # Get headers from the 'Element' row
        
        # Ensure the number of columns matches expected headers
        block.columns = headers[:block.shape[1]]
        
        # Prepare a row dictionary to append to the DataFrame
        row_dict = {'Sample Name': label}
        for _, row in block.iterrows():
            element = row['Element']
            
            for col in row.index[1:]:  # Skip the 'Element' column for key names
                if pd.notna(row[col]):  # Check for NaN
                    col_name = f"{col}_{element}"  # Use header from 'Element' row for column names
                    row_dict[col_name] = row[col]

        # Capture 'Total_wt%' and 'Total_Oxide %' from the 'Total' row
        total_row = data.iloc[total_index, :]  # Correctly access the 'Total' row
        row_dict['Total_wt%'] = total_row.get(headers.index('Wt%'), None)  # Use dynamic index for 'Wt%'
        row_dict['Total_Oxide%'] = total_row.get(headers.index('Oxide %'), None)  # Use dynamic index for 'Oxide %'
        # row_dict['Cation_Sum'] = total_row.get(headers.index('Number of Ions'), None)  # Use dynamic index for 'Oxide %'
        # row_dict['Cation_Sum']=row_dict['Cation_Sum'].replace('(Cation sum)', '')

                    
        processed_data.append(row_dict)

    return pd.DataFrame(processed_data)

# %%
def sort_columns(df, norm = False):
    # Start with fixed priority columns
    priority_cols = ['Sample Name', 'Total_wt%', 'Total_Oxide%'] #, 'Cation_Sum']

    # Define exact matches for metrics and their intended order
    col_order = ['Oxide %_', 'Oxide % Sigma_', 'norm_Oxide %_', 'Wt%_', 'Wt% Sigma_']


    element_to_oxide = {
        'Si': 'SiO2', 'Ti': 'TiO2', 'Al': 'Al2O3', 'Ca': 'CaO',
        'Cr': 'Cr2O3', 'Fe': 'FeO', 'Ni': 'NiO', 'Na': 'Na2O',
        'Mg': 'MgO','Mn': 'MnO',
        'K': 'K2O', 'P': 'P2O5'
    }

    # Rename columns based on the mapping
    new_columns = {}
    for col in df.columns:
        if 'Oxide' in col:
            for element, oxide in element_to_oxide.items():
                if f'_{element}' in col:
                    new_col_name = col.replace(f'_{element}', f'_{oxide}')
                    new_columns[col] = new_col_name

    df.rename(columns=new_columns, inplace=True)
    
    
    # Find the columns that are going to be involved in the normalization
    desired_string = 'Oxide %_'
    matching_columns = [col for col in df.columns if desired_string in col]
    matching_column_indices = [df.columns.get_loc(col) for col in matching_columns]
        
    # Convert SO3 to SO2
    if 'Oxide %_S' in list(df.keys()):
        df = df.rename(columns={'Oxide %_S': 'Oxide %_SO2'})
        df['Oxide %_SO2'] = df['Oxide %_SO2']*(32.065+2*15.999)/(32.065+3*15.999)

    # normalization
    df_norm = df.iloc[:, matching_column_indices]
    df_norm = df_norm.map(lambda x: 0 if x < 0 else x)
    sum = df_norm.sum(axis = 1)
    df_norm = 100*df_norm.div(sum, axis = 0)

    df_norm = df_norm.add_suffix('_norm')
    df_norm = df_norm.add_prefix('norm_')
    df_norm = df_norm.fillna(0.0)

    df = pd.concat([df, df_norm], axis=1)

    # if norm is true, switch normalized and un-normalized analyses
    if norm is True:
        elements = set([col.split('_')[-1].split('_norm')[0] for col in df.columns if 'Oxide %_' in col])
        
        # Swap the data between corresponding columns
        for element in elements:
            if element != 'norm':
                oxide_col = f'Oxide %_{element}'
                norm_oxide_col = f'norm_Oxide %_{element}_norm'
                
                # Swap the data using a temporary variable
                temp = df[oxide_col].copy()
                df[oxide_col] = df[norm_oxide_col]
                df[norm_oxide_col] = temp


    # Collect and sort metric-specific columns using more accurate matching
    metric_cols = []
    for metric in col_order:
        # This loop will check if the columns end with the metric name preceded by an underscore
        # to ensure we match 'Oxide %_Mg' but not 'Something Oxide %_Mg'
        metric_cols.extend(sorted([col for col in df.columns if col.startswith(metric)]))

    
    # Collect all other columns not in priority or metric-specific lists
    other_cols = [col for col in df.columns if col not in priority_cols and col not in metric_cols]

    # Move 'Apparent Concentration' columns to the end
    apparent_concentration_cols = [col for col in other_cols if 'Apparent Concentration' in col]
    other_cols = [col for col in other_cols if col not in apparent_concentration_cols]

    # Combine all columns in the desired order
    final_cols = priority_cols + metric_cols + sorted(other_cols) + sorted(apparent_concentration_cols)

    # Debugging: Print out final column order
    # Move 'Apparent Concentration' columns to the end
    for bad_names in ['Apparent Concentration', 'Factory Standard', 'Line', 'Number of Ions']:
        
        apparent_concentration_cols = [col for col in df.columns if bad_names in col]
        final_cols = [col for col in final_cols if col not in apparent_concentration_cols] + apparent_concentration_cols

    df_out=df[final_cols]

    # replace column headers to make compatible with MinML
    
    df_out.rename(columns=lambda x: x.replace('norm_Oxide %_', ''), inplace=True)   
    if norm is True:
        df_out.rename(columns=lambda x: x.replace('_norm','_unnorm'), inplace=True)
         
    df_out.rename(columns=lambda x: x.replace('Oxide %_', ''), inplace=True)
    df_out.rename(columns=lambda x: x.replace('Number of Ions', '#_ions_'), inplace=True)
    df_out.rename(columns=lambda x: x.replace('FeO', 'FeOt'), inplace=True)

    # Reorder DataFrame
    return df_out

# %% [markdown]
# ## Scroll down to here to run!

# %%
# Had to delete beam current column - e.g. P in excel and onwards ,because it cant deal with changing column headings. 
result = process_excel_file(r"P:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Kamaehu2024\Fluid inclusions\EDS\EDS_redo\MountR3_EDS_6-18-24\MountR3_EDS_6-18-24.xlsx",
                             sheet_name="All_KAM")
sorted_df = sort_columns(result)
sorted_df['SampleID']=sorted_df['Sample Name']
sorted_df['Fo']=(sorted_df['MgO']/40.3044)/((sorted_df['MgO']/40.3044)+(sorted_df['FeOt']/71.844))
# Out:
# Processing row: 2
# Processing row: 12
# Processing row: 22
# Processing row: 32
# Processing row: 42
# Processing row: 52
# Processing row: 62
# Processing row: 72
# Processing row: 82
# Processing row: 92
# Processing row: 102
# Processing row: 112
# Processing row: 122
# Processing row: 132
# Processing row: 142
# Processing row: 152
# Processing row: 162
# Processing row: 172
# Processing row: 182
# Processing row: 192
# Processing row: 202
# Processing row: 212
# Processing row: 222
# Processing row: 232
# Processing row: 242
# Processing row: 252
# Processing row: 262
# Processing row: 272
# Processing row: 282
# Processing row: 292
# Processing row: 302
# Processing row: 312
# Processing row: 322
# Processing row: 332
# Processing row: 342
# Processing row: 352
# Processing row: 362
# Processing row: 372
# Processing row: 382
# Processing row: 392
# Processing row: 402
# Processing row: 412
# Processing row: 422
# Processing row: 432
# Processing row: 442
# Processing row: 452
# Processing row: 462
# Processing row: 472
# Processing row: 482
# Processing row: 492
# Processing row: 502
# Processing row: 512
# Processing row: 522
# Processing row: 532
# Processing row: 542
# Processing row: 552
# Processing row: 562
# Processing row: 572
# Processing row: 582
# Processing row: 592
# Processing row: 602
# Processing row: 612
# Processing row: 622
# Processing row: 632
# Processing row: 642
# Processing row: 652
# Processing row: 662
# Processing row: 672
# Processing row: 682
# Processing row: 692
# Processing row: 702
# Processing row: 712
# Processing row: 722
# Processing row: 730
# Processing row: 738
# Processing row: 746
# Processing row: 756
# Processing row: 766
# Processing row: 776
# Processing row: 788
# Processing row: 800

# %%
# Had to delete beam current column - e.g. P in excel and onwards ,because it cant deal with changing column headings. 
result2 = process_excel_file(r"P:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Kamaehu2024\Fluid inclusions\EDS\EDS_redo\MountR3_EDS_5-8-24\MountR3_EDS_61024.xlsx",
                              sheet_name="All_KAM")
sorted_df2 = sort_columns(result2)
sorted_df2['SampleID']=sorted_df2['Sample Name']
sorted_df2['Fo']=(sorted_df2['MgO']/40.3044)/((sorted_df2['MgO']/40.3044)+(sorted_df2['FeOt']/71.844))
# Out:
# Processing row: 2
# Processing row: 11
# Processing row: 20
# Processing row: 29
# Processing row: 38
# Processing row: 47
# Processing row: 56
# Processing row: 66
# Processing row: 76
# Processing row: 86
# Processing row: 96
# Processing row: 106
# Processing row: 116
# Processing row: 127
# Processing row: 138
# Processing row: 149
# Processing row: 159
# Processing row: 169
# Processing row: 179
# Processing row: 189
# Processing row: 199
# Processing row: 209
# Processing row: 219
# Processing row: 229
# Processing row: 239
# Processing row: 249
# Processing row: 259
# Processing row: 269
# Processing row: 279
# Processing row: 289
# Processing row: 299
# Processing row: 309
# Processing row: 319
# Processing row: 329
# Processing row: 339
# Processing row: 349
# Processing row: 359
# Processing row: 369
# Processing row: 379
# Processing row: 389
# Processing row: 399
# Processing row: 409
# Processing row: 419
# Processing row: 429
# Processing row: 439
# Processing row: 449
# Processing row: 459
# Processing row: 469
# Processing row: 479
# Processing row: 489
# Processing row: 499
# Processing row: 509
# Processing row: 519
# Processing row: 529
# Processing row: 539
# Processing row: 550
# Processing row: 561

# %%
sorted_df2
# Out:
#               Sample Name  Total_wt%  Total_Oxide%   Al2O3     CaO   Cr2O3  \
# 0          Springwater1_1   100.4363      100.4363     NaN     NaN     NaN
# 1          Springwater1_2    99.9991       99.9991     NaN     NaN     NaN
# 2          Springwater1_3    99.8620       99.8620     NaN     NaN     NaN
# 3            SanCarlos1_1    99.6089       99.6089     NaN     NaN     NaN
# 4            SanCarlos1_2    99.8239       99.8239     NaN     NaN     NaN
# 5            SanCarlos1_3    99.9058       99.9058     NaN     NaN     NaN
# 6          Springwater1_4   100.2613      100.2613     NaN  0.0350     NaN
# 7          Springwater1_5   100.6750      100.6750     NaN  0.0100     NaN
# 8          Springwater1_6   100.5384      100.5384     NaN -0.0064     NaN
# 9            SanCarlos1_4    99.6455       99.6455     NaN  0.1080     NaN
# 10           SanCarlos1_5   100.5267      100.5267     NaN  0.0892     NaN
# 11           SanCarlos1_6    99.4350       99.4350     NaN  0.1175     NaN
# 12               JThyp1_1    99.2265       99.2265  1.0283  1.3103  0.6790
# 13               JThyp1_2    99.8136       99.8136  0.9575  1.2564  0.6731
# 14               JThyp1_3    99.4687       99.4687  1.0821  1.2310  0.6764
# 15         187-1-101-reg1   100.0515      100.0515     NaN  0.3078     NaN
# 16         187-1-101-reg2   100.1209      100.1209     NaN  0.3442     NaN
# 17         187-1-101-reg3    99.1836       99.1836     NaN  0.3298     NaN
# 18            187-1-102-A   101.4095      101.4095     NaN  0.3671     NaN
# 19            187-1-102-B   101.3727      101.3727     NaN  0.3870     NaN
# 20            187-1-102-C   101.3151      101.3151     NaN  0.3453     NaN
# 21         187-1-103-core   100.6803      100.6802     NaN  0.3772     NaN
# 22          187-1-103-rim    98.5462       98.5462     NaN  0.3049     NaN
# 23            187-1-104-A    99.7321       99.7321     NaN  0.3410     NaN
# 24         187-1-105-reg1   101.7429      101.7429     NaN  0.3212     NaN
# 25         187-1-105-reg2   101.1519      101.1519     NaN  0.3375     NaN
# 26         187-1-105-reg3   100.2915      100.2915     NaN  0.3297     NaN
# 27         187-1-105-reg4   101.4354      101.4354     NaN  0.3357     NaN
# 28            187-1-106-A    99.4886       99.4886     NaN  0.2896     NaN
# 29            187-1-106-B   100.0432      100.0432     NaN  0.2840     NaN
# 30            187-1-107-A    97.4447       97.4447     NaN  0.3504     NaN
# 31       187-1-107-A_away    98.4894       98.4894     NaN  0.3108     NaN
# 32            187-1-107-B   101.1447      101.1447     NaN  0.3293     NaN
# 33          187-1-107-C,D   101.7230      101.7230     NaN  0.3427     NaN
# 34       187-1-108-A_away    98.2782       98.2782     NaN  0.4201     NaN
# 35            187-1-109-A   102.5013      102.5013     NaN  0.4145     NaN
# 36            187-1-109-B   101.5469      101.5469     NaN  0.3437     NaN
# 37          187-1-109-C,D   101.7373      101.7373     NaN  0.3524     NaN
# 38            187-1-110-A    99.7521       99.7521     NaN  0.2832     NaN
# 39            187-1-110-B    99.2113       99.2113     NaN  0.2756     NaN
# 40         187-1-111-reg1   100.0017      100.0017     NaN  0.2807     NaN
# 41         187-1-111-reg2   100.6271      100.6271     NaN  0.3136     NaN
# 42  187-1-111-reg3-inside    98.4307       98.4307     NaN  0.3280     NaN
# 43         187-1-111-reg3    99.2529       99.2529     NaN  0.3486     NaN
# 44         187-1-111-reg4   100.7378      100.7378     NaN  0.2936     NaN
# 45         187-1-111-reg5    99.5563       99.5563     NaN  0.2787     NaN
# 46         187-1-111-reg6    99.5421       99.5421     NaN  0.3290     NaN
# 47       187-1-111-reg7,8   101.3860      101.3860     NaN  0.2698     NaN
# 48         Springwater1_7   100.7958      100.7958     NaN  0.0170     NaN
# 49         Springwater1_8   100.2891      100.2891     NaN  0.0013     NaN
# 50         Springwater1_9   100.7491      100.7491     NaN  0.0154     NaN
# 51           SanCarlos1_7    99.6768       99.6768     NaN  0.0935     NaN
# 52           SanCarlos1_8    99.9738       99.9738     NaN  0.1036     NaN
# 53           SanCarlos1_9    99.7765       99.7765     NaN  0.0791     NaN
# 54               JThyp1_4    99.5674       99.5674  1.0395  1.3594  0.6466
# 55               JThyp1_5    99.5118       99.5118  0.9990  1.3889  0.6879
# 56               JThyp1_6    99.9002       99.9002  1.0217  1.4009  0.6564
#
#        FeOt      MgO     MnO     NiO  ...   Line_Mg   Line_Si   Line_Mn  \
# 0   16.6446  43.5823  0.3159  0.0073  ...  K series  K series  K series
# 1   16.5925  43.5158  0.2995 -0.0020  ...  K series  K series  K series
# 2   16.5952  43.4066  0.3650 -0.0077  ...  K series  K series  K series
# 3    9.6447  48.5375  0.1358  0.3784  ...  K series  K series  K series
# 4    9.7401  48.6696  0.1626  0.3645  ...  K series  K series  K series
# 5    9.8925  48.6104  0.1295  0.3939  ...  K series  K series  K series
# 6   16.5798  43.4894  0.3185  0.0013  ...  K series  K series  K series
# 7   16.6662  43.7129  0.3159  0.0061  ...  K series  K series  K series
# 8   16.5337  43.6994  0.3244 -0.0033  ...  K series  K series  K series
# 9    9.6892  48.5078  0.1783  0.3806  ...  K series  K series  K series
# 10   9.8485  49.0546  0.1356  0.3588  ...  K series  K series  K series
# 11   9.6663  48.4618  0.0955  0.3612  ...  K series  K series  K series
# 12  14.8063  26.3446  0.5492     NaN  ...  K series  K series  K series
# 13  15.0701  26.5226  0.5001     NaN  ...  K series  K series  K series
# 14  15.1364  26.4011  0.5482     NaN  ...  K series  K series  K series
# 15  12.8572  46.0803  0.2270  0.4083  ...  K series  K series  K series
# 16  12.7108  46.1448  0.2019  0.3001  ...  K series  K series  K series
# 17  12.5571  45.8986  0.1986  0.2998  ...  K series  K series  K series
# 18  13.7361  46.0745  0.2132  0.2790  ...  K series  K series  K series
# 19  13.5197  46.2671  0.2264  0.2668  ...  K series  K series  K series
# 20  13.6406  46.1389  0.1991  0.2871  ...  K series  K series  K series
# 21  13.1549  46.1498  0.2114  0.2893  ...  K series  K series  K series
# 22  12.9665  45.2602  0.2151  0.2919  ...  K series  K series  K series
# 23  13.0680  45.8798  0.2137  0.2827  ...  K series  K series  K series
# 24  11.9308  47.8222  0.1812  0.3191  ...  K series  K series  K series
# 25  12.0003  47.4450  0.1865  0.3329  ...  K series  K series  K series
# 26  11.9373  47.0624  0.2036  0.3229  ...  K series  K series  K series
# 27  12.0026  47.7040  0.2077  0.3224  ...  K series  K series  K series
# 28  10.7499  47.3811  0.1365  0.3095  ...  K series  K series  K series
# 29  10.9366  47.6127  0.1453  0.3158  ...  K series  K series  K series
# 30  14.0991  43.7066  0.2701  0.2655  ...  K series  K series  K series
# 31  14.0241  44.3890  0.2204  0.2595  ...  K series  K series  K series
# 32  14.1185  45.7538  0.2321  0.2498  ...  K series  K series  K series
# 33  14.2182  46.1051  0.2324  0.2543  ...  K series  K series  K series
# 34  12.9551  45.0515  0.2105  0.2812  ...  K series  K series  K series
# 35  12.5938  47.6793  0.1925  0.2893  ...  K series  K series  K series
# 36  12.1896  47.4894  0.1476  0.3490  ...  K series  K series  K series
# 37  12.2522  47.4314  0.1856  0.3212  ...  K series  K series  K series
# 38  10.8877  47.4885  0.1918  0.4335  ...  K series  K series  K series
# 39  10.9274  47.1772  0.1784  0.4158  ...  K series  K series  K series
# 40  11.0520  47.5395  0.1382  0.4175  ...  K series  K series  K series
# 41  11.8602  47.2143  0.1778  0.3660  ...  K series  K series  K series
# 42  11.6127  46.1119  0.1998  0.3759  ...  K series  K series  K series
# 43  11.8965  46.4859  0.1604  0.3584  ...  K series  K series  K series
# 44  11.5140  47.5374  0.1837  0.3878  ...  K series  K series  K series
# 45  11.7026  46.7634  0.2028  0.3901  ...  K series  K series  K series
# 46  11.2923  47.1319  0.1725  0.4145  ...  K series  K series  K series
# 47  10.9754  48.2988  0.1920  0.4183  ...  K series  K series  K series
# 48  16.6501  43.8209  0.3228  0.0032  ...  K series  K series  K series
# 49  16.5714  43.5771  0.2949  0.0048  ...  K series  K series  K series
# 50  16.7487  43.7660  0.3431  0.0071  ...  K series  K series  K series
# 51   9.7506  48.6311  0.1046  0.3583  ...  K series  K series  K series
# 52   9.7098  48.6764  0.1713  0.3684  ...  K series  K series  K series
# 53   9.7508  48.5012  0.1650  0.3738  ...  K series  K series  K series
# 54  14.9421  26.3144  0.5525     NaN  ...  K series  K series  K series
# 55  14.8205  26.2048  0.5611     NaN  ...  K series  K series  K series
# 56  15.0340  26.3182  0.5520     NaN  ...  K series  K series  K series
#
#      Line_Fe   Line_Ni   Line_Ca   Line_Al   Line_Cr               SampleID  \
# 0   K series        Kα       NaN       NaN       NaN         Springwater1_1
# 1   K series        Kα       NaN       NaN       NaN         Springwater1_2
# 2   K series        Kα       NaN       NaN       NaN         Springwater1_3
# 3   K series        Kα       NaN       NaN       NaN           SanCarlos1_1
# 4   K series        Kα       NaN       NaN       NaN           SanCarlos1_2
# 5   K series        Kα       NaN       NaN       NaN           SanCarlos1_3
# 6   K series        Kα  K series       NaN       NaN         Springwater1_4
# 7   K series        Kα  K series       NaN       NaN         Springwater1_5
# 8   K series        Kα  K series       NaN       NaN         Springwater1_6
# 9   K series        Kα  K series       NaN       NaN           SanCarlos1_4
# 10  K series        Kα  K series       NaN       NaN           SanCarlos1_5
# 11  K series        Kα  K series       NaN       NaN           SanCarlos1_6
# 12  K series       NaN  K series  K series  K series               JThyp1_1
# 13  K series       NaN  K series  K series  K series               JThyp1_2
# 14  K series       NaN  K series  K series  K series               JThyp1_3
# 15  K series  K series  K series       NaN       NaN         187-1-101-reg1
# 16  K series        Kα  K series       NaN       NaN         187-1-101-reg2
# 17  K series        Kα  K series       NaN       NaN         187-1-101-reg3
# 18  K series        Kα  K series       NaN       NaN            187-1-102-A
# 19  K series        Kα  K series       NaN       NaN            187-1-102-B
# 20  K series        Kα  K series       NaN       NaN            187-1-102-C
# 21  K series        Kα  K series       NaN       NaN         187-1-103-core
# 22  K series        Kα  K series       NaN       NaN          187-1-103-rim
# 23  K series        Kα  K series       NaN       NaN            187-1-104-A
# 24  K series        Kα  K series       NaN       NaN         187-1-105-reg1
# 25  K series        Kα  K series       NaN       NaN         187-1-105-reg2
# 26  K series        Kα  K series       NaN       NaN         187-1-105-reg3
# 27  K series        Kα  K series       NaN       NaN         187-1-105-reg4
# 28  K series        Kα  K series       NaN       NaN            187-1-106-A
# 29  K series        Kα  K series       NaN       NaN            187-1-106-B
# 30  K series        Kα  K series       NaN       NaN            187-1-107-A
# 31  K series        Kα  K series       NaN       NaN       187-1-107-A_away
# 32  K series        Kα  K series       NaN       NaN            187-1-107-B
# 33  K series        Kα  K series       NaN       NaN          187-1-107-C,D
# 34  K series        Kα  K series       NaN       NaN       187-1-108-A_away
# 35  K series        Kα  K series       NaN       NaN            187-1-109-A
# 36  K series        Kα  K series       NaN       NaN            187-1-109-B
# 37  K series        Kα  K series       NaN       NaN          187-1-109-C,D
# 38  K series        Kα  K series       NaN       NaN            187-1-110-A
# 39  K series        Kα  K series       NaN       NaN            187-1-110-B
# 40  K series        Kα  K series       NaN       NaN         187-1-111-reg1
# 41  K series        Kα  K series       NaN       NaN         187-1-111-reg2
# 42  K series        Kα  K series       NaN       NaN  187-1-111-reg3-inside
# 43  K series        Kα  K series       NaN       NaN         187-1-111-reg3
# 44  K series        Kα  K series       NaN       NaN         187-1-111-reg4
# 45  K series        Kα  K series       NaN       NaN         187-1-111-reg5
# 46  K series        Kα  K series       NaN       NaN         187-1-111-reg6
# 47  K series        Kα  K series       NaN       NaN       187-1-111-reg7,8
# 48  K series        Kα  K series       NaN       NaN         Springwater1_7
# 49  K series        Kα  K series       NaN       NaN         Springwater1_8
# 50  K series        Kα  K series       NaN       NaN         Springwater1_9
# 51  K series        Kα  K series       NaN       NaN           SanCarlos1_7
# 52  K series        Kα  K series       NaN       NaN           SanCarlos1_8
# 53  K series        Kα  K series       NaN       NaN           SanCarlos1_9
# 54  K series       NaN  K series  K series  K series               JThyp1_4
# 55  K series       NaN  K series  K series  K series               JThyp1_5
# 56  K series       NaN  K series  K series  K series               JThyp1_6
#
#           Fo
# 0   0.823552
# 1   0.823786
# 2   0.823397
# 3   0.899706
# 4   0.899061
# 5   0.897532
# 6   0.823809
# 7   0.823798
# 8   0.824909
# 9   0.899235
# 10  0.898772
# 11  0.899363
# 12  0.760286
# 13  0.758289
# 14  0.756639
# 15  0.864657
# 16  0.866154
# 17  0.866942
# 18  0.856715
# 19  0.859159
# 20  0.857740
# 21  0.862135
# 22  0.861535
# 23  0.862225
# 24  0.877224
# 25  0.875738
# 26  0.875430
# 27  0.876309
# 28  0.887091
# 29  0.885849
# 30  0.846762
# 31  0.849445
# 32  0.852435
# 33  0.852512
# 34  0.861088
# 35  0.870944
# 36  0.874128
# 37  0.873428
# 38  0.886038
# 39  0.885002
# 40  0.884626
# 41  0.876484
# 42  0.876209
# 43  0.874456
# 44  0.880375
# 45  0.876892
# 46  0.881516
# 47  0.886933
# 48  0.824296
# 49  0.824174
# 50  0.823257
# 51  0.898892
# 52  0.899357
# 53  0.898647
# 54  0.758408
# 55  0.759140
# 56  0.757309
#
# [57 rows x 125 columns]

# %%
sorted_df_merge = pd.concat([sorted_df, sorted_df2], ignore_index=True)

# %%
sorted_df_merge.to_excel('EDS_KAM.xlsx')

# %% [markdown]
# ## Now lets merge the SEM dataframe with the Raman data

# %%
Raman_df=pd.read_excel('Google KL_SWRZ_wdepths.xlsx')
Raman_df.head()
# Out:
#    Unnamed: 0 Mount          filename Name_on_SEM  \
# 0           0   NaN   FG04-A1-1-start         NaN
# 1           1   NaN        FG04-A1-16         NaN
# 2           2   NaN        FG04-A1-16         NaN
# 3           3   NaN  FG04-A1-16-start         NaN
# 4           4   NaN   FG04-A1-2-start         NaN
#
#   Notes regarding SEM matching        Unnamed: 5  Density g/cm3  \
# 0                          NaN   FG04_A1_1_start       0.609630
# 1                          NaN        FG04_A1_16       0.478732
# 2                          NaN        FG04_A1_16       0.480376
# 3                          NaN  FG04_A1_16_start       0.494153
# 4                          NaN   FG04_A1_2_start       0.464893
#
#    σ Density g/cm3  σ Density g/cm3 (from Ne+peakfit)  \
# 0         0.007472                           0.007085
# 1         0.004766                           0.004145
# 2         0.004752                           0.004129
# 3         0.004861                           0.004253
# 4         0.009226                           0.008921
#
#    σ Density g/cm3 (from densimeter)  ...  T_K_input  error_T_K  \
# 0                           0.002372  ...    1423.15        100
# 1                           0.002353  ...    1423.15        100
# 2                           0.002353  ...    1423.15        100
# 3                           0.002355  ...    1423.15        100
# 4                           0.002352  ...    1423.15        100
#
#    CO2_dens_gcm3_input  error_CO2_dens_gcm3  crust_dens_kgm3_input  \
# 0             0.609630             0.007472                    NaN
# 1             0.478732             0.004766                    NaN
# 2             0.480376             0.004752                    NaN
# 3             0.494153             0.004861                    NaN
# 4             0.464893             0.009226                    NaN
#
#    error_crust_dens_kgm3             model   EOS XH2O_input error_XH2O
# 0                      5  denlinger_lerner  DZ06        0.1       0.05
# 1                      5  denlinger_lerner  DZ06        0.1       0.05
# 2                      5  denlinger_lerner  DZ06        0.1       0.05
# 3                      5  denlinger_lerner  DZ06        0.1       0.05
# 4                      5  denlinger_lerner  DZ06        0.1       0.05
#
# [5 rows x 127 columns]

# %%
sorted_df_renamed = sorted_df_merge.rename(columns={'Sample Name': 'Name_on_SEM'})

# Merge the dataframes on the 'Name_on_SEM' column
combined_df = Raman_df.merge(sorted_df_renamed, on='Name_on_SEM', how='left')

# %%
combined_df.to_excel('Raman_SEM_Merged.xlsx')

# %%
## Find K24 ones
K24=combined_df['filename'].str.contains('K24')
U919=combined_df['filename'].str.contains('919')
plt.plot(combined_df['Fo'].loc[K24], combined_df['Density g/cm3'].loc[K24], '.r', label='2024')
plt.plot(combined_df['Fo'].loc[U919], combined_df['Density g/cm3'].loc[U919], '.k', label='1974')
plt.legend()
plt.ylabel('Density g/cm3')
plt.xlabel('Fo')
# Out:
# Text(0.5, 0, 'Fo')
